# %% [markdown]
# ETL. Extracción y transformación
# EDA. Análisis preliminar de calidad de datos

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# Como el objetivo principal del trabajo es analizar cúales con los factores socioeconómicos que más inciden en la Eperanza de Vida de los (35) países de que integran la OEA (Organización de Estados Americanos), nos vamos vamos a focalizar en buscar indicadores que tengan que ver con el desarrollo económico y el crecimiento de los países.
# Como fuente de datos, nos vamos a nutrir de las bases de datos del World Bank y de base de datos externas de otros organismos internacionales especializados en desarrollo.
# Vamos a poceder a extrer los datos de la base del Banco Mundial utilizando la API que provee el WB.
# Creamos un código para poder extraer los distintos indicadores potenciales para ser analizados, de las distintas bases de datos que se elojan en el sitio del organismo internacional. Las principales bases de datos utilizadas del BM son World Economic Indicators(WEI) y Health & Nutrition indicators.
# El análisis preliminar nos permite hacer un corte en los datos, que se tomarán datos a partir de 1990, debido a al aumento de la disponibilidad de la data del WB y la externa al WB (aún a definir?).
# Elegimos a priori aproximadamente 50 indicadores, según los grandes temas o tópicos de las bases del BM que tienen que ver con factores socioeconómicos que más inciden en la esperanza de vida, y luego apoyados en base a literatura especializada en el tema. (Fuente)
# Al analizar los indicadores prelimminarmente, advertimos que hay variables que podrían enriquecer nuestros análisis, pero que si bien existen en la base de datos del BM, hay muchos nulos y la calidad por tanto no es buena. Dedicimos usar bases de datos externas para aumentar la calidad de los datos, y contar con indicadores confiables en hábitos como consumo de Tabaco, Obesidad, y gasto publico social de los gobiernos.
# Bases de datos externas utilizadas:  Cepal, Naciones Unidas

# %%
#Etracción de Metadata para extraer luego los datos de cógidos de países e indicadores necesarios
# 50 indicadores

# %%
#Código para extraer los datos con la API del WB
#particionamos la información de los países e indicadores para realizar la extracción
# Países de la OEA
countries = ["USA",
    "ATG",
    "ARG",
    "BHS",
    "BRB",
    "BLZ",
    
]


# Indicadores elegidos luego de consultar las distintas base de datos en desarrollo y crecimiento del WB

indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años deseados para extraer los datos
#En base analisis preliminares y a la disponibildiad de las series de tiempo de lo indicadores, 
# optamos por tomar la data a partir de 1990, cuando comienza a aumentar la cantidad de datos 
# relacionados con el desarrollo
#Vamos a bajar los datos en distintos dataframes que luego se van a concatenar para unificarlo en un dataset
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df0 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df0
# Out:
#                País                                          Indicador   Año  \
# 0     United States  Account ownership at a financial institution o...  2022
# 1     United States  Account ownership at a financial institution o...  2021
# 2     United States  Account ownership at a financial institution o...  2020
# 3     United States  Account ownership at a financial institution o...  2019
# 4     United States  Account ownership at a financial institution o...  2018
# ...             ...                                                ...   ...
# 9697         Belize  Total alcohol consumption per capita (liters o...  1994
# 9698         Belize  Total alcohol consumption per capita (liters o...  1993
# 9699         Belize  Total alcohol consumption per capita (liters o...  1992
# 9700         Belize  Total alcohol consumption per capita (liters o...  1991
# 9701         Belize  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1     94.95
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
#Continuamos con la extraccion extracción de datos de los países
countries = ["CAN",
    "CHL",
    "COL",
    "CRI",
    "CUB",
    "DOM",
    "ECU"]
    
    

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df
# Out:
#           País                                          Indicador   Año  Valor
# 0       Canada  Account ownership at a financial institution o...  2022    NaN
# 1       Canada  Account ownership at a financial institution o...  2021  99.63
# 2       Canada  Account ownership at a financial institution o...  2020    NaN
# 3       Canada  Account ownership at a financial institution o...  2019    NaN
# 4       Canada  Account ownership at a financial institution o...  2018    NaN
# ...        ...                                                ...   ...    ...
# 11281  Ecuador  Total alcohol consumption per capita (liters o...  1994    NaN
# 11282  Ecuador  Total alcohol consumption per capita (liters o...  1993    NaN
# 11283  Ecuador  Total alcohol consumption per capita (liters o...  1992    NaN
# 11284  Ecuador  Total alcohol consumption per capita (liters o...  1991    NaN
# 11285  Ecuador  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [11286 rows x 4 columns]

# %%
#Continuamos con el mismo proceso
countries = [
    "GRD",
    "GTM",
    "GUY",
    "HTI",
    "HND",
    "JAM" ]
# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df_a = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df_a
# Out:
#          País                                          Indicador   Año  Valor
# 0     Grenada  Account ownership at a financial institution o...  2022    NaN
# 1     Grenada  Account ownership at a financial institution o...  2021    NaN
# 2     Grenada  Account ownership at a financial institution o...  2020    NaN
# 3     Grenada  Account ownership at a financial institution o...  2019    NaN
# 4     Grenada  Account ownership at a financial institution o...  2018    NaN
# ...       ...                                                ...   ...    ...
# 9697  Jamaica  Total alcohol consumption per capita (liters o...  1994    NaN
# 9698  Jamaica  Total alcohol consumption per capita (liters o...  1993    NaN
# 9699  Jamaica  Total alcohol consumption per capita (liters o...  1992    NaN
# 9700  Jamaica  Total alcohol consumption per capita (liters o...  1991    NaN
# 9701  Jamaica  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [9702 rows x 4 columns]

# %%
#Sigue la lista de países para exraer la data ...
countries = [ 
             "BOL", "BRA", "PER", "DOM", "KNA", "SLV"
             ]
# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años elegidos 
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df1 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df1
# Out:
#              País                                          Indicador   Año  \
# 0         Bolivia  Account ownership at a financial institution o...  2022
# 1         Bolivia  Account ownership at a financial institution o...  2021
# 2         Bolivia  Account ownership at a financial institution o...  2020
# 3         Bolivia  Account ownership at a financial institution o...  2019
# 4         Bolivia  Account ownership at a financial institution o...  2018
# ...           ...                                                ...   ...
# 9697  El Salvador  Total alcohol consumption per capita (liters o...  1994
# 9698  El Salvador  Total alcohol consumption per capita (liters o...  1993
# 9699  El Salvador  Total alcohol consumption per capita (liters o...  1992
# 9700  El Salvador  Total alcohol consumption per capita (liters o...  1991
# 9701  El Salvador  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1     68.89
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
#Sigue la lista de países para exraer la data ...
countries = [
    "MEX", "NIC", "PAN", "PRY" 
]


# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años elegidos 
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df2 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df2
# Out:
#           País                                          Indicador   Año  Valor
# 0       Mexico  Account ownership at a financial institution o...  2022  48.97
# 1       Mexico  Account ownership at a financial institution o...  2021    NaN
# 2       Mexico  Account ownership at a financial institution o...  2020    NaN
# 3       Mexico  Account ownership at a financial institution o...  2019    NaN
# 4       Mexico  Account ownership at a financial institution o...  2018    NaN
# ...        ...                                                ...   ...    ...
# 6463  Paraguay  Total alcohol consumption per capita (liters o...  1994    NaN
# 6464  Paraguay  Total alcohol consumption per capita (liters o...  1993    NaN
# 6465  Paraguay  Total alcohol consumption per capita (liters o...  1992    NaN
# 6466  Paraguay  Total alcohol consumption per capita (liters o...  1991    NaN
# 6467  Paraguay  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [6468 rows x 4 columns]

# %%
#Ultima extracción de data para analizar los países que integran la OEA
countries =[ "LCA", "VCT", "SUR", "TTO", "URY", "VEN"  ]

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df3 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df3
# Out:
#                País                                          Indicador   Año  \
# 0         St. Lucia  Account ownership at a financial institution o...  2022
# 1         St. Lucia  Account ownership at a financial institution o...  2021
# 2         St. Lucia  Account ownership at a financial institution o...  2020
# 3         St. Lucia  Account ownership at a financial institution o...  2019
# 4         St. Lucia  Account ownership at a financial institution o...  2018
# ...             ...                                                ...   ...
# 9697  Venezuela, RB  Total alcohol consumption per capita (liters o...  1994
# 9698  Venezuela, RB  Total alcohol consumption per capita (liters o...  1993
# 9699  Venezuela, RB  Total alcohol consumption per capita (liters o...  1992
# 9700  Venezuela, RB  Total alcohol consumption per capita (liters o...  1991
# 9701  Venezuela, RB  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
# Unificamos los dataframes
concatenated_df2 = pd.concat([data_df0, data_df, data_df1, data_df3, data_df2, data_df_a], ignore_index=True)

# El argumento 'ignore_index=True' restablece los índices de fila para que sean secuenciales.

# Ahora 'concatenated_df' contiene todos los datos de los tres DataFrames.

# %%
concatenated_df2
# Out:
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 56557        Jamaica  Total alcohol consumption per capita (liters o...  1994
# 56558        Jamaica  Total alcohol consumption per capita (liters o...  1993
# 56559        Jamaica  Total alcohol consumption per capita (liters o...  1992
# 56560        Jamaica  Total alcohol consumption per capita (liters o...  1991
# 56561        Jamaica  Total alcohol consumption per capita (liters o...  1990
#
#        Valor
# 0        NaN
# 1      94.95
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 56557    NaN
# 56558    NaN
# 56559    NaN
# 56560    NaN
# 56561    NaN
#
# [56562 rows x 4 columns]

# %%
concatenated_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56562 entries, 0 to 56561
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       56562 non-null  object
#  1   Indicador  56562 non-null  object
#  2   Año        56562 non-null  object
#  3   Valor      39404 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ MB

# %%
#Agregamos data de unos indicadores Obesidad, Gasto publico social, y Consumo de Tabado,  de base de datos externna
#Falta codigo para extraer base de datos eternas
#preliminarmente subimos lso cvs.
archivo1_csv = '../proyecto_final_bootcamp_henry//datasets/obesidad.csv'
archivo2_csv = "../proyecto_final_bootcamp_henry/datasets/consumo_tabaco (1).csv"
archivo3_csv = "../proyecto_final_bootcamp_henry/datasets/gasto_social.csv"

# Cargar el archivo CSV en un DataFrame
data_df5 = pd.read_csv(archivo1_csv)
data_df6 = pd.read_csv(archivo2_csv)
data_df7 = pd.read_csv(archivo3_csv)

# %%
#unificamos datafraames de fuentes externas , para Tabaco, Obesidad y Gasto público social
concatenated_df3 = pd.concat([data_df5, data_df6, data_df7], ignore_index=True)

# %%
concatenated_df3.head()
# Out:
#                Country   Año  \
# 0  Antigua and Barbuda  1990
# 1  Antigua and Barbuda  1991
# 2  Antigua and Barbuda  1992
# 3  Antigua and Barbuda  1993
# 4  Antigua and Barbuda  1994
#
#    Proportion of adults who are obese, 20 years old and over ,by sex  \
# 0                                                8.6
# 1                                                8.9
# 2                                                9.2
# 3                                                9.6
# 4                                                9.9
#
#    Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gasto público social según la clasificación por funciones del gobierno
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Cambiar nombre columna de "Country" a "País"

# Cambiar el nombre de la columna 'Año'
concatenated_df3 = concatenated_df3.rename(columns={'Country': 'País'})

# %%
concatenated_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56595 entries, 0 to 56594
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       56595 non-null  object
#  1   Indicador  56595 non-null  object
#  2   Año        56595 non-null  object
#  3   Valor      39436 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ MB

# %%
concatenated_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3947 entries, 0 to 3946
# Data columns (total 5 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   País                                                                                              3947 non-null   object
#  1   Año                                                                                               3947 non-null   int64
#  2   Proportion of adults who are obese, 20 years old and over ,by sex                                 2835 non-null   float64
#  3   Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  504 non-null    float64
#  4   Gasto público social según la clasificación por funciones del gobierno                            608 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 154.3+ KB

# %%
import pandas as pd

# Suponiendo que concatenated_df3 es el primer DataFrame y concatenated_df2 es el segundo DataFrame

# Asegúrate de que la columna 'Año' sea del mismo tipo de datos en ambos DataFrames (por ejemplo, int64)
concatenated_df2['Año'] = concatenated_df2['Año'].astype(int)

# Fusiona el segundo DataFrame (concatenated_df2) con el primer DataFrame (concatenated_df3) en base a las columnas 'País' y 'Año'
result = pd.merge(concatenated_df2, concatenated_df3, on=['País', 'Año'])

# Si lo deseas, puedes renombrar la columna 'Indicador' para que coincida con el nombre original
result.rename(columns={'Indicador_y': 'Indicador', 'Valor_y': 'Valor'}, inplace=True)

# Muestra el DataFrame resultante
print(result)
# Out:
#                        País  \
# 0       Antigua and Barbuda
# 1       Antigua and Barbuda
# 2       Antigua and Barbuda
# 3       Antigua and Barbuda
# 4       Antigua and Barbuda
# ...                     ...
# 153361              Jamaica
# 153362              Jamaica
# 153363              Jamaica
# 153364              Jamaica
# 153365              Jamaica
#
#                                                 Indicador   Año   Valor  \
# 0       Account ownership at a financial institution o...  2016     NaN
# 1       Account ownership at a financial institution o...  2016     NaN
# 2       Account ownership at a financial institution o...  2016     NaN
# 3                    Birth rate, crude (per 1,000 people)  2016  11.659
# 4                    Birth rate, crude (per 1,000 people)  2016  11.659
# ...                                                   ...   ...     ...
# 153361  Diabetes prevalence (% of population ages 20 t...  1990     NaN
# 153362  Diabetes prevalence (% of population ages 20 t...  1990     NaN
# 153363  Total alcohol consumption per capita (liters o...  1990     NaN
# 153364  Total alcohol consumption per capita (liters o...  1990     NaN
# 153365  Total alcohol consumption per capita (liters o...  1990     NaN
#
#         Proportion of adults who are obese, 20 years old and over ,by sex  \
# 0                                                    19.1
# 1                                                    26.3
# 2                                                    11.7
# 3                                                    19.1
# 4                                                    26.3
# ...                                                   ...
# 153361                                               16.1
# 153362                                                4.4
# 153363                                               10.4
# 153364                                               16.1
# 153365                                                4.4
#
#         Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                                NaN
# 153365                                                NaN
#
#         Gasto público social según la clasificación por funciones del gobierno
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                                NaN
# 153365                                                NaN
#
# [153366 rows x 7 columns]

# %%
import pandas as pd

# Suponiendo que concatenated_df3 es el primer DataFrame y concatenated_df2 es el segundo DataFrame

# Asegúrate de que la columna 'Año' sea del mismo tipo de datos en ambos DataFrames (por ejemplo, int64)
concatenated_df3['Año'] = concatenated_df2['Año'].astype(int)

# Fusiona el segundo DataFrame (concatenated_df2) con el primer DataFrame (concatenated_df3) en base a las columnas 'País' y 'Año'
result = pd.merge(concatenated_df2, concatenated_df3, on=['País', 'Año'])

# Si lo deseas, puedes renombrar la columna 'Indicador' para que coincida con el nombre original
result.rename(columns={'Indicador_y': 'Indicador', 'Valor_y': 'Valor'}, inplace=True)

# Muestra el DataFrame resultante
print(result)
# Out:
#                        País  \
# 0       Antigua and Barbuda
# 1       Antigua and Barbuda
# 2       Antigua and Barbuda
# 3       Antigua and Barbuda
# 4       Antigua and Barbuda
# ...                     ...
# 153361              Jamaica
# 153362              Jamaica
# 153363              Jamaica
# 153364              Jamaica
# 153365              Jamaica
#
#                                                 Indicador   Año  Valor  \
# 0       Account ownership at a financial institution o...  2022    NaN
# 1       Account ownership at a financial institution o...  2022    NaN
# 2       Account ownership at a financial institution o...  2022    NaN
# 3                    Birth rate, crude (per 1,000 people)  2022    NaN
# 4                    Birth rate, crude (per 1,000 people)  2022    NaN
# ...                                                   ...   ...    ...
# 153361  Total alcohol consumption per capita (liters o...  1990    NaN
# 153362  Total alcohol consumption per capita (liters o...  1990    NaN
# 153363  Total alcohol consumption per capita (liters o...  1990    NaN
# 153364  Total alcohol consumption per capita (liters o...  1990    NaN
# 153365  Total alcohol consumption per capita (liters o...  1990    NaN
#
#         Proportion of adults who are obese, 20 years old and over ,by sex  \
# 0                                                     8.6
# 1                                                    18.5
# 2                                                    10.8
# 3                                                     8.6
# 4                                                    18.5
# ...                                                   ...
# 153361                                               24.4
# 153362                                               18.7
# 153363                                               10.4
# 153364                                                NaN
# 153365                                                NaN
#
#         Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                               20.1
# 153365                                                NaN
#
#         Gasto público social según la clasificación por funciones del gobierno
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                                NaN
# 153365                                          28431.039
#
# [153366 rows x 7 columns]

# %%
# Asigna el DataFrame resultante a la variable concatenated_df3
concatenated_df2_df3 = result

# %%
concatenated_df2_df3
# Out:
#                        País  \
# 0       Antigua and Barbuda
# 1       Antigua and Barbuda
# 2       Antigua and Barbuda
# 3       Antigua and Barbuda
# 4       Antigua and Barbuda
# ...                     ...
# 153361              Jamaica
# 153362              Jamaica
# 153363              Jamaica
# 153364              Jamaica
# 153365              Jamaica
#
#                                                 Indicador   Año  Valor  \
# 0       Account ownership at a financial institution o...  2022    NaN
# 1       Account ownership at a financial institution o...  2022    NaN
# 2       Account ownership at a financial institution o...  2022    NaN
# 3                    Birth rate, crude (per 1,000 people)  2022    NaN
# 4                    Birth rate, crude (per 1,000 people)  2022    NaN
# ...                                                   ...   ...    ...
# 153361  Total alcohol consumption per capita (liters o...  1990    NaN
# 153362  Total alcohol consumption per capita (liters o...  1990    NaN
# 153363  Total alcohol consumption per capita (liters o...  1990    NaN
# 153364  Total alcohol consumption per capita (liters o...  1990    NaN
# 153365  Total alcohol consumption per capita (liters o...  1990    NaN
#
#         Proportion of adults who are obese, 20 years old and over ,by sex  \
# 0                                                     8.6
# 1                                                    18.5
# 2                                                    10.8
# 3                                                     8.6
# 4                                                    18.5
# ...                                                   ...
# 153361                                               24.4
# 153362                                               18.7
# 153363                                               10.4
# 153364                                                NaN
# 153365                                                NaN
#
#         Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                               20.1
# 153365                                                NaN
#
#         Gasto público social según la clasificación por funciones del gobierno
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 153361                                                NaN
# 153362                                                NaN
# 153363                                                NaN
# 153364                                                NaN
# 153365                                          28431.039
#
# [153366 rows x 7 columns]

# %%
# Elimina las últimas 3 columnas
columns_to_remove = [
    'Proportion of adults who are obese, 20 years old and over ,by sex',
    'Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex',
    'Gasto público social según la clasificación por funciones del gobierno'
]

concatenated_df2_df3 = concatenated_df2_df3.drop(columns=columns_to_remove)

# %%
concatenated_df2_df3
# Out:
#                        País  \
# 0       Antigua and Barbuda
# 1       Antigua and Barbuda
# 2       Antigua and Barbuda
# 3       Antigua and Barbuda
# 4       Antigua and Barbuda
# ...                     ...
# 153361              Jamaica
# 153362              Jamaica
# 153363              Jamaica
# 153364              Jamaica
# 153365              Jamaica
#
#                                                 Indicador   Año  Valor
# 0       Account ownership at a financial institution o...  2022    NaN
# 1       Account ownership at a financial institution o...  2022    NaN
# 2       Account ownership at a financial institution o...  2022    NaN
# 3                    Birth rate, crude (per 1,000 people)  2022    NaN
# 4                    Birth rate, crude (per 1,000 people)  2022    NaN
# ...                                                   ...   ...    ...
# 153361  Total alcohol consumption per capita (liters o...  1990    NaN
# 153362  Total alcohol consumption per capita (liters o...  1990    NaN
# 153363  Total alcohol consumption per capita (liters o...  1990    NaN
# 153364  Total alcohol consumption per capita (liters o...  1990    NaN
# 153365  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [153366 rows x 4 columns]

# %%
#Vamos a agrupar los indicadores por países y por año 
# 1. Cambia el tipo de dato de la columna 'Año' a numérico (int)
concatenated_df2_df3['Año'] = pd.to_numeric(concatenated_df2_df3['Año'], errors='coerce')

# 2. Realiza una agregación (por ejemplo, suma) en caso de entradas duplicadas
df_aggregated_df2_df3 = concatenated_df2_df3.groupby(['País', 'Año', 'Indicador'])['Valor'].sum().unstack()

# Esto creará un nuevo DataFrame 'df_aggregated' con cada indicador como una columna individual y las entradas duplicadas se agregan mediante la suma (Ver concepto).

# %%
#Exportamos la tabla final de datos crudos a un csv 
nombre_del_archivo = 'df_aggregated_df2_df3.csv'
df_aggregated_df2_df3.to_csv(nombre_del_archivo, index=False)

# %%
#Tabla de indicadores por países y año

df_aggregated_df2_df3
# Out:
# Indicador                 Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# País                Año
# Antigua and Barbuda 1990                                               0.00
#                     1991                                               0.00
#                     1992                                               0.00
#                     1993                                               0.00
#                     1994                                               0.00
# ...                                                                     ...
# Uruguay             2018                                               0.00
#                     2019                                               0.00
#                     2020                                               0.00
#                     2021                                             370.65
#                     2022                                               0.00
#
# Indicador                 Birth rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                41.832
#                     1991                                37.008
#                     1992                                38.456
#                     1993                                37.194
#                     1994                                37.980
# ...                                                        ...
# Uruguay             2018                                46.420
#                     2019                                43.288
#                     2020                                41.356
#                     2021                                52.365
#                     2022                                 0.000
#
# Indicador                 CO2 emissions (kg per PPP $ of GDP)  \
# País                Año
# Antigua and Barbuda 1990                             0.602579
#                     1991                             0.578818
#                     1992                             0.552112
#                     1993                             0.520486
#                     1994                             0.484595
# ...                                                       ...
# Uruguay             2018                             0.318995
#                     2019                             0.323461
#                     2020                             0.325995
#                     2021                             0.000000
#                     2022                             0.000000
#
# Indicador                 Capital health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                               0.000000
#                     1991                               0.000000
#                     1992                               0.000000
#                     1993                               0.000000
#                     1994                               0.000000
# ...                                                         ...
# Uruguay             2018                               0.806297
#                     2019                               0.837991
#                     2020                               0.619265
#                     2021                               0.000000
#                     2022                               0.000000
#
# Indicador                 Compulsory education, duration (years)  \
# País                Año
# Antigua and Barbuda 1990                                     0.0
#                     1991                                     0.0
#                     1992                                     0.0
#                     1993                                     0.0
#                     1994                                     0.0
# ...                                                          ...
# Uruguay             2018                                    56.0
#                     2019                                    56.0
#                     2020                                    56.0
#                     2021                                    70.0
#                     2022                                    70.0
#
# Indicador                 Control of Corruption: Estimate  \
# País                Año
# Antigua and Barbuda 1990                         0.000000
#                     1991                         0.000000
#                     1992                         0.000000
#                     1993                         0.000000
#                     1994                         0.000000
# ...                                                   ...
# Uruguay             2018                         4.829370
#                     2019                         4.781612
#                     2020                         5.459737
#                     2021                         7.931268
#                     2022                         8.052640
#
# Indicador                 Current health expenditure per capita, PPP (current international $)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Uruguay             2018                                        8560.667916
#                     2019                                        9104.855617
#                     2020                                        8442.283732
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 Death rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                15.332
#                     1991                                15.506
#                     1992                                15.490
#                     1993                                15.332
#                     1994                                15.066
# ...                                                        ...
# Uruguay             2018                                39.452
#                     2019                                40.228
#                     2020                                37.728
#                     2021                                60.810
#                     2022                                 0.000
#
# Indicador                 Diabetes prevalence (% of population ages 20 to 79)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Uruguay             2018                                                0.0
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                               45.0
#                     2022                                                0.0
#
# Indicador                 Domestic general government health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Uruguay             2018                                          24.923353
#                     2019                                          25.015905
#                     2020                                          26.269562
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País                Año   ...
# Antigua and Barbuda 1990  ...                                        0.0
#                     1991  ...                                        0.0
#                     1992  ...                                        0.0
#                     1993  ...                                        0.0
#                     1994  ...                                        0.0
# ...                       ...                                        ...
# Uruguay             2018  ...                                        4.4
#                     2019  ...                                        4.4
#                     2020  ...                                        6.8
#                     2021  ...                                        8.0
#                     2022  ...                                        0.0
#
# Indicador                 Pregnant women receiving prenatal care (%)  \
# País                Año
# Antigua and Barbuda 1990                                         0.0
#                     1991                                         0.0
#                     1992                                         0.0
#                     1993                                         0.0
#                     1994                                         0.0
# ...                                                              ...
# Uruguay             2018                                         0.0
#                     2019                                         0.0
#                     2020                                         0.0
#                     2021                                         0.0
#                     2022                                         0.0
#
# Indicador                 Prevalence of overweight (% of adults)  \
# País                Año
# Antigua and Barbuda 1990                                    67.4
#                     1991                                    68.8
#                     1992                                    69.8
#                     1993                                    71.0
#                     1994                                    72.2
# ...                                                          ...
# Uruguay             2018                                     0.0
#                     2019                                     0.0
#                     2020                                     0.0
#                     2021                                     0.0
#                     2022                                     0.0
#
# Indicador                 Prevalence of overweight, weight for height (% of children under 5)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Uruguay             2018                                               45.6
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                                0.0
#                     2022                                                0.0
#
# Indicador                 Prevalence of undernourishment (% of population)  \
# País                Año
# Antigua and Barbuda 1990                                               0.0
#                     1991                                               0.0
#                     1992                                               0.0
#                     1993                                               0.0
#                     1994                                               0.0
# ...                                                                    ...
# Uruguay             2018                                              10.0
#                     2019                                              10.0
#                     2020                                              10.0
#                     2021                                               0.0
#                     2022                                               0.0
#
# Indicador                 Rural population (% of total population)  \
# País                Año
# Antigua and Barbuda 1990                                   129.148
#                     1991                                   129.070
#                     1992                                   129.830
#                     1993                                   130.582
#                     1994                                   131.332
# ...                                                            ...
# Uruguay             2018                                    18.664
#                     2019                                    18.296
#                     2020                                    17.940
#                     2021                                    21.985
#                     2022                                    21.560
#
# Indicador                 Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País                Año
# Antigua and Barbuda 1990                                             0.0000
#                     1991                                             0.0000
#                     1992                                             0.0000
#                     1993                                             0.0000
#                     1994                                             0.0000
# ...                                                                     ...
# Uruguay             2018                                             0.0000
#                     2019                                            21.8106
#                     2020                                             0.0000
#                     2021                                             0.0000
#                     2022                                             0.0000
#
# Indicador                 Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País                Año
# Antigua and Barbuda 1990                                              0.000
#                     1991                                              0.000
#                     1992                                              0.000
#                     1993                                              0.000
#                     1994                                              0.000
# ...                                                                     ...
# Uruguay             2018                                             33.360
#                     2019                                             34.920
#                     2020                                             41.320
#                     2021                                             46.450
#                     2022                                             39.205
#
# Indicador                 Urban population  \
# País                Año
# Antigua and Barbuda 1990           44870.0
#                     1991           45136.0
#                     1992           45372.0
#                     1993           45700.0
#                     1994           46058.0
# ...                                    ...
# Uruguay             2018        13068544.0
#                     2019        13086376.0
#                     2020        13101164.0
#                     2021        16378035.0
#                     2022        16376015.0
#
# Indicador                 Urban population (% of total population)
# País                Año
# Antigua and Barbuda 1990                                    70.852
#                     1991                                    70.930
#                     1992                                    70.170
#                     1993                                    69.418
#                     1994                                    68.668
# ...                                                            ...
# Uruguay             2018                                   381.336
#                     2019                                   381.704
#                     2020                                   382.060
#                     2021                                   478.015
#                     2022                                   478.440
#
# [891 rows x 49 columns]

# %%
#Composición de la tabla, nuevas columnas de indicadores y filas con años/países
df_aggregated_df2_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 891 entries, ('Antigua and Barbuda', 1990) to ('Uruguay', 2022)
# Data columns (total 49 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  891 non-null    float64
#  1   Birth rate, crude (per 1,000 people)                                                                             891 non-null    float64
#  2   CO2 emissions (kg per PPP $ of GDP)                                                                              891 non-null    float64
#  3   Capital health expenditure (% of GDP)                                                                            891 non-null    float64
#  4   Compulsory education, duration (years)                                                                           891 non-null    float64
#  5   Control of Corruption: Estimate                                                                                  891 non-null    float64
#  6   Current health expenditure per capita, PPP (current international $)                                             891 non-null    float64
#  7   Death rate, crude (per 1,000 people)                                                                             891 non-null    float64
#  8   Diabetes prevalence (% of population ages 20 to 79)                                                              891 non-null    float64
#  9   Domestic general government health expenditure (% of GDP)                                                        891 non-null    float64
#  10  Domestic general government health expenditure per capita, PPP (current international $)                         891 non-null    float64
#  11  Domestic private health expenditure (% of current health expenditure)                                            891 non-null    float64
#  12  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                891 non-null    float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)               891 non-null    float64
#  14  Fertility rate, total (births per woman)                                                                         891 non-null    float64
#  15  GDP, PPP (constant 2017 international $)                                                                         891 non-null    float64
#  16  Gini index                                                                                                       891 non-null    float64
#  17  Government expenditure on education, total (% of GDP)                                                            891 non-null    float64
#  18  Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                               891 non-null    float64
#  19  Life expectancy at birth, female (years)                                                                         891 non-null    float64
#  20  Life expectancy at birth, male (years)                                                                           891 non-null    float64
#  21  Life expectancy at birth, total (years)                                                                          891 non-null    float64
#  22  Literacy rate, adult total (% of people ages 15 and above)                                                       891 non-null    float64
#  23  Mortality rate, adult, female (per 1,000 female adults)                                                          891 non-null    float64
#  24  Mortality rate, adult, male (per 1,000 male adults)                                                              891 non-null    float64
#  25  Mortality rate, infant (per 1,000 live births)                                                                   891 non-null    float64
#  26  Number of neonatal deaths                                                                                        891 non-null    float64
#  27  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                     891 non-null    float64
#  28  People using at least basic sanitation services (% of population)                                                891 non-null    float64
#  29  People using safely managed drinking water services (% of population)                                            891 non-null    float64
#  30  Political Stability and Absence of Violence/Terrorism: Estimate                                                  891 non-null    float64
#  31  Population ages 80 and above, female                                                                             891 non-null    float64
#  32  Population ages 80 and above, male                                                                               891 non-null    float64
#  33  Population density (people per sq. km of land area)                                                              858 non-null    float64
#  34  Population, female                                                                                               891 non-null    float64
#  35  Population, female (% of total population)                                                                       891 non-null    float64
#  36  Population, male                                                                                                 891 non-null    float64
#  37  Population, male (% of total population)                                                                         891 non-null    float64
#  38  Population, total                                                                                                891 non-null    float64
#  39  Poverty gap at $6.85 a day (2017 PPP) (%)                                                                        891 non-null    float64
#  40  Pregnant women receiving prenatal care (%)                                                                       891 non-null    float64
#  41  Prevalence of overweight (% of adults)                                                                           891 non-null    float64
#  42  Prevalence of overweight, weight for height (% of children under 5)                                              891 non-null    float64
#  43  Prevalence of undernourishment (% of population)                                                                 891 non-null    float64
#  44  Rural population (% of total population)                                                                         891 non-null    float64
#  45  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)             891 non-null    float64
#  46  Unemployment, total (% of total labor force) (modeled ILO estimate)                                              891 non-null    float64
#  47  Urban population                                                                                                 891 non-null    float64
#  48  Urban population (% of total population)                                                                         891 non-null    float64
# dtypes: float64(49)
# memory usage: 343.3+ KB

# %%
# Para contar tanto los valores nulos (NaN) como los ceros:
nulos_ceros = df_aggregated_df2_df3.isnull().sum() + (df_aggregated_df2_df3 == 0).sum()

print(nulos_ceros) 
print("(",(nulos_ceros/1122)*100,")%")
# Out:
# Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    815
# Birth rate, crude (per 1,000 people)                                                                                27
# CO2 emissions (kg per PPP $ of GDP)                                                                                 85
# Capital health expenditure (% of GDP)                                                                              401
# Compulsory education, duration (years)                                                                             215
# Control of Corruption: Estimate                                                                                    243
# Current health expenditure per capita, PPP (current international $)                                               321
# Death rate, crude (per 1,000 people)                                                                                27
# Diabetes prevalence (% of population ages 20 to 79)                                                                833
# Domestic general government health expenditure (% of GDP)                                                          321
# Domestic general government health expenditure per capita, PPP (current international $)                           321
# Domestic private health expenditure (% of current health expenditure)                                              321
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  792
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                 601
# Fertility rate, total (births per woman)                                                                            27
# GDP, PPP (constant 2017 international $)                                                                            33
# Gini index                                                                                                         495
# Government expenditure on education, total (% of GDP)                                                              333
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 866
# Life expectancy at birth, female (years)                                                                            27
# Life expectancy at birth, male (years)                                                                              27
# Life expectancy at birth, total (years)                                                                             27
# Literacy rate, adult total (% of people ages 15 and above)                                                         702
# Mortality rate, adult, female (per 1,000 female adults)                                                             28
# Mortality rate, adult, male (per 1,000 male adults)                                                                 28
# Mortality rate, infant (per 1,000 live births)                                                                      27
# Number of neonatal deaths                                                                                           27
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                       569
# People using at least basic sanitation services (% of population)                                                  292
# People using safely managed drinking water services (% of population)                                              553
# Political Stability and Absence of Violence/Terrorism: Estimate                                                    243
# Population ages 80 and above, female                                                                                 0
# Population ages 80 and above, male                                                                                   0
# Population density (people per sq. km of land area)                                                                 59
# Population, female                                                                                                   0
# Population, female (% of total population)                                                                           0
# Population, male                                                                                                     0
# Population, male (% of total population)                                                                             0
# Population, total                                                                                                    0
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                          493
# Pregnant women receiving prenatal care (%)                                                                         711
# Prevalence of overweight (% of adults)                                                                             162
# Prevalence of overweight, weight for height (% of children under 5)                                                734
# Prevalence of undernourishment (% of population)                                                                   391
# Rural population (% of total population)                                                                             0
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)               756
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                 91
# Urban population                                                                                                     0
# Urban population (% of total population)                                                                             0
# dtype: int64
# ( Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    72.638146
# Birth rate, crude (per 1,000 people)                                                                                2.406417
# CO2 emissions (kg per PPP $ of GDP)                                                                                 7.575758
# Capital health expenditure (% of GDP)                                                                              35.739750
# Compulsory education, duration (years)                                                                             19.162210
# Control of Corruption: Estimate                                                                                    21.657754
# Current health expenditure per capita, PPP (current international $)                                               28.609626
# Death rate, crude (per 1,000 people)                                                                                2.406417
# Diabetes prevalence (% of population ages 20 to 79)                                                                74.242424
# Domestic general government health expenditure (% of GDP)                                                          28.609626
# Domestic general government health expenditure per capita, PPP (current international $)                           28.609626
# Domestic private health expenditure (% of current health expenditure)                                              28.609626
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  70.588235
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                 53.565062
# Fertility rate, total (births per woman)                                                                            2.406417
# GDP, PPP (constant 2017 international $)                                                                            2.941176
# Gini index                                                                                                         44.117647
# Government expenditure on education, total (% of GDP)                                                              29.679144
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 77.183601
# Life expectancy at birth, female (years)                                                                            2.406417
# Life expectancy at birth, male (years)                                                                              2.406417
# Life expectancy at birth, total (years)                                                                             2.406417
# Literacy rate, adult total (% of people ages 15 and above)                                                         62.566845
# Mortality rate, adult, female (per 1,000 female adults)                                                             2.495544
# Mortality rate, adult, male (per 1,000 male adults)                                                                 2.495544
# Mortality rate, infant (per 1,000 live births)                                                                      2.406417
# Number of neonatal deaths                                                                                           2.406417
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                       50.713012
# People using at least basic sanitation services (% of population)                                                  26.024955
# People using safely managed drinking water services (% of population)                                              49.286988
# Political Stability and Absence of Violence/Terrorism: Estimate                                                    21.657754
# Population ages 80 and above, female                                                                                0.000000
# Population ages 80 and above, male                                                                                  0.000000
# Population density (people per sq. km of land area)                                                                 5.258467
# Population, female                                                                                                  0.000000
# Population, female (% of total population)                                                                          0.000000
# Population, male                                                                                                    0.000000
# Population, male (% of total population)                                                                            0.000000
# Population, total                                                                                                   0.000000
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                          43.939394
# Pregnant women receiving prenatal care (%)                                                                         63.368984
# Prevalence of overweight (% of adults)                                                                             14.438503
# Prevalence of overweight, weight for height (% of children under 5)                                                65.418895
# Prevalence of undernourishment (% of population)                                                                   34.848485
# Rural population (% of total population)                                                                            0.000000
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)               67.379679
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                 8.110517
# Urban population                                                                                                    0.000000
# Urban population (% of total population)                                                                            0.000000
# dtype: float64 )%

# %%
nulos_ceros.head(50)
# Out:
# Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    815
# Birth rate, crude (per 1,000 people)                                                                                27
# CO2 emissions (kg per PPP $ of GDP)                                                                                 85
# Capital health expenditure (% of GDP)                                                                              401
# Compulsory education, duration (years)                                                                             215
# Control of Corruption: Estimate                                                                                    243
# Current health expenditure per capita, PPP (current international $)                                               321
# Death rate, crude (per 1,000 people)                                                                                27
# Diabetes prevalence (% of population ages 20 to 79)                                                                833
# Domestic general government health expenditure (% of GDP)                                                          321
# Domestic general government health expenditure per capita, PPP (current international $)                           321
# Domestic private health expenditure (% of current health expenditure)                                              321
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  792
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                 601
# Fertility rate, total (births per woman)                                                                            27
# GDP, PPP (constant 2017 international $)                                                                            33
# Gini index                                                                                                         495
# Government expenditure on education, total (% of GDP)                                                              333
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 866
# Life expectancy at birth, female (years)                                                                            27
# Life expectancy at birth, male (years)                                                                              27
# Life expectancy at birth, total (years)                                                                             27
# Literacy rate, adult total (% of people ages 15 and above)                                                         702
# Mortality rate, adult, female (per 1,000 female adults)                                                             28
# Mortality rate, adult, male (per 1,000 male adults)                                                                 28
# Mortality rate, infant (per 1,000 live births)                                                                      27
# Number of neonatal deaths                                                                                           27
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                       569
# People using at least basic sanitation services (% of population)                                                  292
# People using safely managed drinking water services (% of population)                                              553
# Political Stability and Absence of Violence/Terrorism: Estimate                                                    243
# Population ages 80 and above, female                                                                                 0
# Population ages 80 and above, male                                                                                   0
# Population density (people per sq. km of land area)                                                                 59
# Population, female                                                                                                   0
# Population, female (% of total population)                                                                           0
# Population, male                                                                                                     0
# Population, male (% of total population)                                                                             0
# Population, total                                                                                                    0
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                          493
# Pregnant women receiving prenatal care (%)                                                                         711
# Prevalence of overweight (% of adults)                                                                             162
# Prevalence of overweight, weight for height (% of children under 5)                                                734
# Prevalence of undernourishment (% of population)                                                                   391
# Rural population (% of total population)                                                                             0
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)               756
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                 91
# Urban population                                                                                                     0
# Urban population (% of total population)                                                                             0
# dtype: int64

# %%
# Eliminamos columnas que tienen más de 65% de nulos de la base del BM
#Tomamos nota de las variables qeu eliminamos, para tomarls de fuenes externas
#Dejamos aún algunas columnas que tiene muchos nulos evidentes, y dejamos aquellos que podrían mejorar luego de la limpieza de datos.
# Lista de palabras clave para las columnas a eliminar
palabras_a_eliminar = [
    "Account ownership",
    "Educational attainment,",
    "Educational attainment,",
    "Infant and young",
    "Literacy rate,",
    "pure alcohol"
]

# Encuentra y elimina las columnas que contienen alguna de las palabras clave
columnas_a_eliminar = [col for col in df_aggregated_df2_df3.columns if any(palabra in col for palabra in palabras_a_eliminar)]
df_filtrado_nulos = df_aggregated_df2_df3.drop(columns=columnas_a_eliminar)

# %%
#Eliminar Columna indicador Diabetes en niños

columna_a_eliminar = next((col for col in df_filtrado_nulos.columns if col.startswith("Diabetes prevalence") and "child" in col), None)

if columna_a_eliminar is not None:
    df_filtrado_nulos = df_filtrado_nulos.drop(columns=columna_a_eliminar)

# %%
df_filtrado_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 891 entries, ('Antigua and Barbuda', 1990) to ('Uruguay', 2022)
# Data columns (total 43 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                          891 non-null    float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                           891 non-null    float64
#  2   Capital health expenditure (% of GDP)                                                         891 non-null    float64
#  3   Compulsory education, duration (years)                                                        891 non-null    float64
#  4   Control of Corruption: Estimate                                                               891 non-null    float64
#  5   Current health expenditure per capita, PPP (current international $)                          891 non-null    float64
#  6   Death rate, crude (per 1,000 people)                                                          891 non-null    float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                           891 non-null    float64
#  8   Domestic general government health expenditure (% of GDP)                                     891 non-null    float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)      891 non-null    float64
#  10  Domestic private health expenditure (% of current health expenditure)                         891 non-null    float64
#  11  Fertility rate, total (births per woman)                                                      891 non-null    float64
#  12  GDP, PPP (constant 2017 international $)                                                      891 non-null    float64
#  13  Gini index                                                                                    891 non-null    float64
#  14  Government expenditure on education, total (% of GDP)                                         891 non-null    float64
#  15  Life expectancy at birth, female (years)                                                      891 non-null    float64
#  16  Life expectancy at birth, male (years)                                                        891 non-null    float64
#  17  Life expectancy at birth, total (years)                                                       891 non-null    float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                       891 non-null    float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                           891 non-null    float64
#  20  Mortality rate, infant (per 1,000 live births)                                                891 non-null    float64
#  21  Number of neonatal deaths                                                                     891 non-null    float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)  891 non-null    float64
#  23  People using at least basic sanitation services (% of population)                             891 non-null    float64
#  24  People using safely managed drinking water services (% of population)                         891 non-null    float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                               891 non-null    float64
#  26  Population ages 80 and above, female                                                          891 non-null    float64
#  27  Population ages 80 and above, male                                                            891 non-null    float64
#  28  Population density (people per sq. km of land area)                                           858 non-null    float64
#  29  Population, female                                                                            891 non-null    float64
#  30  Population, female (% of total population)                                                    891 non-null    float64
#  31  Population, male                                                                              891 non-null    float64
#  32  Population, male (% of total population)                                                      891 non-null    float64
#  33  Population, total                                                                             891 non-null    float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                     891 non-null    float64
#  35  Pregnant women receiving prenatal care (%)                                                    891 non-null    float64
#  36  Prevalence of overweight (% of adults)                                                        891 non-null    float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                           891 non-null    float64
#  38  Prevalence of undernourishment (% of population)                                              891 non-null    float64
#  39  Rural population (% of total population)                                                      891 non-null    float64
#  40  Unemployment, total (% of total labor force) (modeled ILO estimate)                           891 non-null    float64
#  41  Urban population                                                                              891 non-null    float64
#  42  Urban population (% of total population)                                                      891 non-null    float64
# dtypes: float64(43)
# memory usage: 301.5+ KB

# %%
#La base de datos mantiene aún muchos nulos en datos de países de las islas del Caribe.
#Para aumentar la calidad de los datos, vamos a quitar del análisis los países con una población menor a 2 millones de personas, que básicamente son las islas mencionadas más pequeñas.
#Umbral = 2000000





# Define un umbral de población (2 millones en este caso)
umbral_población = 2000000

# Filtra los países con población mayor al umbral
df_filtrado_nulos_Sin_Caribe = df_filtrado_nulos.groupby('País').filter(lambda x: x['Population, total'].max() > umbral_población)

# %%
df_filtrado_nulos_Sin_Caribe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 759 entries, ('Argentina', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 44 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                                   759 non-null    float64
#  2   Capital health expenditure (% of GDP)                                                                 759 non-null    float64
#  3   Compulsory education, duration (years)                                                                759 non-null    float64
#  4   Control of Corruption: Estimate                                                                       759 non-null    float64
#  5   Current health expenditure per capita, PPP (current international $)                                  759 non-null    float64
#  6   Death rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                                   759 non-null    float64
#  8   Domestic general government health expenditure (% of GDP)                                             759 non-null    float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)              759 non-null    float64
#  10  Domestic private health expenditure (% of current health expenditure)                                 759 non-null    float64
#  11  Fertility rate, total (births per woman)                                                              759 non-null    float64
#  12  GDP, PPP (constant 2017 international $)                                                              759 non-null    float64
#  13  Gini index                                                                                            759 non-null    float64
#  14  Government expenditure on education, total (% of GDP)                                                 759 non-null    float64
#  15  Life expectancy at birth, female (years)                                                              759 non-null    float64
#  16  Life expectancy at birth, male (years)                                                                759 non-null    float64
#  17  Life expectancy at birth, total (years)                                                               759 non-null    float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                               759 non-null    float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                                   759 non-null    float64
#  20  Mortality rate, infant (per 1,000 live births)                                                        759 non-null    float64
#  21  Number of neonatal deaths                                                                             759 non-null    float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)          759 non-null    float64
#  23  People using at least basic sanitation services (% of population)                                     759 non-null    float64
#  24  People using safely managed drinking water services (% of population)                                 759 non-null    float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                                       759 non-null    float64
#  26  Population ages 80 and above, female                                                                  759 non-null    float64
#  27  Population ages 80 and above, male                                                                    759 non-null    float64
#  28  Population density (people per sq. km of land area)                                                   759 non-null    float64
#  29  Population, female                                                                                    759 non-null    float64
#  30  Population, female (% of total population)                                                            759 non-null    float64
#  31  Population, male                                                                                      759 non-null    float64
#  32  Population, male (% of total population)                                                              759 non-null    float64
#  33  Population, total                                                                                     759 non-null    float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                             759 non-null    float64
#  35  Pregnant women receiving prenatal care (%)                                                            759 non-null    float64
#  36  Prevalence of overweight (% of adults)                                                                759 non-null    float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                                   759 non-null    float64
#  38  Prevalence of undernourishment (% of population)                                                      759 non-null    float64
#  39  Rural population (% of total population)                                                              759 non-null    float64
#  40  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  759 non-null    float64
#  41  Unemployment, total (% of total labor force) (modeled ILO estimate)                                   759 non-null    float64
#  42  Urban population                                                                                      759 non-null    float64
#  43  Urban population (% of total population)                                                              759 non-null    float64
# dtypes: float64(44)
# memory usage: 264.1+ KB

# %%
df_filtrado_nulos_Sin_Caribe.head()
# Out:
# Indicador       Birth rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                87.956
#           1991                                87.376
#           1992                                86.732
#           1993                                86.280
#           1994                                85.676
#
# Indicador       CO2 emissions (kg per PPP $ of GDP)  \
# País      Año
# Argentina 1990                             1.711437
#           1991                             1.601483
#           1992                             1.478251
#           1993                             1.363379
#           1994                             1.280178
#
# Indicador       Capital health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                    0.0
#           1991                                    0.0
#           1992                                    0.0
#           1993                                    0.0
#           1994                                    0.0
#
# Indicador       Compulsory education, duration (years)  \
# País      Año
# Argentina 1990                                     0.0
#           1991                                     0.0
#           1992                                     0.0
#           1993                                     0.0
#           1994                                     0.0
#
# Indicador       Control of Corruption: Estimate  \
# País      Año
# Argentina 1990                              0.0
#           1991                              0.0
#           1992                              0.0
#           1993                              0.0
#           1994                              0.0
#
# Indicador       Current health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Death rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                30.972
#           1991                                30.144
#           1992                                30.380
#           1993                                30.524
#           1994                                29.612
#
# Indicador       Diabetes prevalence (% of population ages 20 to 79)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       ...  Population, total  \
# País      Año   ...
# Argentina 1990  ...        130550628.0
#           1991  ...        132423052.0
#           1992  ...        134273140.0
#           1993  ...        136108960.0
#           1994  ...        137954784.0
#
# Indicador       Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País      Año
# Argentina 1990                                        0.0
#           1991                                       18.0
#           1992                                       20.0
#           1993                                       22.0
#           1994                                       22.8
#
# Indicador       Pregnant women receiving prenatal care (%)  \
# País      Año
# Argentina 1990                                         0.0
#           1991                                         0.0
#           1992                                         0.0
#           1993                                       380.0
#           1994                                         0.0
#
# Indicador       Prevalence of overweight (% of adults)  \
# País      Año
# Argentina 1990                                   194.8
#           1991                                   197.2
#           1992                                   199.6
#           1993                                   202.0
#           1994                                   204.4
#
# Indicador       Prevalence of overweight, weight for height (% of children under 5)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                               44.4
#
# Indicador       Prevalence of undernourishment (% of population)  \
# País      Año
# Argentina 1990                                               0.0
#           1991                                               0.0
#           1992                                               0.0
#           1993                                               0.0
#           1994                                               0.0
#
# Indicador       Rural population (% of total population)  \
# País      Año
# Argentina 1990                                    52.064
#           1991                                    50.688
#           1992                                    49.832
#           1993                                    48.992
#           1994                                    48.160
#
# Indicador       Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País      Año
# Argentina 1990                                               0.00
#           1991                                              21.76
#           1992                                              25.44
#           1993                                              40.40
#           1994                                              47.04
#
# Indicador       Urban population  Urban population (% of total population)
# País      Año
# Argentina 1990       113558160.0                                   347.936
#           1991       115642404.0                                   349.312
#           1992       117545392.0                                   350.168
#           1993       119438336.0                                   351.008
#           1994       121345028.0                                   351.840
#
# [5 rows x 43 columns]

# %%
# Especifica el nombre del archivo CSV sin la ruta completa
nombre_archivo_csv = 'Tabla_sin_caribe.csv'

# Exporta el DataFrame a un archivo CSV en la misma carpeta
df_filtrado_nulos_Sin_Caribe.to_csv(nombre_archivo_csv)
