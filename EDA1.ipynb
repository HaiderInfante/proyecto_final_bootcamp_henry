# %% [markdown]
# ETL. Extracción y transformación
# EDA. Análisis preliminar de calidad de datos

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# Como el objetivo principal del trabajo es analizar cúales con los factores socioeconómicos que más inciden en la Eperanza de Vida de los (35) países de que integran la OEA (Organización de Estados Americanos), nos vamos vamos a focalizar en buscar indicadores que tengan que ver con el desarrollo económico y el crecimiento de los países.
# Como fuente de datos, nos vamos a nutrir de las bases de datos del World Bank y de base de datos externas de otros organismos internacionales especializados en desarrollo.
# Vamos a poceder a extrer los datos de la base del Banco Mundial utilizando la API que provee el WB.
# Creamos un código para poder extraer los distintos indicadores potenciales para ser analizados, de las distintas bases de datos que se elojan en el sitio del organismo internacional. Las principales bases de datos utilizadas del BM son World Economic Indicators(WEI) y Health & Nutrition indicators.
# El análisis preliminar nos permite hacer un corte en los datos, que se tomarán datos a partir de 1990, debido a al aumento de la disponibilidad de la data del WB y la externa al WB (aún a definir?).
# Elegimos a priori aproximadamente 50 indicadores, según los grandes temas o tópicos de las bases del BM que tienen que ver con factores socioeconómicos que más inciden en la esperanza de vida, y luego apoyados en base a literatura especializada en el tema. (Fuente)
# Al analizar los indicadores prelimminarmente, advertimos que hay variables que podrían enriquecer nuestros análisis, pero que si bien existen en la base de datos del BM, hay muchos nulos y la calidad por tanto no es buena. Dedicimos usar bases de datos externas para aumentar la calidad de los datos, y contar con indicadores confiables en hábitos como consumo de Tabaco, Obesidaud, y gasto publico social de los gobiernos.
# Bases de datos externas utilizadas:  Cepal, Naciones Unidas

# %%
#Etracción de Metadata para extraer luego los datos de cógidos de países e indicadores necesarios
# 50 indicadores

# %%
#Código para extraer los datos con la API del WB
#particionamos la información de los países e indicadores para realizar la extracción
# Países de la OEA
countries = ["USA",
    "ATG",
    "ARG",
    "BHS",
    "BRB",
    "BLZ",
    
]


# Indicadores elegidos luego de consultar las distintas base de datos en desarrollo y crecimiento del WB

indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años deseados para extraer los datos
#En base analisis preliminares y a la disponibildiad de las series de tiempo de lo indicadores, 
# optamos por tomar la data a partir de 1990, cuando comienza a aumentar la cantidad de datos 
# relacionados con el desarrollo
#Vamos a bajar los datos en distintos dataframes que luego se van a concatenar para unificarlo en un dataset
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df0 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df0
# Out:
#                País                                          Indicador   Año  \
# 0     United States  Account ownership at a financial institution o...  2022
# 1     United States  Account ownership at a financial institution o...  2021
# 2     United States  Account ownership at a financial institution o...  2020
# 3     United States  Account ownership at a financial institution o...  2019
# 4     United States  Account ownership at a financial institution o...  2018
# ...             ...                                                ...   ...
# 9697         Belize  Total alcohol consumption per capita (liters o...  1994
# 9698         Belize  Total alcohol consumption per capita (liters o...  1993
# 9699         Belize  Total alcohol consumption per capita (liters o...  1992
# 9700         Belize  Total alcohol consumption per capita (liters o...  1991
# 9701         Belize  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1     94.95
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
#Continuamos con la extraccion extracción de datos de los países
countries = ["CAN",
    "CHL",
    "COL",
    "CRI",
    "CUB",
    "DOM",
    "ECU"]
    
    

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df
# Out:
#           País                                          Indicador   Año  Valor
# 0       Canada  Account ownership at a financial institution o...  2022    NaN
# 1       Canada  Account ownership at a financial institution o...  2021  99.63
# 2       Canada  Account ownership at a financial institution o...  2020    NaN
# 3       Canada  Account ownership at a financial institution o...  2019    NaN
# 4       Canada  Account ownership at a financial institution o...  2018    NaN
# ...        ...                                                ...   ...    ...
# 11314  Ecuador  Total alcohol consumption per capita (liters o...  1994    NaN
# 11315  Ecuador  Total alcohol consumption per capita (liters o...  1993    NaN
# 11316  Ecuador  Total alcohol consumption per capita (liters o...  1992    NaN
# 11317  Ecuador  Total alcohol consumption per capita (liters o...  1991    NaN
# 11318  Ecuador  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [11319 rows x 4 columns]

# %%
#Continuamos con el mismo proceso
countries = [
    "GRD",
    "GTM",
    "GUY",
    "HTI",
    "HND",
    "JAM" ]
# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df_a = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df_a
# Out:
#          País                                          Indicador   Año  Valor
# 0     Grenada  Account ownership at a financial institution o...  2022    NaN
# 1     Grenada  Account ownership at a financial institution o...  2021    NaN
# 2     Grenada  Account ownership at a financial institution o...  2020    NaN
# 3     Grenada  Account ownership at a financial institution o...  2019    NaN
# 4     Grenada  Account ownership at a financial institution o...  2018    NaN
# ...       ...                                                ...   ...    ...
# 9697  Jamaica  Total alcohol consumption per capita (liters o...  1994    NaN
# 9698  Jamaica  Total alcohol consumption per capita (liters o...  1993    NaN
# 9699  Jamaica  Total alcohol consumption per capita (liters o...  1992    NaN
# 9700  Jamaica  Total alcohol consumption per capita (liters o...  1991    NaN
# 9701  Jamaica  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [9702 rows x 4 columns]

# %%
#Sigue la lista de países para exraer la data ...
countries = [ 
             "BOL", "BRA", "PER", "DOM", "KNA", "SLV"
             ]
# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años elegidos 
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df1 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df1
# Out:
#              País                                          Indicador   Año  \
# 0         Bolivia  Account ownership at a financial institution o...  2022
# 1         Bolivia  Account ownership at a financial institution o...  2021
# 2         Bolivia  Account ownership at a financial institution o...  2020
# 3         Bolivia  Account ownership at a financial institution o...  2019
# 4         Bolivia  Account ownership at a financial institution o...  2018
# ...           ...                                                ...   ...
# 9697  El Salvador  Total alcohol consumption per capita (liters o...  1994
# 9698  El Salvador  Total alcohol consumption per capita (liters o...  1993
# 9699  El Salvador  Total alcohol consumption per capita (liters o...  1992
# 9700  El Salvador  Total alcohol consumption per capita (liters o...  1991
# 9701  El Salvador  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1     68.89
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
#Sigue la lista de países para exraer la data ...
countries = [
    "MEX", "NIC", "PAN", "PRY" 
]


# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]

# Años elegidos 
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df2 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df2
# Out:
#           País                                          Indicador   Año  Valor
# 0       Mexico  Account ownership at a financial institution o...  2022  48.97
# 1       Mexico  Account ownership at a financial institution o...  2021    NaN
# 2       Mexico  Account ownership at a financial institution o...  2020    NaN
# 3       Mexico  Account ownership at a financial institution o...  2019    NaN
# 4       Mexico  Account ownership at a financial institution o...  2018    NaN
# ...        ...                                                ...   ...    ...
# 6463  Paraguay  Total alcohol consumption per capita (liters o...  1994    NaN
# 6464  Paraguay  Total alcohol consumption per capita (liters o...  1993    NaN
# 6465  Paraguay  Total alcohol consumption per capita (liters o...  1992    NaN
# 6466  Paraguay  Total alcohol consumption per capita (liters o...  1991    NaN
# 6467  Paraguay  Total alcohol consumption per capita (liters o...  1990    NaN
#
# [6468 rows x 4 columns]

# %%
#Ultima extracción de data para analizar los países que integran la OEA
countries =[ "LCA", "VCT", "SUR", "TTO", "URY", "VEN"  ]

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS",
      "EN.POP.DNST",
"SP.DYN.LE00.MA.IN",
"SH.STA.ANVC.ZS",
"SN.ITK.DEFC.ZS",
"SH.STA.DIAB.ZS",
"SH.ALC.PCAP.LI"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df3 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df3
# Out:
#                País                                          Indicador   Año  \
# 0         St. Lucia  Account ownership at a financial institution o...  2022
# 1         St. Lucia  Account ownership at a financial institution o...  2021
# 2         St. Lucia  Account ownership at a financial institution o...  2020
# 3         St. Lucia  Account ownership at a financial institution o...  2019
# 4         St. Lucia  Account ownership at a financial institution o...  2018
# ...             ...                                                ...   ...
# 9697  Venezuela, RB  Total alcohol consumption per capita (liters o...  1994
# 9698  Venezuela, RB  Total alcohol consumption per capita (liters o...  1993
# 9699  Venezuela, RB  Total alcohol consumption per capita (liters o...  1992
# 9700  Venezuela, RB  Total alcohol consumption per capita (liters o...  1991
# 9701  Venezuela, RB  Total alcohol consumption per capita (liters o...  1990
#
#       Valor
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 9697    NaN
# 9698    NaN
# 9699    NaN
# 9700    NaN
# 9701    NaN
#
# [9702 rows x 4 columns]

# %%
# Unificamos los dataframes
concatenated_df2 = pd.concat([data_df0, data_df, data_df1, data_df3, data_df2, data_df_a], ignore_index=True)

# El argumento 'ignore_index=True' restablece los índices de fila para que sean secuenciales.

# Ahora 'concatenated_df' contiene todos los datos de los tres DataFrames.

# %%
concatenated_df2
# Out:
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 56590        Jamaica  Total alcohol consumption per capita (liters o...  1994
# 56591        Jamaica  Total alcohol consumption per capita (liters o...  1993
# 56592        Jamaica  Total alcohol consumption per capita (liters o...  1992
# 56593        Jamaica  Total alcohol consumption per capita (liters o...  1991
# 56594        Jamaica  Total alcohol consumption per capita (liters o...  1990
#
#        Valor
# 0        NaN
# 1      94.95
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 56590    NaN
# 56591    NaN
# 56592    NaN
# 56593    NaN
# 56594    NaN
#
# [56595 rows x 4 columns]

# %%
concatenated_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56595 entries, 0 to 56594
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       56595 non-null  object
#  1   Indicador  56595 non-null  object
#  2   Año        56595 non-null  object
#  3   Valor      39436 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ MB

# %%
#Agregamos data de unos indicadores Obesidad, Gasto publico social, y Consumo de Tabado,  de base de datos externna
#Falta codigo para extraer base de datos eternas
#preliminarmente subimos lso cvs.
archivo1_csv = 'obesidad.csv'
archivo2_csv = "consumo_tabaco (1).csv"
archivo3_csv = "gasto_social.csv"

# Cargar el archivo CSV en un DataFrame
data_df5 = pd.read_csv(archivo1_csv)
data_df6 = pd.read_csv(archivo2_csv)
data_df7 = pd.read_csv(archivo3_csv)

# %%
data_df5 = data_df5.reset_index(drop=True)
data_df6 = data_df6.reset_index(drop=True)
data_df7 = data_df7.reset_index(drop=True)

# %%
#unificamos datafraames de fuentes externas , para Tabaco, Obesidad y Gasto público social
concatenated_df3 = pd.concat([data_df5, data_df6, data_df7], ignore_index=True)

# %%
concatenated_df3.head()
# Out:
#                Country   Año  \
# 0  Antigua and Barbuda  1990
# 1  Antigua and Barbuda  1991
# 2  Antigua and Barbuda  1992
# 3  Antigua and Barbuda  1993
# 4  Antigua and Barbuda  1994
#
#    Proportion of adults who are obese, 20 years old and over ,by sex  \
# 0                                                8.6
# 1                                                8.9
# 2                                                9.2
# 3                                                9.6
# 4                                                9.9
#
#    Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Gasto público social según la clasificación por funciones del gobierno
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
#Cambiar nombre columna de "Country" a "País"

# Cambiar el nombre de la columna 'Año'
concatenated_df3 = concatenated_df3.rename(columns={'Country': 'País'})

# %%
concatenated_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56595 entries, 0 to 56594
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       56595 non-null  object
#  1   Indicador  56595 non-null  object
#  2   Año        56595 non-null  object
#  3   Valor      39436 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ MB

# %%
concatenated_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3947 entries, 0 to 3946
# Data columns (total 5 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   País                                                                                              3947 non-null   object
#  1   Año                                                                                               3947 non-null   int64
#  2   Proportion of adults who are obese, 20 years old and over ,by sex                                 2835 non-null   float64
#  3   Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex  504 non-null    float64
#  4   Gasto público social según la clasificación por funciones del gobierno                            608 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 154.3+ KB

# %%
#Revisar este codigo

# Crear la columna "Indicador" combinando las tres columnas específicas
concatenated_df3["Indicador"] = concatenated_df3[["Proportion of adults who are obese, 20 years old and over ,by sex", "Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex", "Gasto público social según la clasificación por funciones del gobierno"]].astype(str).apply(lambda x: ' '.join(x.dropna()), axis=1)

# Seleccionar solo las columnas que necesitas de concatenated_df3
concatenated_df3 = concatenated_df3[["Country", "Año", "Indicador", "Valor"]]

# Restablecer los índices antes de la concatenación
concatenated_df2.reset_index(drop=True, inplace=True)
columnas_necesarias.reset_index(drop=True, inplace=True)

# Concatenar concatenated_df2 y columnas_necesarias
concatenated_df2_df3 = pd.concat([concatenated_df2, concatenated_df3], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\maral\Desktop\PF_DS\EDA1.ipynb Celda 24 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/maral/Desktop/PF_DS/EDA1.ipynb#X66sZmlsZQ%3D%3D?line=3'>4</a> concatenated_df3["Indicador"] = concatenated_df3[["Proportion of adults who are obese, 20 years old and over ,by sex", "Age-standardized prevalence of current tobacco use among persons aged 15 years and older, by sex", "Gasto público social según la clasificación por funciones del gobierno"]].astype(str).apply(lambda x: ' '.join(x.dropna()), axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/maral/Desktop/PF_DS/EDA1.ipynb#X66sZmlsZQ%3D%3D?line=5'>6</a> # Seleccionar solo las columnas que necesitas de concatenated_df3
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maral/Desktop/PF_DS/EDA1.ipynb#X66sZmlsZQ%3D%3D?line=6'>7</a> concatenated_df3 = concatenated_df3[["Country", "Año", "Indicador", "Valor"]]
#       <a href='vscode-notebook-cell:/c%3A/Users/maral/Desktop/PF_DS/EDA1.ipynb#X66sZmlsZQ%3D%3D?line=8'>9</a> # Restablecer los índices antes de la concatenación
#      <a href='vscode-notebook-cell:/c%3A/Users/maral/Desktop/PF_DS/EDA1.ipynb#X66sZmlsZQ%3D%3D?line=9'>10</a> concatenated_df2.reset_index(drop=True, inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Country', 'Valor'] not in index"

# %%
concatenated_df2_df3
# Out:
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 66292  Venezuela, RB  Total alcohol consumption per capita (liters o...  1994
# 66293  Venezuela, RB  Total alcohol consumption per capita (liters o...  1993
# 66294  Venezuela, RB  Total alcohol consumption per capita (liters o...  1992
# 66295  Venezuela, RB  Total alcohol consumption per capita (liters o...  1991
# 66296  Venezuela, RB  Total alcohol consumption per capita (liters o...  1990
#
#        Valor
# 0        NaN
# 1      94.95
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 66292    NaN
# 66293    NaN
# 66294    NaN
# 66295    NaN
# 66296    NaN
#
# [66297 rows x 4 columns]

# %%
#Vemos la estructura de variables y filas
#Observamos que hay muchos nulos en la columna de los vaores numericos, que haya que analiza en detalle
concatenated_df2_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66297 entries, 0 to 66296
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       66297 non-null  object
#  1   Indicador  66297 non-null  object
#  2   Año        66297 non-null  object
#  3   Valor      45940 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ MB

# %%
#Vamos a agrupar los indicadores por países y por año 
# 1. Cambia el tipo de dato de la columna 'Año' a numérico (int)
concatenated_df2_df3['Año'] = pd.to_numeric(concatenated_df2_df3['Año'], errors='coerce')

# 2. Realiza una agregación (por ejemplo, suma) en caso de entradas duplicadas
df_aggregated_df2_df3 = concatenated_df2_df3.groupby(['País', 'Año', 'Indicador'])['Valor'].sum().unstack()

# Esto creará un nuevo DataFrame 'df_aggregated' con cada indicador como una columna individual y las entradas duplicadas se agregan mediante la suma (Ver concepto).

# %%
#Exportamos la tabla final de datos crudos a un csv 
nombre_del_archivo = 'df_aggregated_df2_df3.csv'
df_aggregated_df2_df3.to_csv(nombre_del_archivo, index=False)

# %%
#Verifico que la concatenacion esté correcta

# Concatenar DataFrames verticalmente (incorrecto en este caso)
concatenated_df2_df3 = pd.concat([df2, df3], axis=0)

# Verificar las dimensiones después de la concatenación
expected_shape = (df1.shape[0] + df2.shape[0], max(df1.shape[1], df2.shape[1]))
if concatenated_df.shape == expected_shape:
    print("Dimensiones correctas después de la concatenación.")
else:
    print("Dimensiones incorrectas después de la concatenación.")

# Verificar las columnas después de la concatenación
expected_columns = df1.columns.union(df2.columns)
if concatenated_df.columns.equals(expected_columns):
    print("Columnas correctas después de la concatenación.")
else:
    print("Columnas incorrectas después de la concatenación.")

# %%
#Tabla de indicadores por países y año

df_aggregated_df2_df3
# Out:
# Indicador                 Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# País                Año
# Antigua and Barbuda 1990                                               0.00
#                     1991                                               0.00
#                     1992                                               0.00
#                     1993                                               0.00
#                     1994                                               0.00
# ...                                                                     ...
# Venezuela, RB       2018                                               0.00
#                     2019                                               0.00
#                     2020                                               0.00
#                     2021                                             168.78
#                     2022                                               0.00
#
# Indicador                 Birth rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                20.916
#                     1991                                18.504
#                     1992                                19.228
#                     1993                                18.597
#                     1994                                18.990
# ...                                                        ...
# Venezuela, RB       2018                                35.664
#                     2019                                33.776
#                     2020                                32.426
#                     2021                                31.754
#                     2022                                 0.000
#
# Indicador                 CO2 emissions (kg per PPP $ of GDP)  \
# País                Año
# Antigua and Barbuda 1990                             0.301290
#                     1991                             0.289409
#                     1992                             0.276056
#                     1993                             0.260243
#                     1994                             0.242297
# ...                                                       ...
# Venezuela, RB       2018                             0.000000
#                     2019                             0.000000
#                     2020                             0.000000
#                     2021                             0.000000
#                     2022                             0.000000
#
# Indicador                 Capital health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                    0.0
#                     1991                                    0.0
#                     1992                                    0.0
#                     1993                                    0.0
#                     1994                                    0.0
# ...                                                         ...
# Venezuela, RB       2018                                    0.0
#                     2019                                    0.0
#                     2020                                    0.0
#                     2021                                    0.0
#                     2022                                    0.0
#
# Indicador                 Compulsory education, duration (years)  \
# País                Año
# Antigua and Barbuda 1990                                     0.0
#                     1991                                     0.0
#                     1992                                     0.0
#                     1993                                     0.0
#                     1994                                     0.0
# ...                                                          ...
# Venezuela, RB       2018                                    34.0
#                     2019                                    34.0
#                     2020                                    34.0
#                     2021                                    34.0
#                     2022                                     0.0
#
# Indicador                 Control of Corruption: Estimate  \
# País                Año
# Antigua and Barbuda 1990                         0.000000
#                     1991                         0.000000
#                     1992                         0.000000
#                     1993                         0.000000
#                     1994                         0.000000
# ...                                                   ...
# Venezuela, RB       2018                        -3.024075
#                     2019                        -3.055198
#                     2020                        -3.152036
#                     2021                        -3.244983
#                     2022                        -3.302274
#
# Indicador                 Current health expenditure per capita, PPP (current international $)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Venezuela, RB       2018                                        1277.226835
#                     2019                                         938.268572
#                     2020                                        1180.238466
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 Death rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                 7.666
#                     1991                                 7.753
#                     1992                                 7.745
#                     1993                                 7.666
#                     1994                                 7.533
# ...                                                        ...
# Venezuela, RB       2018                                13.728
#                     2019                                14.034
#                     2020                                15.150
#                     2021                                16.248
#                     2022                                 0.000
#
# Indicador                 Diabetes prevalence (% of population ages 20 to 79)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Venezuela, RB       2018                                                0.0
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                               19.2
#                     2022                                                0.0
#
# Indicador                 Domestic general government health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Venezuela, RB       2018                                           2.491263
#                     2019                                           1.623506
#                     2020                                           3.353269
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País                Año   ...
# Antigua and Barbuda 1990  ...                                        0.0
#                     1991  ...                                        0.0
#                     1992  ...                                        0.0
#                     1993  ...                                        0.0
#                     1994  ...                                        0.0
# ...                       ...                                        ...
# Venezuela, RB       2018  ...                                        0.0
#                     2019  ...                                        0.0
#                     2020  ...                                        0.0
#                     2021  ...                                        0.0
#                     2022  ...                                        0.0
#
# Indicador                 Pregnant women receiving prenatal care (%)  \
# País                Año
# Antigua and Barbuda 1990                                         0.0
#                     1991                                         0.0
#                     1992                                         0.0
#                     1993                                         0.0
#                     1994                                         0.0
# ...                                                              ...
# Venezuela, RB       2018                                         0.0
#                     2019                                         0.0
#                     2020                                         0.0
#                     2021                                         0.0
#                     2022                                         0.0
#
# Indicador                 Prevalence of overweight (% of adults)  \
# País                Año
# Antigua and Barbuda 1990                                    33.7
#                     1991                                    34.4
#                     1992                                    34.9
#                     1993                                    35.5
#                     1994                                    36.1
# ...                                                          ...
# Venezuela, RB       2018                                     0.0
#                     2019                                     0.0
#                     2020                                     0.0
#                     2021                                     0.0
#                     2022                                     0.0
#
# Indicador                 Prevalence of overweight, weight for height (% of children under 5)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Venezuela, RB       2018                                                0.0
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                                0.0
#                     2022                                                0.0
#
# Indicador                 Prevalence of undernourishment (% of population)  \
# País                Año
# Antigua and Barbuda 1990                                               0.0
#                     1991                                               0.0
#                     1992                                               0.0
#                     1993                                               0.0
#                     1994                                               0.0
# ...                                                                    ...
# Venezuela, RB       2018                                              45.4
#                     2019                                              49.8
#                     2020                                              45.8
#                     2021                                               0.0
#                     2022                                               0.0
#
# Indicador                 Rural population (% of total population)  \
# País                Año
# Antigua and Barbuda 1990                                    64.574
#                     1991                                    64.535
#                     1992                                    64.915
#                     1993                                    65.291
#                     1994                                    65.666
# ...                                                            ...
# Venezuela, RB       2018                                    23.584
#                     2019                                    23.520
#                     2020                                    23.442
#                     2021                                    23.350
#                     2022                                    23.244
#
# Indicador                 Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País                Año
# Antigua and Barbuda 1990                                             0.0000
#                     1991                                             0.0000
#                     1992                                             0.0000
#                     1993                                             0.0000
#                     1994                                             0.0000
# ...                                                                     ...
# Venezuela, RB       2018                                             0.0000
#                     2019                                             6.0325
#                     2020                                             0.0000
#                     2021                                             0.0000
#                     2022                                             0.0000
#
# Indicador                 Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País                Año
# Antigua and Barbuda 1990                                              0.000
#                     1991                                              0.000
#                     1992                                              0.000
#                     1993                                              0.000
#                     1994                                              0.000
# ...                                                                     ...
# Venezuela, RB       2018                                             10.040
#                     2019                                             10.184
#                     2020                                             15.060
#                     2021                                             12.942
#                     2022                                             10.656
#
# Indicador                 Urban population  \
# País                Año
# Antigua and Barbuda 1990           22435.0
#                     1991           22568.0
#                     1992           22686.0
#                     1993           22850.0
#                     1994           23029.0
# ...                                    ...
# Venezuela, RB       2018        52617224.0
#                     2019        51129226.0
#                     2020        50302174.0
#                     2021        49815066.0
#                     2022        50024946.0
#
# Indicador                 Urban population (% of total population)
# País                Año
# Antigua and Barbuda 1990                                    35.426
#                     1991                                    35.465
#                     1992                                    35.085
#                     1993                                    34.709
#                     1994                                    34.334
# ...                                                            ...
# Venezuela, RB       2018                                   176.416
#                     2019                                   176.480
#                     2020                                   176.558
#                     2021                                   176.650
#                     2022                                   176.756
#
# [1122 rows x 49 columns]

# %%
#Composición de la tabla, nuevas columnas de indicadores y filas con años/países
df_aggregated_df2_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 49 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  1122 non-null   float64
#  1   Birth rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  2   CO2 emissions (kg per PPP $ of GDP)                                                                              1122 non-null   float64
#  3   Capital health expenditure (% of GDP)                                                                            1122 non-null   float64
#  4   Compulsory education, duration (years)                                                                           1122 non-null   float64
#  5   Control of Corruption: Estimate                                                                                  1122 non-null   float64
#  6   Current health expenditure per capita, PPP (current international $)                                             1122 non-null   float64
#  7   Death rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  8   Diabetes prevalence (% of population ages 20 to 79)                                                              1122 non-null   float64
#  9   Domestic general government health expenditure (% of GDP)                                                        1122 non-null   float64
#  10  Domestic general government health expenditure per capita, PPP (current international $)                         1122 non-null   float64
#  11  Domestic private health expenditure (% of current health expenditure)                                            1122 non-null   float64
#  12  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                1122 non-null   float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)               1122 non-null   float64
#  14  Fertility rate, total (births per woman)                                                                         1122 non-null   float64
#  15  GDP, PPP (constant 2017 international $)                                                                         1122 non-null   float64
#  16  Gini index                                                                                                       1122 non-null   float64
#  17  Government expenditure on education, total (% of GDP)                                                            1122 non-null   float64
#  18  Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                               1122 non-null   float64
#  19  Life expectancy at birth, female (years)                                                                         1122 non-null   float64
#  20  Life expectancy at birth, male (years)                                                                           1122 non-null   float64
#  21  Life expectancy at birth, total (years)                                                                          1122 non-null   float64
#  22  Literacy rate, adult total (% of people ages 15 and above)                                                       1122 non-null   float64
#  23  Mortality rate, adult, female (per 1,000 female adults)                                                          1122 non-null   float64
#  24  Mortality rate, adult, male (per 1,000 male adults)                                                              1122 non-null   float64
#  25  Mortality rate, infant (per 1,000 live births)                                                                   1122 non-null   float64
#  26  Number of neonatal deaths                                                                                        1122 non-null   float64
#  27  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                     1122 non-null   float64
#  28  People using at least basic sanitation services (% of population)                                                1122 non-null   float64
#  29  People using safely managed drinking water services (% of population)                                            1122 non-null   float64
#  30  Political Stability and Absence of Violence/Terrorism: Estimate                                                  1122 non-null   float64
#  31  Population ages 80 and above, female                                                                             1122 non-null   float64
#  32  Population ages 80 and above, male                                                                               1122 non-null   float64
#  33  Population density (people per sq. km of land area)                                                              1122 non-null   float64
#  34  Population, female                                                                                               1122 non-null   float64
#  35  Population, female (% of total population)                                                                       1122 non-null   float64
#  36  Population, male                                                                                                 1122 non-null   float64
#  37  Population, male (% of total population)                                                                         1122 non-null   float64
#  38  Population, total                                                                                                1122 non-null   float64
#  39  Poverty gap at $6.85 a day (2017 PPP) (%)                                                                        1122 non-null   float64
#  40  Pregnant women receiving prenatal care (%)                                                                       1122 non-null   float64
#  41  Prevalence of overweight (% of adults)                                                                           1122 non-null   float64
#  42  Prevalence of overweight, weight for height (% of children under 5)                                              1122 non-null   float64
#  43  Prevalence of undernourishment (% of population)                                                                 1122 non-null   float64
#  44  Rural population (% of total population)                                                                         1122 non-null   float64
#  45  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)             1122 non-null   float64
#  46  Unemployment, total (% of total labor force) (modeled ILO estimate)                                              1122 non-null   float64
#  47  Urban population                                                                                                 1122 non-null   float64
#  48  Urban population (% of total population)                                                                         1122 non-null   float64
# dtypes: float64(49)
# memory usage: 432.4+ KB

# %%
# Para contar tanto los valores nulos (NaN) como los ceros:
nulos_ceros = df_aggregated_df2_df3.isnull().sum() + (df_aggregated_df2_df3 == 0).sum()

print(nulos_ceros) 
print("(",(nulos_ceros/1122)*100,")%")
nulos_ceros[]
# Out:
# Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    1034
# Birth rate, crude (per 1,000 people)                                                                                 34
# CO2 emissions (kg per PPP $ of GDP)                                                                                 108
# Capital health expenditure (% of GDP)                                                                               493
# Compulsory education, duration (years)                                                                              279
# Control of Corruption: Estimate                                                                                     321
# Current health expenditure per capita, PPP (current international $)                                                405
# Death rate, crude (per 1,000 people)                                                                                 34
# Diabetes prevalence (% of population ages 20 to 79)                                                                1049
# Domestic general government health expenditure (% of GDP)                                                           405
# Domestic general government health expenditure per capita, PPP (current international $)                            405
# Domestic private health expenditure (% of current health expenditure)                                               405
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  1007
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                  767
# Fertility rate, total (births per woman)                                                                             34
# GDP, PPP (constant 2017 international $)                                                                             66
# Gini index                                                                                                          660
# Government expenditure on education, total (% of GDP)                                                               441
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 1096
# Life expectancy at birth, female (years)                                                                             34
# Life expectancy at birth, male (years)                                                                               34
# Life expectancy at birth, total (years)                                                                              34
# Literacy rate, adult total (% of people ages 15 and above)                                                          916
# Mortality rate, adult, female (per 1,000 female adults)                                                              36
# Mortality rate, adult, male (per 1,000 male adults)                                                                  36
# Mortality rate, infant (per 1,000 live births)                                                                       34
# Number of neonatal deaths                                                                                            34
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                        728
# People using at least basic sanitation services (% of population)                                                   374
# People using safely managed drinking water services (% of population)                                               766
# Political Stability and Absence of Violence/Terrorism: Estimate                                                     310
# Population ages 80 and above, female                                                                                  0
# Population ages 80 and above, male                                                                                    0
# Population density (people per sq. km of land area)                                                                  34
# Population, female                                                                                                    0
# Population, female (% of total population)                                                                            0
# Population, male                                                                                                      0
# Population, male (% of total population)                                                                              0
# Population, total                                                                                                     0
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                           658
# Pregnant women receiving prenatal care (%)                                                                          913
# Prevalence of overweight (% of adults)                                                                              204
# Prevalence of overweight, weight for height (% of children under 5)                                                 927
# Prevalence of undernourishment (% of population)                                                                    542
# Rural population (% of total population)                                                                              0
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)                952
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                 130
# Urban population                                                                                                      0
# Urban population (% of total population)                                                                              0
# dtype: int64
# ( Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    92.156863
# Birth rate, crude (per 1,000 people)                                                                                3.030303
# CO2 emissions (kg per PPP $ of GDP)                                                                                 9.625668
# Capital health expenditure (% of GDP)                                                                              43.939394
# Compulsory education, duration (years)                                                                             24.866310
# Control of Corruption: Estimate                                                                                    28.609626
# Current health expenditure per capita, PPP (current international $)                                               36.096257
# Death rate, crude (per 1,000 people)                                                                                3.030303
# Diabetes prevalence (% of population ages 20 to 79)                                                                93.493761
# Domestic general government health expenditure (% of GDP)                                                          36.096257
# Domestic general government health expenditure per capita, PPP (current international $)                           36.096257
# Domestic private health expenditure (% of current health expenditure)                                              36.096257
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  89.750446
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                 68.360071
# Fertility rate, total (births per woman)                                                                            3.030303
# GDP, PPP (constant 2017 international $)                                                                            5.882353
# Gini index                                                                                                         58.823529
# Government expenditure on education, total (% of GDP)                                                              39.304813
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 97.682709
# Life expectancy at birth, female (years)                                                                            3.030303
# Life expectancy at birth, male (years)                                                                              3.030303
# Life expectancy at birth, total (years)                                                                             3.030303
# Literacy rate, adult total (% of people ages 15 and above)                                                         81.639929
# Mortality rate, adult, female (per 1,000 female adults)                                                             3.208556
# Mortality rate, adult, male (per 1,000 male adults)                                                                 3.208556
# Mortality rate, infant (per 1,000 live births)                                                                      3.030303
# Number of neonatal deaths                                                                                           3.030303
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                       64.884135
# People using at least basic sanitation services (% of population)                                                  33.333333
# People using safely managed drinking water services (% of population)                                              68.270945
# Political Stability and Absence of Violence/Terrorism: Estimate                                                    27.629234
# Population ages 80 and above, female                                                                                0.000000
# Population ages 80 and above, male                                                                                  0.000000
# Population density (people per sq. km of land area)                                                                 3.030303
# Population, female                                                                                                  0.000000
# Population, female (% of total population)                                                                          0.000000
# Population, male                                                                                                    0.000000
# Population, male (% of total population)                                                                            0.000000
# Population, total                                                                                                   0.000000
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                          58.645276
# Pregnant women receiving prenatal care (%)                                                                         81.372549
# Prevalence of overweight (% of adults)                                                                             18.181818
# Prevalence of overweight, weight for height (% of children under 5)                                                82.620321
# Prevalence of undernourishment (% of population)                                                                   48.306595
# Rural population (% of total population)                                                                            0.000000
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)               84.848485
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                11.586453
# Urban population                                                                                                    0.000000
# Urban population (% of total population)                                                                            0.000000
# dtype: float64 )%

# %%
df_aggregated_df2_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 49 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  1122 non-null   float64
#  1   Birth rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  2   CO2 emissions (kg per PPP $ of GDP)                                                                              1122 non-null   float64
#  3   Capital health expenditure (% of GDP)                                                                            1122 non-null   float64
#  4   Compulsory education, duration (years)                                                                           1122 non-null   float64
#  5   Control of Corruption: Estimate                                                                                  1122 non-null   float64
#  6   Current health expenditure per capita, PPP (current international $)                                             1122 non-null   float64
#  7   Death rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  8   Diabetes prevalence (% of population ages 20 to 79)                                                              1122 non-null   float64
#  9   Domestic general government health expenditure (% of GDP)                                                        1122 non-null   float64
#  10  Domestic general government health expenditure per capita, PPP (current international $)                         1122 non-null   float64
#  11  Domestic private health expenditure (% of current health expenditure)                                            1122 non-null   float64
#  12  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                1122 non-null   float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)               1122 non-null   float64
#  14  Fertility rate, total (births per woman)                                                                         1122 non-null   float64
#  15  GDP, PPP (constant 2017 international $)                                                                         1122 non-null   float64
#  16  Gini index                                                                                                       1122 non-null   float64
#  17  Government expenditure on education, total (% of GDP)                                                            1122 non-null   float64
#  18  Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                               1122 non-null   float64
#  19  Life expectancy at birth, female (years)                                                                         1122 non-null   float64
#  20  Life expectancy at birth, male (years)                                                                           1122 non-null   float64
#  21  Life expectancy at birth, total (years)                                                                          1122 non-null   float64
#  22  Literacy rate, adult total (% of people ages 15 and above)                                                       1122 non-null   float64
#  23  Mortality rate, adult, female (per 1,000 female adults)                                                          1122 non-null   float64
#  24  Mortality rate, adult, male (per 1,000 male adults)                                                              1122 non-null   float64
#  25  Mortality rate, infant (per 1,000 live births)                                                                   1122 non-null   float64
#  26  Number of neonatal deaths                                                                                        1122 non-null   float64
#  27  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                     1122 non-null   float64
#  28  People using at least basic sanitation services (% of population)                                                1122 non-null   float64
#  29  People using safely managed drinking water services (% of population)                                            1122 non-null   float64
#  30  Political Stability and Absence of Violence/Terrorism: Estimate                                                  1122 non-null   float64
#  31  Population ages 80 and above, female                                                                             1122 non-null   float64
#  32  Population ages 80 and above, male                                                                               1122 non-null   float64
#  33  Population density (people per sq. km of land area)                                                              1122 non-null   float64
#  34  Population, female                                                                                               1122 non-null   float64
#  35  Population, female (% of total population)                                                                       1122 non-null   float64
#  36  Population, male                                                                                                 1122 non-null   float64
#  37  Population, male (% of total population)                                                                         1122 non-null   float64
#  38  Population, total                                                                                                1122 non-null   float64
#  39  Poverty gap at $6.85 a day (2017 PPP) (%)                                                                        1122 non-null   float64
#  40  Pregnant women receiving prenatal care (%)                                                                       1122 non-null   float64
#  41  Prevalence of overweight (% of adults)                                                                           1122 non-null   float64
#  42  Prevalence of overweight, weight for height (% of children under 5)                                              1122 non-null   float64
#  43  Prevalence of undernourishment (% of population)                                                                 1122 non-null   float64
#  44  Rural population (% of total population)                                                                         1122 non-null   float64
#  45  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)             1122 non-null   float64
#  46  Unemployment, total (% of total labor force) (modeled ILO estimate)                                              1122 non-null   float64
#  47  Urban population                                                                                                 1122 non-null   float64
#  48  Urban population (% of total population)                                                                         1122 non-null   float64
# dtypes: float64(49)
# memory usage: 432.4+ KB

# %%
# Eliminamos columnas que tienen más de 65% de nulos de la base del BM
#Tomamos nota de las variables qeu eliminamos, para tomarls de fuenes externas
#Dejamos aún algunas columnas que tiene muchos nulos evidentes, y dejamos aquellos que podrían mejorar luego de la limpieza de datos.
# Lista de palabras clave para las columnas a eliminar
palabras_a_eliminar = [
    "Account ownership",
    "Educational attainment,",
    "Educational attainment,",
    "Infant and young",
    "Literacy rate,",
    "pure alcohol"
]

# Encuentra y elimina las columnas que contienen alguna de las palabras clave
columnas_a_eliminar = [col for col in df_aggregated_df2_df3.columns if any(palabra in col for palabra in palabras_a_eliminar)]
df_filtrado_nulos = df_aggregated_df2_df3.drop(columns=columnas_a_eliminar)

# %%
#Eliminar Columna indicador Diabetes en niños

columna_a_eliminar = next((col for col in df_filtrado_nulos.columns if col.startswith("Diabetes prevalence") and "child" in col), None)

if columna_a_eliminar is not None:
    df_filtrado_nulos = df_filtrado_nulos.drop(columns=columna_a_eliminar)

# %%
df_filtrado_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 43 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                          1122 non-null   float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                           1122 non-null   float64
#  2   Capital health expenditure (% of GDP)                                                         1122 non-null   float64
#  3   Compulsory education, duration (years)                                                        1122 non-null   float64
#  4   Control of Corruption: Estimate                                                               1122 non-null   float64
#  5   Current health expenditure per capita, PPP (current international $)                          1122 non-null   float64
#  6   Death rate, crude (per 1,000 people)                                                          1122 non-null   float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                           1122 non-null   float64
#  8   Domestic general government health expenditure (% of GDP)                                     1122 non-null   float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)      1122 non-null   float64
#  10  Domestic private health expenditure (% of current health expenditure)                         1122 non-null   float64
#  11  Fertility rate, total (births per woman)                                                      1122 non-null   float64
#  12  GDP, PPP (constant 2017 international $)                                                      1122 non-null   float64
#  13  Gini index                                                                                    1122 non-null   float64
#  14  Government expenditure on education, total (% of GDP)                                         1122 non-null   float64
#  15  Life expectancy at birth, female (years)                                                      1122 non-null   float64
#  16  Life expectancy at birth, male (years)                                                        1122 non-null   float64
#  17  Life expectancy at birth, total (years)                                                       1122 non-null   float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                       1122 non-null   float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                           1122 non-null   float64
#  20  Mortality rate, infant (per 1,000 live births)                                                1122 non-null   float64
#  21  Number of neonatal deaths                                                                     1122 non-null   float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)  1122 non-null   float64
#  23  People using at least basic sanitation services (% of population)                             1122 non-null   float64
#  24  People using safely managed drinking water services (% of population)                         1122 non-null   float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                               1122 non-null   float64
#  26  Population ages 80 and above, female                                                          1122 non-null   float64
#  27  Population ages 80 and above, male                                                            1122 non-null   float64
#  28  Population density (people per sq. km of land area)                                           1122 non-null   float64
#  29  Population, female                                                                            1122 non-null   float64
#  30  Population, female (% of total population)                                                    1122 non-null   float64
#  31  Population, male                                                                              1122 non-null   float64
#  32  Population, male (% of total population)                                                      1122 non-null   float64
#  33  Population, total                                                                             1122 non-null   float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                     1122 non-null   float64
#  35  Pregnant women receiving prenatal care (%)                                                    1122 non-null   float64
#  36  Prevalence of overweight (% of adults)                                                        1122 non-null   float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                           1122 non-null   float64
#  38  Prevalence of undernourishment (% of population)                                              1122 non-null   float64
#  39  Rural population (% of total population)                                                      1122 non-null   float64
#  40  Unemployment, total (% of total labor force) (modeled ILO estimate)                           1122 non-null   float64
#  41  Urban population                                                                              1122 non-null   float64
#  42  Urban population (% of total population)                                                      1122 non-null   float64
# dtypes: float64(43)
# memory usage: 379.8+ KB

# %%
#La base de datos mantiene aún muchos nulos en datos de países de las islas del Caribe.
#Para aumentar la calidad de los datos, vamos a quitar del análisis los países con una población menor a 2 millones de personas, que básicamente son las islas mencionadas más pequeñas.
#Umbral = 2000000





# Define un umbral de población (2 millones en este caso)
umbral_población = 2000000

# Filtra los países con población mayor al umbral
df_filtrado_nulos_Sin_Caribe = df_filtrado_nulos.groupby('País').filter(lambda x: x['Population, total'].max() > umbral_población)

# %%
df_filtrado_nulos_Sin_Caribe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 759 entries, ('Argentina', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 44 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                                   759 non-null    float64
#  2   Capital health expenditure (% of GDP)                                                                 759 non-null    float64
#  3   Compulsory education, duration (years)                                                                759 non-null    float64
#  4   Control of Corruption: Estimate                                                                       759 non-null    float64
#  5   Current health expenditure per capita, PPP (current international $)                                  759 non-null    float64
#  6   Death rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                                   759 non-null    float64
#  8   Domestic general government health expenditure (% of GDP)                                             759 non-null    float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)              759 non-null    float64
#  10  Domestic private health expenditure (% of current health expenditure)                                 759 non-null    float64
#  11  Fertility rate, total (births per woman)                                                              759 non-null    float64
#  12  GDP, PPP (constant 2017 international $)                                                              759 non-null    float64
#  13  Gini index                                                                                            759 non-null    float64
#  14  Government expenditure on education, total (% of GDP)                                                 759 non-null    float64
#  15  Life expectancy at birth, female (years)                                                              759 non-null    float64
#  16  Life expectancy at birth, male (years)                                                                759 non-null    float64
#  17  Life expectancy at birth, total (years)                                                               759 non-null    float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                               759 non-null    float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                                   759 non-null    float64
#  20  Mortality rate, infant (per 1,000 live births)                                                        759 non-null    float64
#  21  Number of neonatal deaths                                                                             759 non-null    float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)          759 non-null    float64
#  23  People using at least basic sanitation services (% of population)                                     759 non-null    float64
#  24  People using safely managed drinking water services (% of population)                                 759 non-null    float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                                       759 non-null    float64
#  26  Population ages 80 and above, female                                                                  759 non-null    float64
#  27  Population ages 80 and above, male                                                                    759 non-null    float64
#  28  Population density (people per sq. km of land area)                                                   759 non-null    float64
#  29  Population, female                                                                                    759 non-null    float64
#  30  Population, female (% of total population)                                                            759 non-null    float64
#  31  Population, male                                                                                      759 non-null    float64
#  32  Population, male (% of total population)                                                              759 non-null    float64
#  33  Population, total                                                                                     759 non-null    float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                             759 non-null    float64
#  35  Pregnant women receiving prenatal care (%)                                                            759 non-null    float64
#  36  Prevalence of overweight (% of adults)                                                                759 non-null    float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                                   759 non-null    float64
#  38  Prevalence of undernourishment (% of population)                                                      759 non-null    float64
#  39  Rural population (% of total population)                                                              759 non-null    float64
#  40  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  759 non-null    float64
#  41  Unemployment, total (% of total labor force) (modeled ILO estimate)                                   759 non-null    float64
#  42  Urban population                                                                                      759 non-null    float64
#  43  Urban population (% of total population)                                                              759 non-null    float64
# dtypes: float64(44)
# memory usage: 264.1+ KB

# %%
df_filtrado_nulos_Sin_Caribe.head()
# Out:
# Indicador       Birth rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                21.989
#           1991                                21.844
#           1992                                21.683
#           1993                                21.570
#           1994                                21.419
#
# Indicador       CO2 emissions (kg per PPP $ of GDP)  \
# País      Año
# Argentina 1990                             0.427859
#           1991                             0.400371
#           1992                             0.369563
#           1993                             0.340845
#           1994                             0.320044
#
# Indicador       Capital health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                    0.0
#           1991                                    0.0
#           1992                                    0.0
#           1993                                    0.0
#           1994                                    0.0
#
# Indicador       Compulsory education, duration (years)  \
# País      Año
# Argentina 1990                                     0.0
#           1991                                     0.0
#           1992                                     0.0
#           1993                                     0.0
#           1994                                     0.0
#
# Indicador       Control of Corruption: Estimate  \
# País      Año
# Argentina 1990                              0.0
#           1991                              0.0
#           1992                              0.0
#           1993                              0.0
#           1994                              0.0
#
# Indicador       Current health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Death rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                 7.743
#           1991                                 7.536
#           1992                                 7.595
#           1993                                 7.631
#           1994                                 7.403
#
# Indicador       Diabetes prevalence (% of population ages 20 to 79)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País      Año   ...
# Argentina 1990  ...                                        0.0
#           1991  ...                                        4.5
#           1992  ...                                        5.0
#           1993  ...                                        5.5
#           1994  ...                                        5.7
#
# Indicador       Pregnant women receiving prenatal care (%)  \
# País      Año
# Argentina 1990                                         0.0
#           1991                                         0.0
#           1992                                         0.0
#           1993                                        95.0
#           1994                                         0.0
#
# Indicador       Prevalence of overweight (% of adults)  \
# País      Año
# Argentina 1990                                    48.7
#           1991                                    49.3
#           1992                                    49.9
#           1993                                    50.5
#           1994                                    51.1
#
# Indicador       Prevalence of overweight, weight for height (% of children under 5)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                               11.1
#
# Indicador       Prevalence of undernourishment (% of population)  \
# País      Año
# Argentina 1990                                               0.0
#           1991                                               0.0
#           1992                                               0.0
#           1993                                               0.0
#           1994                                               0.0
#
# Indicador       Rural population (% of total population)  \
# País      Año
# Argentina 1990                                    13.016
#           1991                                    12.672
#           1992                                    12.458
#           1993                                    12.248
#           1994                                    12.040
#
# Indicador       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País      Año
# Argentina 1990                                               0.00
#           1991                                               5.44
#           1992                                               6.36
#           1993                                              10.10
#           1994                                              11.76
#
# Indicador       Urban population  Urban population (% of total population)
# País      Año
# Argentina 1990        28389540.0                                    86.984
#           1991        28910601.0                                    87.328
#           1992        29386348.0                                    87.542
#           1993        29859584.0                                    87.752
#           1994        30336257.0                                    87.960
#
# [5 rows x 44 columns]

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado df_filtrado_nulos_Sin_Caribe
# y que 'País' y 'Año' están en el índice

# 1. Filtrar las columnas numéricas
columnas_numericas = df_filtrado_nulos_Sin_Caribe.select_dtypes(include='number')

# 2. Crear un DataFrame vacío para almacenar las correlaciones por país
correlaciones_por_pais = pd.DataFrame()

# 3. Iterar a través de los países y calcular las correlaciones para cada uno
for pais in df_filtrado_nulos_Sin_Caribe.index.get_level_values('País').unique():
    datos_pais = df_filtrado_nulos_Sin_Caribe.xs(pais, level='País', drop_level=False)
    correlaciones = datos_pais.corrwith(datos_pais['Life expectancy at birth, total (years)'])
    correlaciones_por_pais = pd.concat([correlaciones_por_pais, correlaciones], axis=1, sort=False)

# Transponer el DataFrame de correlaciones para que los países sean las filas y los indicadores las columnas
correlaciones_por_pais = correlaciones_por_pais.T

# Imprimir las correlaciones
print("Correlaciones de indicadores numéricos por país con Esperanza de Vida:")
print(correlaciones_por_pais)
# Out:
# Correlaciones de indicadores numéricos por país con Esperanza de Vida:
#    Birth rate, crude (per 1,000 people)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                              0.769019                             0.400697
# 0                              0.553211                             0.159017
# 0                              0.477770                             0.483241
# 0                              0.767757                             0.348921
# 0                              0.542633                             0.292770
# 0                              0.470423                             0.229455
# 0                              0.558151                             0.378914
# 0                              0.676471                                  NaN
# 0                              0.660309                             0.311954
# 0                              0.593779                             0.484526
# 0                              0.498134                             0.538358
# 0                              0.541473                             0.575301
# 0                              0.499552                             0.503997
# 0                              0.503109                                  NaN
# 0                              0.552385                             0.418508
# 0                              0.627683                             0.454843
# 0                              0.516760                             0.290397
# 0                              0.750761                             0.315505
# 0                              0.636636                             0.540965
# 0                              0.528817                             0.297951
# 0                              0.817973                             0.306141
# 0                              0.713190                             0.392865
# 0                              0.745975                             0.240057
#
#    Capital health expenditure (% of GDP)  \
# 0                               0.219555
# 0                               0.433155
# 0                               0.275348
# 0                               0.334708
# 0                               0.289604
# 0                               0.226812
# 0                               0.256316
# 0                               0.189297
# 0                               0.085722
# 0                               0.324360
# 0                               0.345090
# 0                               0.339533
# 0                               0.201676
# 0                                    NaN
# 0                               0.206841
# 0                               0.239385
# 0                               0.267110
# 0                               0.327275
# 0                               0.285176
# 0                               0.397175
# 0                               0.306199
# 0                               0.254943
# 0                               0.157030
#
#    Compulsory education, duration (years)  Control of Corruption: Estimate  \
# 0                               -0.043365                         0.098457
# 0                                0.101643                        -0.002336
# 0                               -0.009387                         0.213800
# 0                               -0.008530                         0.023635
# 0                                0.021668                         0.097501
# 0                                0.015002                        -0.012546
# 0                               -0.071576                         0.013785
# 0                               -0.016219                         0.286060
# 0                               -0.040619                        -0.174798
# 0                               -0.005803                        -0.043671
# 0                                0.130375                         0.099921
# 0                                0.139860                        -0.075180
# 0                                0.008218                         0.047049
# 0                                0.034464                         0.038268
# 0                               -0.103166                        -0.139739
# 0                               -0.073336                         0.253710
# 0                                0.100461                         0.070447
# 0                                0.036894                         0.130698
# 0                               -0.045245                         0.050809
# 0                                0.097928                         0.185178
# 0                               -0.030809                         0.032817
# 0                               -0.051223                        -0.127024
# 0                                0.284241                         0.219000
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                           0.312727
# 0                                           0.415349
# 0                                           0.408673
# 0                                           0.337380
# 0                                           0.341573
# 0                                           0.380711
# 0                                           0.273027
# 0                                           0.281334
# 0                                           0.332150
# 0                                           0.346861
# 0                                           0.456054
# 0                                           0.417250
# 0                                           0.390747
# 0                                                NaN
# 0                                           0.234545
# 0                                           0.304027
# 0                                           0.422321
# 0                                           0.312294
# 0                                           0.330873
# 0                                           0.422354
# 0                                           0.293550
# 0                                           0.314885
# 0                                           0.237530
#
#    Death rate, crude (per 1,000 people)  \
# 0                              0.967689
# 0                              0.495251
# 0                              0.887702
# 0                              0.985748
# 0                              0.901336
# 0                              0.812565
# 0                              0.762766
# 0                              0.707088
# 0                              0.973464
# 0                              0.772898
# 0                              0.458220
# 0                              0.280488
# 0                              0.515541
# 0                              0.921301
# 0                              0.886043
# 0                              0.648494
# 0                              0.571413
# 0                              0.902634
# 0                              0.887582
# 0                              0.867643
# 0                              0.924958
# 0                              0.950170
# 0                              0.728668
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                           0.062824
# 0                                           0.079589
# 0                                           0.080030
# 0                                           0.079702
# 0                                           0.074265
# 0                                           0.067595
# 0                                           0.047761
# 0                                           0.035484
# 0                                           0.077480
# 0                                           0.064582
# 0                                           0.071866
# 0                                           0.118295
# 0                                           0.070979
# 0                                           0.076343
# 0                                           0.049606
# 0                                           0.041814
# 0                                           0.123874
# 0                                           0.070437
# 0                                           0.049830
# 0                                           0.074705
# 0                                           0.047076
# 0                                           0.047637
# 0                                           0.034409
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.323658
# 0                                           0.452302
# 0                                           0.401578
# 0                                           0.345970
# 0                                           0.370077
# 0                                           0.395621
# 0                                           0.299825
# 0                                           0.311878
# 0                                           0.334782
# 0                                           0.335491
# 0                                           0.452813
# 0                                           0.319906
# 0                                           0.408071
# 0                                                NaN
# 0                                           0.236417
# 0                                           0.319137
# 0                                           0.427502
# 0                                           0.358245
# 0                                           0.334579
# 0                                           0.435403
# 0                                           0.302031
# 0                                           0.325513
# 0                                           0.222923
#
#    Domestic general government health expenditure per capita, PPP (current international $)  \
# 0                                           0.303186
# 0                                           0.387887
# 0                                           0.407687
# 0                                           0.336460
# 0                                           0.317375
# 0                                           0.381242
# 0                                           0.267628
# 0                                           0.277205
# 0                                           0.301088
# 0                                           0.307159
# 0                                           0.451146
# 0                                           0.352708
# 0                                           0.395385
# 0                                                NaN
# 0                                           0.222887
# 0                                           0.291070
# 0                                           0.401957
# 0                                           0.317979
# 0                                           0.308967
# 0                                           0.401184
# 0                                           0.283770
# 0                                           0.294063
# 0                                           0.234633
#
#    ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# 0  ...                                   0.194124
# 0  ...                                   0.242822
# 0  ...                                   0.159368
# 0  ...                                   0.179966
# 0  ...                                   0.032427
# 0  ...                                   0.254229
# 0  ...                                   0.116808
# 0  ...                                        NaN
# 0  ...                                   0.279958
# 0  ...                                   0.069732
# 0  ...                                   0.067863
# 0  ...                                   0.079528
# 0  ...                                   0.284475
# 0  ...                                        NaN
# 0  ...                                   0.070377
# 0  ...                                   0.158055
# 0  ...                                   0.006258
# 0  ...                                   0.192145
# 0  ...                                   0.099204
# 0  ...                                   0.317862
# 0  ...                                   0.661656
# 0  ...                                   0.185170
# 0  ...                                   0.111759
#
#    Pregnant women receiving prenatal care (%)  \
# 0                                    0.075038
# 0                                    0.123391
# 0                                    0.119130
# 0                                    0.036705
# 0                                   -0.011661
# 0                                    0.101640
# 0                                    0.103081
# 0                                    0.167485
# 0                                    0.109584
# 0                                    0.021434
# 0                                    0.081639
# 0                                    0.118108
# 0                                    0.086129
# 0                                         NaN
# 0                                    0.096500
# 0                                    0.116530
# 0                                    0.035905
# 0                                    0.096232
# 0                                    0.065305
# 0                                    0.354986
# 0                                         NaN
# 0                                    0.072486
# 0                                    0.056411
#
#    Prevalence of overweight (% of adults)  \
# 0                                0.335196
# 0                                0.322811
# 0                                0.307279
# 0                                0.330184
# 0                                0.319733
# 0                                0.319394
# 0                                0.352482
# 0                                0.372768
# 0                                0.323019
# 0                                0.348186
# 0                                0.310366
# 0                                0.251114
# 0                                0.325196
# 0                                     NaN
# 0                                0.372399
# 0                                0.403086
# 0                                0.270338
# 0                                0.330770
# 0                                0.327988
# 0                                0.309750
# 0                                0.365604
# 0                                0.339690
# 0                                0.396649
#
#    Prevalence of overweight, weight for height (% of children under 5)  \
# 0                                           0.058614
# 0                                           0.094767
# 0                                           0.085662
# 0                                           0.029653
# 0                                           0.120969
# 0                                           0.082999
# 0                                           0.056814
# 0                                           0.047309
# 0                                           0.096929
# 0                                           0.143206
# 0                                           0.055224
# 0                                           0.093093
# 0                                           0.096276
# 0                                                NaN
# 0                                           0.198943
# 0                                           0.120609
# 0                                           0.038192
# 0                                           0.084968
# 0                                           0.086462
# 0                                           0.310057
# 0                                           0.151683
# 0                                           0.134842
# 0                                           0.216618
#
#    Prevalence of undernourishment (% of population)  \
# 0                                          0.294207
# 0                                          0.368006
# 0                                          0.242975
# 0                                          0.302708
# 0                                          0.335737
# 0                                          0.337671
# 0                                          0.274131
# 0                                          0.311234
# 0                                          0.222665
# 0                                          0.279982
# 0                                          0.419242
# 0                                          0.395274
# 0                                          0.335524
# 0                                          0.334937
# 0                                          0.238238
# 0                                          0.293922
# 0                                          0.355280
# 0                                          0.243878
# 0                                          0.309716
# 0                                          0.279973
# 0                                          0.292696
# 0                                          0.290468
# 0                                          0.134534
#
#    Rural population (% of total population)  \
# 0                                  0.149099
# 0                                 -0.010054
# 0                                  0.022155
# 0                                  0.095959
# 0                                  0.051659
# 0                                  0.086413
# 0                                  0.201812
# 0                                  0.143097
# 0                                  0.132840
# 0                                  0.061489
# 0                                  0.064386
# 0                                  0.001443
# 0                                  0.124888
# 0                                 -0.030424
# 0                                  0.321625
# 0                                  0.230172
# 0                                  0.059514
# 0                                  0.095862
# 0                                  0.117755
# 0                                 -0.009536
# 0                                  0.195642
# 0                                  0.113209
# 0                                  0.135419
#
#    Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                           0.107467
# 0                                           0.153904
# 0                                           0.124308
# 0                                           0.100214
# 0                                           0.113746
# 0                                           0.121109
# 0                                           0.089783
# 0                                           0.102004
# 0                                           0.104055
# 0                                           0.121098
# 0                                           0.125975
# 0                                           0.050089
# 0                                           0.123958
# 0                                                NaN
# 0                                           0.074407
# 0                                           0.108041
# 0                                           0.131249
# 0                                           0.116328
# 0                                           0.105010
# 0                                           0.144115
# 0                                           0.098585
# 0                                           0.097467
# 0                                           0.085135
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                           0.137313
# 0                                          -0.145745
# 0                                           0.104225
# 0                                           0.162844
# 0                                           0.067728
# 0                                           0.007510
# 0                                          -0.205180
# 0                                           0.092510
# 0                                          -0.080883
# 0                                           0.008559
# 0                                           0.144333
# 0                                           0.091942
# 0                                          -0.114647
# 0                                          -0.056332
# 0                                           0.121118
# 0                                           0.109368
# 0                                          -0.018661
# 0                                          -0.219381
# 0                                          -0.139812
# 0                                           0.059684
# 0                                           0.213134
# 0                                           0.077239
# 0                                           0.162441
#
#    Urban population  Urban population (% of total population)
# 0         -0.192160                                 -0.149099
# 0         -0.040174                                  0.010054
# 0         -0.047544                                 -0.022155
# 0         -0.209193                                 -0.095959
# 0         -0.161430                                 -0.051659
# 0         -0.119684                                 -0.086413
# 0         -0.213080                                 -0.201812
# 0         -0.047479                                 -0.143097
# 0         -0.158273                                 -0.132840
# 0         -0.147819                                 -0.061489
# 0         -0.069109                                 -0.064386
# 0         -0.030335                                 -0.001443
# 0         -0.141558                                 -0.124888
# 0         -0.018134                                  0.030424
# 0         -0.266819                                 -0.321625
# 0         -0.220590                                 -0.230172
# 0         -0.059299                                 -0.059514
# 0         -0.155415                                 -0.095862
# 0         -0.167460                                 -0.117755
# 0         -0.070705                                  0.009536
# 0         -0.193300                                 -0.195642
# 0         -0.110409                                 -0.113209
# 0         -0.098932                                 -0.135419
#
# [23 rows x 44 columns]

# %%
correlaciones_por_pais.head(100)
# Out:
#    Birth rate, crude (per 1,000 people)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                              0.769019                             0.400697
# 0                              0.553211                             0.159017
# 0                              0.477770                             0.483241
# 0                              0.767757                             0.348921
# 0                              0.542633                             0.292770
# 0                              0.470423                             0.229455
# 0                              0.558151                             0.378914
# 0                              0.676471                                  NaN
# 0                              0.660309                             0.311954
# 0                              0.593779                             0.484526
# 0                              0.498134                             0.538358
# 0                              0.541473                             0.575301
# 0                              0.499552                             0.503997
# 0                              0.503109                                  NaN
# 0                              0.552385                             0.418508
# 0                              0.627683                             0.454843
# 0                              0.516760                             0.290397
# 0                              0.750761                             0.315505
# 0                              0.636636                             0.540965
# 0                              0.528817                             0.297951
# 0                              0.817973                             0.306141
# 0                              0.713190                             0.392865
# 0                              0.745975                             0.240057
#
#    Capital health expenditure (% of GDP)  \
# 0                               0.219555
# 0                               0.433155
# 0                               0.275348
# 0                               0.334708
# 0                               0.289604
# 0                               0.226812
# 0                               0.256316
# 0                               0.189297
# 0                               0.085722
# 0                               0.324360
# 0                               0.345090
# 0                               0.339533
# 0                               0.201676
# 0                                    NaN
# 0                               0.206841
# 0                               0.239385
# 0                               0.267110
# 0                               0.327275
# 0                               0.285176
# 0                               0.397175
# 0                               0.306199
# 0                               0.254943
# 0                               0.157030
#
#    Compulsory education, duration (years)  Control of Corruption: Estimate  \
# 0                               -0.043365                         0.098457
# 0                                0.101643                        -0.002336
# 0                               -0.009387                         0.213800
# 0                               -0.008530                         0.023635
# 0                                0.021668                         0.097501
# 0                                0.015002                        -0.012546
# 0                               -0.071576                         0.013785
# 0                               -0.016219                         0.286060
# 0                               -0.040619                        -0.174798
# 0                               -0.005803                        -0.043671
# 0                                0.130375                         0.099921
# 0                                0.139860                        -0.075180
# 0                                0.008218                         0.047049
# 0                                0.034464                         0.038268
# 0                               -0.103166                        -0.139739
# 0                               -0.073336                         0.253710
# 0                                0.100461                         0.070447
# 0                                0.036894                         0.130698
# 0                               -0.045245                         0.050809
# 0                                0.097928                         0.185178
# 0                               -0.030809                         0.032817
# 0                               -0.051223                        -0.127024
# 0                                0.284241                         0.219000
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                           0.312727
# 0                                           0.415349
# 0                                           0.408673
# 0                                           0.337380
# 0                                           0.341573
# 0                                           0.380711
# 0                                           0.273027
# 0                                           0.281334
# 0                                           0.332150
# 0                                           0.346861
# 0                                           0.456054
# 0                                           0.417250
# 0                                           0.390747
# 0                                                NaN
# 0                                           0.234545
# 0                                           0.304027
# 0                                           0.422321
# 0                                           0.312294
# 0                                           0.330873
# 0                                           0.422354
# 0                                           0.293550
# 0                                           0.314885
# 0                                           0.237530
#
#    Death rate, crude (per 1,000 people)  \
# 0                              0.967689
# 0                              0.495251
# 0                              0.887702
# 0                              0.985748
# 0                              0.901336
# 0                              0.812565
# 0                              0.762766
# 0                              0.707088
# 0                              0.973464
# 0                              0.772898
# 0                              0.458220
# 0                              0.280488
# 0                              0.515541
# 0                              0.921301
# 0                              0.886043
# 0                              0.648494
# 0                              0.571413
# 0                              0.902634
# 0                              0.887582
# 0                              0.867643
# 0                              0.924958
# 0                              0.950170
# 0                              0.728668
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                           0.062824
# 0                                           0.079589
# 0                                           0.080030
# 0                                           0.079702
# 0                                           0.074265
# 0                                           0.067595
# 0                                           0.047761
# 0                                           0.035484
# 0                                           0.077480
# 0                                           0.064582
# 0                                           0.071866
# 0                                           0.118295
# 0                                           0.070979
# 0                                           0.076343
# 0                                           0.049606
# 0                                           0.041814
# 0                                           0.123874
# 0                                           0.070437
# 0                                           0.049830
# 0                                           0.074705
# 0                                           0.047076
# 0                                           0.047637
# 0                                           0.034409
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.323658
# 0                                           0.452302
# 0                                           0.401578
# 0                                           0.345970
# 0                                           0.370077
# 0                                           0.395621
# 0                                           0.299825
# 0                                           0.311878
# 0                                           0.334782
# 0                                           0.335491
# 0                                           0.452813
# 0                                           0.319906
# 0                                           0.408071
# 0                                                NaN
# 0                                           0.236417
# 0                                           0.319137
# 0                                           0.427502
# 0                                           0.358245
# 0                                           0.334579
# 0                                           0.435403
# 0                                           0.302031
# 0                                           0.325513
# 0                                           0.222923
#
#    Domestic general government health expenditure per capita, PPP (current international $)  \
# 0                                           0.303186
# 0                                           0.387887
# 0                                           0.407687
# 0                                           0.336460
# 0                                           0.317375
# 0                                           0.381242
# 0                                           0.267628
# 0                                           0.277205
# 0                                           0.301088
# 0                                           0.307159
# 0                                           0.451146
# 0                                           0.352708
# 0                                           0.395385
# 0                                                NaN
# 0                                           0.222887
# 0                                           0.291070
# 0                                           0.401957
# 0                                           0.317979
# 0                                           0.308967
# 0                                           0.401184
# 0                                           0.283770
# 0                                           0.294063
# 0                                           0.234633
#
#    ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# 0  ...                                   0.194124
# 0  ...                                   0.242822
# 0  ...                                   0.159368
# 0  ...                                   0.179966
# 0  ...                                   0.032427
# 0  ...                                   0.254229
# 0  ...                                   0.116808
# 0  ...                                        NaN
# 0  ...                                   0.279958
# 0  ...                                   0.069732
# 0  ...                                   0.067863
# 0  ...                                   0.079528
# 0  ...                                   0.284475
# 0  ...                                        NaN
# 0  ...                                   0.070377
# 0  ...                                   0.158055
# 0  ...                                   0.006258
# 0  ...                                   0.192145
# 0  ...                                   0.099204
# 0  ...                                   0.317862
# 0  ...                                   0.661656
# 0  ...                                   0.185170
# 0  ...                                   0.111759
#
#    Pregnant women receiving prenatal care (%)  \
# 0                                    0.075038
# 0                                    0.123391
# 0                                    0.119130
# 0                                    0.036705
# 0                                   -0.011661
# 0                                    0.101640
# 0                                    0.103081
# 0                                    0.167485
# 0                                    0.109584
# 0                                    0.021434
# 0                                    0.081639
# 0                                    0.118108
# 0                                    0.086129
# 0                                         NaN
# 0                                    0.096500
# 0                                    0.116530
# 0                                    0.035905
# 0                                    0.096232
# 0                                    0.065305
# 0                                    0.354986
# 0                                         NaN
# 0                                    0.072486
# 0                                    0.056411
#
#    Prevalence of overweight (% of adults)  \
# 0                                0.335196
# 0                                0.322811
# 0                                0.307279
# 0                                0.330184
# 0                                0.319733
# 0                                0.319394
# 0                                0.352482
# 0                                0.372768
# 0                                0.323019
# 0                                0.348186
# 0                                0.310366
# 0                                0.251114
# 0                                0.325196
# 0                                     NaN
# 0                                0.372399
# 0                                0.403086
# 0                                0.270338
# 0                                0.330770
# 0                                0.327988
# 0                                0.309750
# 0                                0.365604
# 0                                0.339690
# 0                                0.396649
#
#    Prevalence of overweight, weight for height (% of children under 5)  \
# 0                                           0.058614
# 0                                           0.094767
# 0                                           0.085662
# 0                                           0.029653
# 0                                           0.120969
# 0                                           0.082999
# 0                                           0.056814
# 0                                           0.047309
# 0                                           0.096929
# 0                                           0.143206
# 0                                           0.055224
# 0                                           0.093093
# 0                                           0.096276
# 0                                                NaN
# 0                                           0.198943
# 0                                           0.120609
# 0                                           0.038192
# 0                                           0.084968
# 0                                           0.086462
# 0                                           0.310057
# 0                                           0.151683
# 0                                           0.134842
# 0                                           0.216618
#
#    Prevalence of undernourishment (% of population)  \
# 0                                          0.294207
# 0                                          0.368006
# 0                                          0.242975
# 0                                          0.302708
# 0                                          0.335737
# 0                                          0.337671
# 0                                          0.274131
# 0                                          0.311234
# 0                                          0.222665
# 0                                          0.279982
# 0                                          0.419242
# 0                                          0.395274
# 0                                          0.335524
# 0                                          0.334937
# 0                                          0.238238
# 0                                          0.293922
# 0                                          0.355280
# 0                                          0.243878
# 0                                          0.309716
# 0                                          0.279973
# 0                                          0.292696
# 0                                          0.290468
# 0                                          0.134534
#
#    Rural population (% of total population)  \
# 0                                  0.149099
# 0                                 -0.010054
# 0                                  0.022155
# 0                                  0.095959
# 0                                  0.051659
# 0                                  0.086413
# 0                                  0.201812
# 0                                  0.143097
# 0                                  0.132840
# 0                                  0.061489
# 0                                  0.064386
# 0                                  0.001443
# 0                                  0.124888
# 0                                 -0.030424
# 0                                  0.321625
# 0                                  0.230172
# 0                                  0.059514
# 0                                  0.095862
# 0                                  0.117755
# 0                                 -0.009536
# 0                                  0.195642
# 0                                  0.113209
# 0                                  0.135419
#
#    Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                           0.107467
# 0                                           0.153904
# 0                                           0.124308
# 0                                           0.100214
# 0                                           0.113746
# 0                                           0.121109
# 0                                           0.089783
# 0                                           0.102004
# 0                                           0.104055
# 0                                           0.121098
# 0                                           0.125975
# 0                                           0.050089
# 0                                           0.123958
# 0                                                NaN
# 0                                           0.074407
# 0                                           0.108041
# 0                                           0.131249
# 0                                           0.116328
# 0                                           0.105010
# 0                                           0.144115
# 0                                           0.098585
# 0                                           0.097467
# 0                                           0.085135
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                           0.137313
# 0                                          -0.145745
# 0                                           0.104225
# 0                                           0.162844
# 0                                           0.067728
# 0                                           0.007510
# 0                                          -0.205180
# 0                                           0.092510
# 0                                          -0.080883
# 0                                           0.008559
# 0                                           0.144333
# 0                                           0.091942
# 0                                          -0.114647
# 0                                          -0.056332
# 0                                           0.121118
# 0                                           0.109368
# 0                                          -0.018661
# 0                                          -0.219381
# 0                                          -0.139812
# 0                                           0.059684
# 0                                           0.213134
# 0                                           0.077239
# 0                                           0.162441
#
#    Urban population  Urban population (% of total population)
# 0         -0.192160                                 -0.149099
# 0         -0.040174                                  0.010054
# 0         -0.047544                                 -0.022155
# 0         -0.209193                                 -0.095959
# 0         -0.161430                                 -0.051659
# 0         -0.119684                                 -0.086413
# 0         -0.213080                                 -0.201812
# 0         -0.047479                                 -0.143097
# 0         -0.158273                                 -0.132840
# 0         -0.147819                                 -0.061489
# 0         -0.069109                                 -0.064386
# 0         -0.030335                                 -0.001443
# 0         -0.141558                                 -0.124888
# 0         -0.018134                                  0.030424
# 0         -0.266819                                 -0.321625
# 0         -0.220590                                 -0.230172
# 0         -0.059299                                 -0.059514
# 0         -0.155415                                 -0.095862
# 0         -0.167460                                 -0.117755
# 0         -0.070705                                  0.009536
# 0         -0.193300                                 -0.195642
# 0         -0.110409                                 -0.113209
# 0         -0.098932                                 -0.135419
#
# [23 rows x 44 columns]

# %%
# Especifica el nombre del archivo CSV sin la ruta completa
nombre_archivo_csv = 'Tabla_sin_caribe.csv'

# Exporta el DataFrame a un archivo CSV en la misma carpeta
df_filtrado_nulos_Sin_Caribe.to_csv(nombre_archivo_csv)
