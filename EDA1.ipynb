# %% [markdown]
# ETL. Extracción y transformación
# EDA. Análisis preliminar

# %% [markdown]
# # Importe de Librerias

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# # Introducción

# %% [markdown]
# Como el objetivo principal del trabajo es analizar cúales con los factores socioeconómicos que más inciden en la Esperanza de Vida de los países de que integran la OEA (Organización de Estados Americanos), nos vamos a focalizar en buscar indicadores que tengan que ver con el desarrollo económico y el crecimiento de los países.
#
# Como fuente de datos, nos vamos a nutrir de las bases de datos del World Bank y de base de datos externas de otros organismos internacionales especializados en desarrollo. Vamos a poceder a extrer los datos de la base del Banco Mundial utilizando la API que provee el WB.
#
# Creamos un código para poder extraer los distintos indicadores potenciales para ser analizados, de las distintas bases de datos que se elojan en el sitio del organismo internacional. Las principales bases de datos utilizadas son World Economic Indicators(WEI) y Health & Nutrition ().??
# El análisis preliminar nos permite hacer un corte en los datos, que se tomarán datos a partir de 1990, debido a al aumento de la disponibilidad de la data del WB y la externa al WB (aún a definir?).
# Elegimos a priori aproximadamente 50 indicadores, según los grandes temas o tópicos que tienen que ver con factores socioeconómicos que más inciden en la esperanza de vida, en base a literatura especializada en el tema. (Fuente)
# #(ver de agregar codigos de las bases de datos y agregar data externa elegida y el alcance del proyecto).
# #Preguntar fuentes, lecturas, etc,como documentamos

# %% [markdown]
# # Extracción de datos

# %% [markdown]
# Extracción de Metadata para extraer luego los datos de cógidos de países e indicadores necesarios (50 indicadores)

# %%
# 1ER DATASET

#Código para extraer los datos con la API del WB
#particionamos la información de los países e indicadores para realizar la extracción
# Países de la OEA
countries = ["USA",
    "ATG",
    "ARG",
    "BHS",
    "BRB",
    "BLZ",
    "BOL",
    "BRA",
]


# Indicadores elegidos luego de consultar las distintas base de datos en desarrollo y crecimiento del WB

indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS"
]

# Años deseados para extraer los datos
#En base analisis preliminares y a la disponibildiad de las series de tiempo de lo indicadores, 
# optamos por tomar la data a partir de 1990, cuando comienza a aumentar la cantidad de datos 
# relacionados con el desarrollo
#Vamos a bajar los datos en distintos dataframes que luego se van a concatenar para unificarlo en un dataset
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df0 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df0
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_21400\1885659105.py:100: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df0 = pd.concat(data_frames, ignore_index=True)
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 11347         Brazil           Urban population (% of total population)  1994
# 11348         Brazil           Urban population (% of total population)  1993
# 11349         Brazil           Urban population (% of total population)  1992
# 11350         Brazil           Urban population (% of total population)  1991
# 11351         Brazil           Urban population (% of total population)  1990
#
#         Valor
# 0         NaN
# 1      94.950
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 11347  76.903
# 11348  76.181
# 11349  75.444
# 11350  74.690
# 11351  73.922
#
# [11352 rows x 4 columns]

# %%
# 2DO DATASET

#Continuamos con la extraccion de datos de los países
countries = ["CAN",
    "CHL",
    "COL",
    "CRI",
    "CUB",
    "DOM",
    "ECU"]
    
    

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_21400\2346953927.py:95: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df = pd.concat(data_frames, ignore_index=True)
#          País                                          Indicador   Año   Valor
# 0      Canada  Account ownership at a financial institution o...  2022     NaN
# 1      Canada  Account ownership at a financial institution o...  2021  99.630
# 2      Canada  Account ownership at a financial institution o...  2020     NaN
# 3      Canada  Account ownership at a financial institution o...  2019     NaN
# 4      Canada  Account ownership at a financial institution o...  2018     NaN
# ...       ...                                                ...   ...     ...
# 9928  Ecuador           Urban population (% of total population)  1994  57.254
# 9929  Ecuador           Urban population (% of total population)  1993  56.740
# 9930  Ecuador           Urban population (% of total population)  1992  56.226
# 9931  Ecuador           Urban population (% of total population)  1991  55.709
# 9932  Ecuador           Urban population (% of total population)  1990  55.090
#
# [9933 rows x 4 columns]

# %%
# 3ER DATASET

#Continuamos con el mismo proceso
countries = [
    "GRD",
    "GTM",
    "GUY",
    "HTI",
    "HND",
    "HKG",
    "JAM" ]
# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df_a = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df_a
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_21400\2679272733.py:93: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df_a = pd.concat(data_frames, ignore_index=True)
#          País                                          Indicador   Año   Valor
# 0     Grenada  Account ownership at a financial institution o...  2022     NaN
# 1     Grenada  Account ownership at a financial institution o...  2021     NaN
# 2     Grenada  Account ownership at a financial institution o...  2020     NaN
# 3     Grenada  Account ownership at a financial institution o...  2019     NaN
# 4     Grenada  Account ownership at a financial institution o...  2018     NaN
# ...       ...                                                ...   ...     ...
# 9928  Jamaica           Urban population (% of total population)  1994  50.375
# 9929  Jamaica           Urban population (% of total population)  1993  50.136
# 9930  Jamaica           Urban population (% of total population)  1992  49.896
# 9931  Jamaica           Urban population (% of total population)  1991  49.656
# 9932  Jamaica           Urban population (% of total population)  1990  49.444
#
# [9933 rows x 4 columns]

# %%
# 4TO DATASET

#Sigue la lista de países para exraer la data ...
countries = [
    "MEX", "NIC", "PAN", "PRY", "PER", "DOM", "KNA", 
]


# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS"
]

# Años elegidos 
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df2 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df2
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_21400\2937006103.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df2 = pd.concat(data_frames, ignore_index=True)
#                      País                                          Indicador  \
# 0                  Mexico  Account ownership at a financial institution o...
# 1                  Mexico  Account ownership at a financial institution o...
# 2                  Mexico  Account ownership at a financial institution o...
# 3                  Mexico  Account ownership at a financial institution o...
# 4                  Mexico  Account ownership at a financial institution o...
# ...                   ...                                                ...
# 9928  St. Kitts and Nevis           Urban population (% of total population)
# 9929  St. Kitts and Nevis           Urban population (% of total population)
# 9930  St. Kitts and Nevis           Urban population (% of total population)
# 9931  St. Kitts and Nevis           Urban population (% of total population)
# 9932  St. Kitts and Nevis           Urban population (% of total population)
#
#        Año   Valor
# 0     2022  48.970
# 1     2021     NaN
# 2     2020     NaN
# 3     2019     NaN
# 4     2018     NaN
# ...    ...     ...
# 9928  1994  33.904
# 9929  1993  34.093
# 9930  1992  34.283
# 9931  1991  34.474
# 9932  1990  34.609
#
# [9933 rows x 4 columns]

# %%
# 5TO DATASET

#Ultima extracción de data para analizar los países que integran la OEA
countries =[ "LCA", "VCT", "SUR", "TTO", "URY", "VEN"  ]

# Indicadores que deseas consultar
indicators = [
    "FX.OWN.TOTL.ZS",
    "SP.DYN.CBRT.IN",
    "SH.XPD.KHEX.GD.ZS",
    "EN.ATM.CO2E.PP.GD",
    "SE.COM.DURS",
    "CC.EST",
    "SH.XPD.CHEX.PP.CD",
    "SP.DYN.CDRT.IN",
    "SH.XPD.GHED.GD.ZS",
    "SH.XPD.GHED.PP.CD",
    "SH.XPD.PVTD.CH.ZS",
    "SE.TER.CUAT.BA.ZS",
    "SE.SEC.CUAT.LO.ZS",
    "SP.DYN.TFRT.IN",
    "NY.GDP.MKTP.PP.KD",
    "SI.POV.GINI",
    "SH.STA.IYCF.ZS",
    "SP.DYN.LE00.FE.IN",
    "SP.DYN.LE00.IN",
    "SE.ADT.LITR.ZS",
    "SP.DYN.AMRT.FE",
    "SP.DYN.AMRT.MA",
    "SP.DYN.IMRT.IN",
    "SH.DTH.NMRT",
    "SH.STA.BASS.ZS",
    "SH.H2O.SMDW.ZS",
    "EN.ATM.PM25.MC.ZS",
    "PV.EST",
    "SP.POP.80UP.FE",
    "SP.POP.80UP.MA",
    "SP.POP.TOTL.FE.IN",
    "SP.POP.TOTL.FE.ZS",
    "SP.POP.TOTL.MA.IN",
    "SP.POP.TOTL.MA.ZS",
    "SP.POP.TOTL",
    "SI.POV.UMIC.GP",
    "SH.STA.OWAD.ZS",
    "SH.STA.OWGH.ZS",
    "SE.XPD.TOTL.GD.ZS",
    "SP.RUR.TOTL.ZS",
    "SL.UEM.TOTL.ZS",
    "SP.URB.TOTL",
    "SP.URB.TOTL.IN.ZS"
]




# Años elegidos
start_year = "1990"
end_year = "2022"

# Lista para almacenar DataFrames individuales
data_frames = []

# URL base de la API del Banco Mundial
base_url = "http://api.worldbank.org/v2/country"

# Realiza las consultas para cada país, indicador y año
for country_code in countries:
    for indicator in indicators:
        # Construye la URL de la consulta
        url = f"{base_url}/{country_code}/indicator/{indicator}?date={start_year}:{end_year}&format=json"
        
        # Realiza la solicitud GET a la API del Banco Mundial
        response = requests.get(url)
        
        # Verifica si la solicitud fue exitosa
        if response.status_code == 200:
            data = response.json()
            # Los datos se encuentran en data[1]
            for entry in data[1]:
                year = entry['date']
                value = entry['value']
                indicator_name = entry['indicator']['value'] 
                country_name = entry['country']['value']
                data_frames.append(pd.DataFrame({"País": [country_name], "Indicador": [indicator_name], "Año": [year], "Valor": [value]}))

# Concatenar todos los DataFrames individuales en uno
data_df3 = pd.concat(data_frames, ignore_index=True)

# Mostrar los datos en una tabla
data_df3
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_21400\1154330113.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data_df3 = pd.concat(data_frames, ignore_index=True)
#                País                                          Indicador   Año  \
# 0         St. Lucia  Account ownership at a financial institution o...  2022
# 1         St. Lucia  Account ownership at a financial institution o...  2021
# 2         St. Lucia  Account ownership at a financial institution o...  2020
# 3         St. Lucia  Account ownership at a financial institution o...  2019
# 4         St. Lucia  Account ownership at a financial institution o...  2018
# ...             ...                                                ...   ...
# 8509  Venezuela, RB           Urban population (% of total population)  1994
# 8510  Venezuela, RB           Urban population (% of total population)  1993
# 8511  Venezuela, RB           Urban population (% of total population)  1992
# 8512  Venezuela, RB           Urban population (% of total population)  1991
# 8513  Venezuela, RB           Urban population (% of total population)  1990
#
#        Valor
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 8509  85.686
# 8510  85.352
# 8511  85.012
# 8512  84.664
# 8513  84.284
#
# [8514 rows x 4 columns]

# %% [markdown]
# # Concatenación de dataframes

# %% [markdown]
# ## Concatenando los datasets seleccionados del wb

# %%
# Unificamos los dataframes
concatenated_df2 = pd.concat([data_df0, data_df, data_df3, data_df2, data_df_a], ignore_index=True)

# El argumento 'ignore_index=True' restablece los índices de fila para que sean secuenciales.

# Ahora 'concatenated_df' contiene todos los datos de los tres DataFrames.

# %%
concatenated_df2
# Out:
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 49660        Jamaica           Urban population (% of total population)  1994
# 49661        Jamaica           Urban population (% of total population)  1993
# 49662        Jamaica           Urban population (% of total population)  1992
# 49663        Jamaica           Urban population (% of total population)  1991
# 49664        Jamaica           Urban population (% of total population)  1990
#
#         Valor
# 0         NaN
# 1      94.950
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 49660  50.375
# 49661  50.136
# 49662  49.896
# 49663  49.656
# 49664  49.444
#
# [49665 rows x 4 columns]

# %%
concatenated_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49665 entries, 0 to 49664
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   País       49665 non-null  object
#  1   Indicador  49665 non-null  object
#  2   Año        49665 non-null  object
#  3   Valor      35841 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# ## Concatenando otros indicadores importantes del wb

# %%
#Agregamos data de unos indicadores que faltaban de la base del WB
#Para ello hicimos un proceso similar de extracción y guardamos la data en data_df5
# Reemplaza 'tu_archivo.csv' con la ruta de tu archivo CSV

archivo_csv = 'Recursos/data_df5.csv'

# Cargar el archivo CSV en un DataFrame
data_df5 = pd.read_csv(archivo_csv)

# %%
data_df5
# Out:
#       Unnamed: 0           País  \
# 0              0  United States
# 1              1  United States
# 2              2  United States
# 3              3  United States
# 4              4  United States
# ...          ...            ...
# 6925        6925  Venezuela, RB
# 6926        6926  Venezuela, RB
# 6927        6927  Venezuela, RB
# 6928        6928  Venezuela, RB
# 6929        6929  Venezuela, RB
#
#                                               Indicador   Año      Valor
# 0     Population density (people per sq. km of land ...  2022        NaN
# 1     Population density (people per sq. km of land ...  2021  36.297836
# 2     Population density (people per sq. km of land ...  2020  36.240985
# 3     Population density (people per sq. km of land ...  2019  35.893176
# 4     Population density (people per sq. km of land ...  2018  35.730096
# ...                                                 ...   ...        ...
# 6925  Total alcohol consumption per capita (liters o...  1994        NaN
# 6926  Total alcohol consumption per capita (liters o...  1993        NaN
# 6927  Total alcohol consumption per capita (liters o...  1992        NaN
# 6928  Total alcohol consumption per capita (liters o...  1991        NaN
# 6929  Total alcohol consumption per capita (liters o...  1990        NaN
#
# [6930 rows x 5 columns]

# %%
#Unificamos la data nueva df de indicadores con la data previa
 
concatenated_df2_df5 = pd.concat([concatenated_df2, data_df5], ignore_index=True)

# %%
concatenated_df2_df5
# Out:
#                 País                                          Indicador   Año  \
# 0      United States  Account ownership at a financial institution o...  2022
# 1      United States  Account ownership at a financial institution o...  2021
# 2      United States  Account ownership at a financial institution o...  2020
# 3      United States  Account ownership at a financial institution o...  2019
# 4      United States  Account ownership at a financial institution o...  2018
# ...              ...                                                ...   ...
# 56590  Venezuela, RB  Total alcohol consumption per capita (liters o...  1994
# 56591  Venezuela, RB  Total alcohol consumption per capita (liters o...  1993
# 56592  Venezuela, RB  Total alcohol consumption per capita (liters o...  1992
# 56593  Venezuela, RB  Total alcohol consumption per capita (liters o...  1991
# 56594  Venezuela, RB  Total alcohol consumption per capita (liters o...  1990
#
#        Valor  Unnamed: 0
# 0        NaN         NaN
# 1      94.95         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# ...      ...         ...
# 56590    NaN      6925.0
# 56591    NaN      6926.0
# 56592    NaN      6927.0
# 56593    NaN      6928.0
# 56594    NaN      6929.0
#
# [56595 rows x 5 columns]

# %%
#Vemos la estructura de variables y filas
#Observamos que hay muchos nulos en la columna de los vaores numericos, que haya que analiza en detalle
concatenated_df2_df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56595 entries, 0 to 56594
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        56595 non-null  object
#  1   Indicador   56595 non-null  object
#  2   Año         56595 non-null  object
#  3   Valor       39141 non-null  float64
#  4   Unnamed: 0  6930 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 2.2+ MB

# %%
#Vamos a agrupar los indicadores por países y por año 
# 1. Cambia el tipo de dato de la columna 'Año' a numérico (int)
concatenated_df2_df5['Año'] = pd.to_numeric(concatenated_df2_df5['Año'], errors='coerce')

# 2. Realiza una agregación (por ejemplo, suma) en caso de entradas duplicadas
df_aggregated_df2_df5 = concatenated_df2_df5.groupby(['País', 'Año', 'Indicador'])['Valor'].sum().unstack()

# Esto creará un nuevo DataFrame 'df_aggregated' con cada indicador como una columna individual y las entradas duplicadas se agregan mediante la suma (Ver concepto).

# %%
#Exportamos la tabla final de datos crudos a un csv 
nombre_del_archivo = 'dataset_completo_con_caribe.csv'
df_aggregated_df2_df5.to_csv(nombre_del_archivo, index=False)

# %% [markdown]
# ## Dataset completo

# %%
#Tabla de indicadores por países y año

df_aggregated_df2_df5
# Out:
# Indicador                 Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# País                Año
# Antigua and Barbuda 1990                                               0.00
#                     1991                                               0.00
#                     1992                                               0.00
#                     1993                                               0.00
#                     1994                                               0.00
# ...                                                                     ...
# Venezuela, RB       2018                                               0.00
#                     2019                                               0.00
#                     2020                                               0.00
#                     2021                                              84.39
#                     2022                                               0.00
#
# Indicador                 Birth rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                20.916
#                     1991                                18.504
#                     1992                                19.228
#                     1993                                18.597
#                     1994                                18.990
# ...                                                        ...
# Venezuela, RB       2018                                17.832
#                     2019                                16.888
#                     2020                                16.213
#                     2021                                15.877
#                     2022                                 0.000
#
# Indicador                 CO2 emissions (kg per PPP $ of GDP)  \
# País                Año
# Antigua and Barbuda 1990                             0.301290
#                     1991                             0.289409
#                     1992                             0.276056
#                     1993                             0.260243
#                     1994                             0.242297
# ...                                                       ...
# Venezuela, RB       2018                             0.000000
#                     2019                             0.000000
#                     2020                             0.000000
#                     2021                             0.000000
#                     2022                             0.000000
#
# Indicador                 Capital health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                    0.0
#                     1991                                    0.0
#                     1992                                    0.0
#                     1993                                    0.0
#                     1994                                    0.0
# ...                                                         ...
# Venezuela, RB       2018                                    0.0
#                     2019                                    0.0
#                     2020                                    0.0
#                     2021                                    0.0
#                     2022                                    0.0
#
# Indicador                 Compulsory education, duration (years)  \
# País                Año
# Antigua and Barbuda 1990                                     0.0
#                     1991                                     0.0
#                     1992                                     0.0
#                     1993                                     0.0
#                     1994                                     0.0
# ...                                                          ...
# Venezuela, RB       2018                                    17.0
#                     2019                                    17.0
#                     2020                                    17.0
#                     2021                                    17.0
#                     2022                                     0.0
#
# Indicador                 Control of Corruption: Estimate  \
# País                Año
# Antigua and Barbuda 1990                         0.000000
#                     1991                         0.000000
#                     1992                         0.000000
#                     1993                         0.000000
#                     1994                         0.000000
# ...                                                   ...
# Venezuela, RB       2018                        -1.512038
#                     2019                        -1.527599
#                     2020                        -1.576018
#                     2021                        -1.622492
#                     2022                        -1.651137
#
# Indicador                 Current health expenditure per capita, PPP (current international $)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Venezuela, RB       2018                                         638.613417
#                     2019                                         469.134286
#                     2020                                         590.119233
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 Death rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                 7.666
#                     1991                                 7.753
#                     1992                                 7.745
#                     1993                                 7.666
#                     1994                                 7.533
# ...                                                        ...
# Venezuela, RB       2018                                 6.864
#                     2019                                 7.017
#                     2020                                 7.575
#                     2021                                 8.124
#                     2022                                 0.000
#
# Indicador                 Diabetes prevalence (% of population ages 20 to 79)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Venezuela, RB       2018                                                0.0
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                                9.6
#                     2022                                                0.0
#
# Indicador                 Domestic general government health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                           0.000000
#                     1991                                           0.000000
#                     1992                                           0.000000
#                     1993                                           0.000000
#                     1994                                           0.000000
# ...                                                                     ...
# Venezuela, RB       2018                                           1.245631
#                     2019                                           0.811753
#                     2020                                           1.676635
#                     2021                                           0.000000
#                     2022                                           0.000000
#
# Indicador                 ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País                Año   ...
# Antigua and Barbuda 1990  ...                                        0.0
#                     1991  ...                                        0.0
#                     1992  ...                                        0.0
#                     1993  ...                                        0.0
#                     1994  ...                                        0.0
# ...                       ...                                        ...
# Venezuela, RB       2018  ...                                        0.0
#                     2019  ...                                        0.0
#                     2020  ...                                        0.0
#                     2021  ...                                        0.0
#                     2022  ...                                        0.0
#
# Indicador                 Pregnant women receiving prenatal care (%)  \
# País                Año
# Antigua and Barbuda 1990                                         0.0
#                     1991                                         0.0
#                     1992                                         0.0
#                     1993                                         0.0
#                     1994                                         0.0
# ...                                                              ...
# Venezuela, RB       2018                                         0.0
#                     2019                                         0.0
#                     2020                                         0.0
#                     2021                                         0.0
#                     2022                                         0.0
#
# Indicador                 Prevalence of overweight (% of adults)  \
# País                Año
# Antigua and Barbuda 1990                                    33.7
#                     1991                                    34.4
#                     1992                                    34.9
#                     1993                                    35.5
#                     1994                                    36.1
# ...                                                          ...
# Venezuela, RB       2018                                     0.0
#                     2019                                     0.0
#                     2020                                     0.0
#                     2021                                     0.0
#                     2022                                     0.0
#
# Indicador                 Prevalence of overweight, weight for height (% of children under 5)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
# ...                                                                     ...
# Venezuela, RB       2018                                                0.0
#                     2019                                                0.0
#                     2020                                                0.0
#                     2021                                                0.0
#                     2022                                                0.0
#
# Indicador                 Prevalence of undernourishment (% of population)  \
# País                Año
# Antigua and Barbuda 1990                                               0.0
#                     1991                                               0.0
#                     1992                                               0.0
#                     1993                                               0.0
#                     1994                                               0.0
# ...                                                                    ...
# Venezuela, RB       2018                                              22.7
#                     2019                                              24.9
#                     2020                                              22.9
#                     2021                                               0.0
#                     2022                                               0.0
#
# Indicador                 Rural population (% of total population)  \
# País                Año
# Antigua and Barbuda 1990                                    64.574
#                     1991                                    64.535
#                     1992                                    64.915
#                     1993                                    65.291
#                     1994                                    65.666
# ...                                                            ...
# Venezuela, RB       2018                                    11.792
#                     2019                                    11.760
#                     2020                                    11.721
#                     2021                                    11.675
#                     2022                                    11.622
#
# Indicador                 Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País                Año
# Antigua and Barbuda 1990                                            0.00000
#                     1991                                            0.00000
#                     1992                                            0.00000
#                     1993                                            0.00000
#                     1994                                            0.00000
# ...                                                                     ...
# Venezuela, RB       2018                                            0.00000
#                     2019                                            3.01625
#                     2020                                            0.00000
#                     2021                                            0.00000
#                     2022                                            0.00000
#
# Indicador                 Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País                Año
# Antigua and Barbuda 1990                                              0.000
#                     1991                                              0.000
#                     1992                                              0.000
#                     1993                                              0.000
#                     1994                                              0.000
# ...                                                                     ...
# Venezuela, RB       2018                                              5.020
#                     2019                                              5.092
#                     2020                                              7.530
#                     2021                                              6.471
#                     2022                                              5.328
#
# Indicador                 Urban population  \
# País                Año
# Antigua and Barbuda 1990           22435.0
#                     1991           22568.0
#                     1992           22686.0
#                     1993           22850.0
#                     1994           23029.0
# ...                                    ...
# Venezuela, RB       2018        26308612.0
#                     2019        25564613.0
#                     2020        25151087.0
#                     2021        24907533.0
#                     2022        25012473.0
#
# Indicador                 Urban population (% of total population)
# País                Año
# Antigua and Barbuda 1990                                    35.426
#                     1991                                    35.465
#                     1992                                    35.085
#                     1993                                    34.709
#                     1994                                    34.334
# ...                                                            ...
# Venezuela, RB       2018                                    88.208
#                     2019                                    88.240
#                     2020                                    88.279
#                     2021                                    88.325
#                     2022                                    88.378
#
# [1122 rows x 49 columns]

# %%
#Composición de la tabla, nuevas columnas de indicadores y filas con años/países
df_aggregated_df2_df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 49 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  1122 non-null   float64
#  1   Birth rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  2   CO2 emissions (kg per PPP $ of GDP)                                                                              1122 non-null   float64
#  3   Capital health expenditure (% of GDP)                                                                            1122 non-null   float64
#  4   Compulsory education, duration (years)                                                                           1122 non-null   float64
#  5   Control of Corruption: Estimate                                                                                  1122 non-null   float64
#  6   Current health expenditure per capita, PPP (current international $)                                             1122 non-null   float64
#  7   Death rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  8   Diabetes prevalence (% of population ages 20 to 79)                                                              1122 non-null   float64
#  9   Domestic general government health expenditure (% of GDP)                                                        1122 non-null   float64
#  10  Domestic general government health expenditure per capita, PPP (current international $)                         1122 non-null   float64
#  11  Domestic private health expenditure (% of current health expenditure)                                            1122 non-null   float64
#  12  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                1122 non-null   float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)               1122 non-null   float64
#  14  Fertility rate, total (births per woman)                                                                         1122 non-null   float64
#  15  GDP, PPP (constant 2017 international $)                                                                         1122 non-null   float64
#  16  Gini index                                                                                                       1122 non-null   float64
#  17  Government expenditure on education, total (% of GDP)                                                            1122 non-null   float64
#  18  Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                               1122 non-null   float64
#  19  Life expectancy at birth, female (years)                                                                         1122 non-null   float64
#  20  Life expectancy at birth, male (years)                                                                           1122 non-null   float64
#  21  Life expectancy at birth, total (years)                                                                          1122 non-null   float64
#  22  Literacy rate, adult total (% of people ages 15 and above)                                                       1122 non-null   float64
#  23  Mortality rate, adult, female (per 1,000 female adults)                                                          1122 non-null   float64
#  24  Mortality rate, adult, male (per 1,000 male adults)                                                              1122 non-null   float64
#  25  Mortality rate, infant (per 1,000 live births)                                                                   1122 non-null   float64
#  26  Number of neonatal deaths                                                                                        1122 non-null   float64
#  27  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                     1122 non-null   float64
#  28  People using at least basic sanitation services (% of population)                                                1122 non-null   float64
#  29  People using safely managed drinking water services (% of population)                                            1122 non-null   float64
#  30  Political Stability and Absence of Violence/Terrorism: Estimate                                                  1122 non-null   float64
#  31  Population ages 80 and above, female                                                                             1122 non-null   float64
#  32  Population ages 80 and above, male                                                                               1122 non-null   float64
#  33  Population density (people per sq. km of land area)                                                              1122 non-null   float64
#  34  Population, female                                                                                               1122 non-null   float64
#  35  Population, female (% of total population)                                                                       1122 non-null   float64
#  36  Population, male                                                                                                 1122 non-null   float64
#  37  Population, male (% of total population)                                                                         1122 non-null   float64
#  38  Population, total                                                                                                1122 non-null   float64
#  39  Poverty gap at $6.85 a day (2017 PPP) (%)                                                                        1122 non-null   float64
#  40  Pregnant women receiving prenatal care (%)                                                                       1122 non-null   float64
#  41  Prevalence of overweight (% of adults)                                                                           1122 non-null   float64
#  42  Prevalence of overweight, weight for height (% of children under 5)                                              1122 non-null   float64
#  43  Prevalence of undernourishment (% of population)                                                                 1122 non-null   float64
#  44  Rural population (% of total population)                                                                         1122 non-null   float64
#  45  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)             1122 non-null   float64
#  46  Unemployment, total (% of total labor force) (modeled ILO estimate)                                              1122 non-null   float64
#  47  Urban population                                                                                                 1122 non-null   float64
#  48  Urban population (% of total population)                                                                         1122 non-null   float64
# dtypes: float64(49)
# memory usage: 432.4+ KB

# %%
# Cambiar el nombre de la columna "Pais" a "Country" y "Año" a Year" para unificar idioma
df_aggregated_df2_df5 = df_aggregated_df2_df5.rename(columns={'País': 'Country','Año' : 'Year', 'Indicador': 'Indicator'})

# %% [markdown]
# # Limpieza de datos

# %%
# Para contar tanto los valores nulos (NaN) como los ceros:
nulos_ceros = df_aggregated_df2_df5.isnull().sum() + (df_aggregated_df2_df5 == 0).sum()

print(nulos_ceros) 
print("(",(nulos_ceros/1122)*100,")%")
# Out:
# Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    1034
# Birth rate, crude (per 1,000 people)                                                                                 34
# CO2 emissions (kg per PPP $ of GDP)                                                                                 139
# Capital health expenditure (% of GDP)                                                                               497
# Compulsory education, duration (years)                                                                              279
# Control of Corruption: Estimate                                                                                     321
# Current health expenditure per capita, PPP (current international $)                                                426
# Death rate, crude (per 1,000 people)                                                                                 34
# Diabetes prevalence (% of population ages 20 to 79)                                                                1048
# Domestic general government health expenditure (% of GDP)                                                           426
# Domestic general government health expenditure per capita, PPP (current international $)                            426
# Domestic private health expenditure (% of current health expenditure)                                               426
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  1012
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                  777
# Fertility rate, total (births per woman)                                                                             34
# GDP, PPP (constant 2017 international $)                                                                             66
# Gini index                                                                                                          687
# Government expenditure on education, total (% of GDP)                                                               439
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 1097
# Life expectancy at birth, female (years)                                                                             34
# Life expectancy at birth, male (years)                                                                               34
# Life expectancy at birth, total (years)                                                                              34
# Literacy rate, adult total (% of people ages 15 and above)                                                          930
# Mortality rate, adult, female (per 1,000 female adults)                                                              36
# Mortality rate, adult, male (per 1,000 male adults)                                                                  36
# Mortality rate, infant (per 1,000 live births)                                                                       66
# Number of neonatal deaths                                                                                            66
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                        740
# People using at least basic sanitation services (% of population)                                                   374
# People using safely managed drinking water services (% of population)                                               743
# Political Stability and Absence of Violence/Terrorism: Estimate                                                     310
# Population ages 80 and above, female                                                                                  0
# Population ages 80 and above, male                                                                                    0
# Population density (people per sq. km of land area)                                                                  34
# Population, female                                                                                                    0
# Population, female (% of total population)                                                                            0
# Population, male                                                                                                      0
# Population, male (% of total population)                                                                              0
# Population, total                                                                                                     0
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                           685
# Pregnant women receiving prenatal care (%)                                                                          918
# Prevalence of overweight (% of adults)                                                                              231
# Prevalence of overweight, weight for height (% of children under 5)                                                 932
# Prevalence of undernourishment (% of population)                                                                    542
# Rural population (% of total population)                                                                             30
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)                957
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                 130
# Urban population                                                                                                      0
# Urban population (% of total population)                                                                              0
# dtype: int64
# ( Indicador
# Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)    92.156863
# Birth rate, crude (per 1,000 people)                                                                                3.030303
# CO2 emissions (kg per PPP $ of GDP)                                                                                12.388592
# Capital health expenditure (% of GDP)                                                                              44.295900
# Compulsory education, duration (years)                                                                             24.866310
# Control of Corruption: Estimate                                                                                    28.609626
# Current health expenditure per capita, PPP (current international $)                                               37.967914
# Death rate, crude (per 1,000 people)                                                                                3.030303
# Diabetes prevalence (% of population ages 20 to 79)                                                                93.404635
# Domestic general government health expenditure (% of GDP)                                                          37.967914
# Domestic general government health expenditure per capita, PPP (current international $)                           37.967914
# Domestic private health expenditure (% of current health expenditure)                                              37.967914
# Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                  90.196078
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)                 69.251337
# Fertility rate, total (births per woman)                                                                            3.030303
# GDP, PPP (constant 2017 international $)                                                                            5.882353
# Gini index                                                                                                         61.229947
# Government expenditure on education, total (% of GDP)                                                              39.126560
# Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                                 97.771836
# Life expectancy at birth, female (years)                                                                            3.030303
# Life expectancy at birth, male (years)                                                                              3.030303
# Life expectancy at birth, total (years)                                                                             3.030303
# Literacy rate, adult total (% of people ages 15 and above)                                                         82.887701
# Mortality rate, adult, female (per 1,000 female adults)                                                             3.208556
# Mortality rate, adult, male (per 1,000 male adults)                                                                 3.208556
# Mortality rate, infant (per 1,000 live births)                                                                      5.882353
# Number of neonatal deaths                                                                                           5.882353
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                       65.953654
# People using at least basic sanitation services (% of population)                                                  33.333333
# People using safely managed drinking water services (% of population)                                              66.221034
# Political Stability and Absence of Violence/Terrorism: Estimate                                                    27.629234
# Population ages 80 and above, female                                                                                0.000000
# Population ages 80 and above, male                                                                                  0.000000
# Population density (people per sq. km of land area)                                                                 3.030303
# Population, female                                                                                                  0.000000
# Population, female (% of total population)                                                                          0.000000
# Population, male                                                                                                    0.000000
# Population, male (% of total population)                                                                            0.000000
# Population, total                                                                                                   0.000000
# Poverty gap at $6.85 a day (2017 PPP) (%)                                                                          61.051693
# Pregnant women receiving prenatal care (%)                                                                         81.818182
# Prevalence of overweight (% of adults)                                                                             20.588235
# Prevalence of overweight, weight for height (% of children under 5)                                                83.065954
# Prevalence of undernourishment (% of population)                                                                   48.306595
# Rural population (% of total population)                                                                            2.673797
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)               85.294118
# Unemployment, total (% of total labor force) (modeled ILO estimate)                                                11.586453
# Urban population                                                                                                    0.000000
# Urban population (% of total population)                                                                            0.000000
# dtype: float64 )%

# %%
df_aggregated_df2_df5.head()
# Out:
# Indicador                 Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Birth rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                20.916
#                     1991                                18.504
#                     1992                                19.228
#                     1993                                18.597
#                     1994                                18.990
#
# Indicador                 CO2 emissions (kg per PPP $ of GDP)  \
# País                Año
# Antigua and Barbuda 1990                             0.301290
#                     1991                             0.289409
#                     1992                             0.276056
#                     1993                             0.260243
#                     1994                             0.242297
#
# Indicador                 Capital health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                    0.0
#                     1991                                    0.0
#                     1992                                    0.0
#                     1993                                    0.0
#                     1994                                    0.0
#
# Indicador                 Compulsory education, duration (years)  \
# País                Año
# Antigua and Barbuda 1990                                     0.0
#                     1991                                     0.0
#                     1992                                     0.0
#                     1993                                     0.0
#                     1994                                     0.0
#
# Indicador                 Control of Corruption: Estimate  \
# País                Año
# Antigua and Barbuda 1990                              0.0
#                     1991                              0.0
#                     1992                              0.0
#                     1993                              0.0
#                     1994                              0.0
#
# Indicador                 Current health expenditure per capita, PPP (current international $)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Death rate, crude (per 1,000 people)  \
# País                Año
# Antigua and Barbuda 1990                                 7.666
#                     1991                                 7.753
#                     1992                                 7.745
#                     1993                                 7.666
#                     1994                                 7.533
#
# Indicador                 Diabetes prevalence (% of population ages 20 to 79)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Domestic general government health expenditure (% of GDP)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País                Año   ...
# Antigua and Barbuda 1990  ...                                        0.0
#                     1991  ...                                        0.0
#                     1992  ...                                        0.0
#                     1993  ...                                        0.0
#                     1994  ...                                        0.0
#
# Indicador                 Pregnant women receiving prenatal care (%)  \
# País                Año
# Antigua and Barbuda 1990                                         0.0
#                     1991                                         0.0
#                     1992                                         0.0
#                     1993                                         0.0
#                     1994                                         0.0
#
# Indicador                 Prevalence of overweight (% of adults)  \
# País                Año
# Antigua and Barbuda 1990                                    33.7
#                     1991                                    34.4
#                     1992                                    34.9
#                     1993                                    35.5
#                     1994                                    36.1
#
# Indicador                 Prevalence of overweight, weight for height (% of children under 5)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Prevalence of undernourishment (% of population)  \
# País                Año
# Antigua and Barbuda 1990                                               0.0
#                     1991                                               0.0
#                     1992                                               0.0
#                     1993                                               0.0
#                     1994                                               0.0
#
# Indicador                 Rural population (% of total population)  \
# País                Año
# Antigua and Barbuda 1990                                    64.574
#                     1991                                    64.535
#                     1992                                    64.915
#                     1993                                    65.291
#                     1994                                    65.666
#
# Indicador                 Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País                Año
# Antigua and Barbuda 1990                                                0.0
#                     1991                                                0.0
#                     1992                                                0.0
#                     1993                                                0.0
#                     1994                                                0.0
#
# Indicador                 Urban population  \
# País                Año
# Antigua and Barbuda 1990           22435.0
#                     1991           22568.0
#                     1992           22686.0
#                     1993           22850.0
#                     1994           23029.0
#
# Indicador                 Urban population (% of total population)
# País                Año
# Antigua and Barbuda 1990                                    35.426
#                     1991                                    35.465
#                     1992                                    35.085
#                     1993                                    34.709
#                     1994                                    34.334
#
# [5 rows x 49 columns]

# %%
df_aggregated_df2_df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 49 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)  1122 non-null   float64
#  1   Birth rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  2   CO2 emissions (kg per PPP $ of GDP)                                                                              1122 non-null   float64
#  3   Capital health expenditure (% of GDP)                                                                            1122 non-null   float64
#  4   Compulsory education, duration (years)                                                                           1122 non-null   float64
#  5   Control of Corruption: Estimate                                                                                  1122 non-null   float64
#  6   Current health expenditure per capita, PPP (current international $)                                             1122 non-null   float64
#  7   Death rate, crude (per 1,000 people)                                                                             1122 non-null   float64
#  8   Diabetes prevalence (% of population ages 20 to 79)                                                              1122 non-null   float64
#  9   Domestic general government health expenditure (% of GDP)                                                        1122 non-null   float64
#  10  Domestic general government health expenditure per capita, PPP (current international $)                         1122 non-null   float64
#  11  Domestic private health expenditure (% of current health expenditure)                                            1122 non-null   float64
#  12  Educational attainment, at least Bachelor's or equivalent, population 25+, total (%) (cumulative)                1122 non-null   float64
#  13  Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)               1122 non-null   float64
#  14  Fertility rate, total (births per woman)                                                                         1122 non-null   float64
#  15  GDP, PPP (constant 2017 international $)                                                                         1122 non-null   float64
#  16  Gini index                                                                                                       1122 non-null   float64
#  17  Government expenditure on education, total (% of GDP)                                                            1122 non-null   float64
#  18  Infant and young child feeding practices, all 3 IYCF (% children ages 6-23 months)                               1122 non-null   float64
#  19  Life expectancy at birth, female (years)                                                                         1122 non-null   float64
#  20  Life expectancy at birth, male (years)                                                                           1122 non-null   float64
#  21  Life expectancy at birth, total (years)                                                                          1122 non-null   float64
#  22  Literacy rate, adult total (% of people ages 15 and above)                                                       1122 non-null   float64
#  23  Mortality rate, adult, female (per 1,000 female adults)                                                          1122 non-null   float64
#  24  Mortality rate, adult, male (per 1,000 male adults)                                                              1122 non-null   float64
#  25  Mortality rate, infant (per 1,000 live births)                                                                   1122 non-null   float64
#  26  Number of neonatal deaths                                                                                        1122 non-null   float64
#  27  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                     1122 non-null   float64
#  28  People using at least basic sanitation services (% of population)                                                1122 non-null   float64
#  29  People using safely managed drinking water services (% of population)                                            1122 non-null   float64
#  30  Political Stability and Absence of Violence/Terrorism: Estimate                                                  1122 non-null   float64
#  31  Population ages 80 and above, female                                                                             1122 non-null   float64
#  32  Population ages 80 and above, male                                                                               1122 non-null   float64
#  33  Population density (people per sq. km of land area)                                                              1122 non-null   float64
#  34  Population, female                                                                                               1122 non-null   float64
#  35  Population, female (% of total population)                                                                       1122 non-null   float64
#  36  Population, male                                                                                                 1122 non-null   float64
#  37  Population, male (% of total population)                                                                         1122 non-null   float64
#  38  Population, total                                                                                                1122 non-null   float64
#  39  Poverty gap at $6.85 a day (2017 PPP) (%)                                                                        1122 non-null   float64
#  40  Pregnant women receiving prenatal care (%)                                                                       1122 non-null   float64
#  41  Prevalence of overweight (% of adults)                                                                           1122 non-null   float64
#  42  Prevalence of overweight, weight for height (% of children under 5)                                              1122 non-null   float64
#  43  Prevalence of undernourishment (% of population)                                                                 1122 non-null   float64
#  44  Rural population (% of total population)                                                                         1122 non-null   float64
#  45  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)             1122 non-null   float64
#  46  Unemployment, total (% of total labor force) (modeled ILO estimate)                                              1122 non-null   float64
#  47  Urban population                                                                                                 1122 non-null   float64
#  48  Urban population (% of total population)                                                                         1122 non-null   float64
# dtypes: float64(49)
# memory usage: 432.4+ KB

# %% [markdown]
# ## Eliminando variables con la mayor participación de valores nulos

# %%
# Eliminamos columnas que tienen más de 65% de nulos
#Dejamos aún algunas columnas que tiene muchos nulos evidentes, y dejamos aquellos que podrían mejorar luego de la limpieza de datos.
# Lista de palabras clave para las columnas a eliminar
palabras_a_eliminar = [
    "Account ownership",
    "Educational attainment,",
    "Educational attainment,",
    "Infant and young",
    "Literacy rate,"
]

# Encuentra y elimina las columnas que contienen alguna de las palabras clave
columnas_a_eliminar = [col for col in df_aggregated_df2_df5.columns if any(palabra in col for palabra in palabras_a_eliminar)]
df_filtrado_nulos = df_aggregated_df2_df5.drop(columns=columnas_a_eliminar)

# %%
#Eliminar Columna indicador Diabetes en niños

columna_a_eliminar = next((col for col in df_filtrado_nulos.columns if col.startswith("Diabetes prevalence") and "child" in col), None)

if columna_a_eliminar is not None:
    df_filtrado_nulos = df_filtrado_nulos.drop(columns=columna_a_eliminar)

# %%
df_filtrado_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1122 entries, ('Antigua and Barbuda', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 44 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                                  1122 non-null   float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                                   1122 non-null   float64
#  2   Capital health expenditure (% of GDP)                                                                 1122 non-null   float64
#  3   Compulsory education, duration (years)                                                                1122 non-null   float64
#  4   Control of Corruption: Estimate                                                                       1122 non-null   float64
#  5   Current health expenditure per capita, PPP (current international $)                                  1122 non-null   float64
#  6   Death rate, crude (per 1,000 people)                                                                  1122 non-null   float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                                   1122 non-null   float64
#  8   Domestic general government health expenditure (% of GDP)                                             1122 non-null   float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)              1122 non-null   float64
#  10  Domestic private health expenditure (% of current health expenditure)                                 1122 non-null   float64
#  11  Fertility rate, total (births per woman)                                                              1122 non-null   float64
#  12  GDP, PPP (constant 2017 international $)                                                              1122 non-null   float64
#  13  Gini index                                                                                            1122 non-null   float64
#  14  Government expenditure on education, total (% of GDP)                                                 1122 non-null   float64
#  15  Life expectancy at birth, female (years)                                                              1122 non-null   float64
#  16  Life expectancy at birth, male (years)                                                                1122 non-null   float64
#  17  Life expectancy at birth, total (years)                                                               1122 non-null   float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                               1122 non-null   float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                                   1122 non-null   float64
#  20  Mortality rate, infant (per 1,000 live births)                                                        1122 non-null   float64
#  21  Number of neonatal deaths                                                                             1122 non-null   float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)          1122 non-null   float64
#  23  People using at least basic sanitation services (% of population)                                     1122 non-null   float64
#  24  People using safely managed drinking water services (% of population)                                 1122 non-null   float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                                       1122 non-null   float64
#  26  Population ages 80 and above, female                                                                  1122 non-null   float64
#  27  Population ages 80 and above, male                                                                    1122 non-null   float64
#  28  Population density (people per sq. km of land area)                                                   1122 non-null   float64
#  29  Population, female                                                                                    1122 non-null   float64
#  30  Population, female (% of total population)                                                            1122 non-null   float64
#  31  Population, male                                                                                      1122 non-null   float64
#  32  Population, male (% of total population)                                                              1122 non-null   float64
#  33  Population, total                                                                                     1122 non-null   float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                             1122 non-null   float64
#  35  Pregnant women receiving prenatal care (%)                                                            1122 non-null   float64
#  36  Prevalence of overweight (% of adults)                                                                1122 non-null   float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                                   1122 non-null   float64
#  38  Prevalence of undernourishment (% of population)                                                      1122 non-null   float64
#  39  Rural population (% of total population)                                                              1122 non-null   float64
#  40  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  1122 non-null   float64
#  41  Unemployment, total (% of total labor force) (modeled ILO estimate)                                   1122 non-null   float64
#  42  Urban population                                                                                      1122 non-null   float64
#  43  Urban population (% of total population)                                                              1122 non-null   float64
# dtypes: float64(44)
# memory usage: 388.6+ KB

# %% [markdown]
# ## Limpieza eliminando los países del Caribe (menos de dos millones de habitantes)

# %%
#La base de datos mantiene aún muchos nulos en datos de países de las islas del Caribe.
#Para aumentar la calidad de los datos, vamos a quitar del análisis los países con una población menor a 2 millones de personas, que básicamente son las islas mencionadas más pequeñas.
#Umbral = 2000000

# Define un umbral de población (2 millones en este caso)
umbral_población = 2000000

# Filtra los países con población mayor al umbral
df_filtrado_nulos_Sin_Caribe = df_filtrado_nulos.groupby('País').filter(lambda x: x['Population, total'].max() > umbral_población)

# %%
df_filtrado_nulos_Sin_Caribe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 759 entries, ('Argentina', 1990) to ('Venezuela, RB', 2022)
# Data columns (total 44 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Birth rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  1   CO2 emissions (kg per PPP $ of GDP)                                                                   759 non-null    float64
#  2   Capital health expenditure (% of GDP)                                                                 759 non-null    float64
#  3   Compulsory education, duration (years)                                                                759 non-null    float64
#  4   Control of Corruption: Estimate                                                                       759 non-null    float64
#  5   Current health expenditure per capita, PPP (current international $)                                  759 non-null    float64
#  6   Death rate, crude (per 1,000 people)                                                                  759 non-null    float64
#  7   Diabetes prevalence (% of population ages 20 to 79)                                                   759 non-null    float64
#  8   Domestic general government health expenditure (% of GDP)                                             759 non-null    float64
#  9   Domestic general government health expenditure per capita, PPP (current international $)              759 non-null    float64
#  10  Domestic private health expenditure (% of current health expenditure)                                 759 non-null    float64
#  11  Fertility rate, total (births per woman)                                                              759 non-null    float64
#  12  GDP, PPP (constant 2017 international $)                                                              759 non-null    float64
#  13  Gini index                                                                                            759 non-null    float64
#  14  Government expenditure on education, total (% of GDP)                                                 759 non-null    float64
#  15  Life expectancy at birth, female (years)                                                              759 non-null    float64
#  16  Life expectancy at birth, male (years)                                                                759 non-null    float64
#  17  Life expectancy at birth, total (years)                                                               759 non-null    float64
#  18  Mortality rate, adult, female (per 1,000 female adults)                                               759 non-null    float64
#  19  Mortality rate, adult, male (per 1,000 male adults)                                                   759 non-null    float64
#  20  Mortality rate, infant (per 1,000 live births)                                                        759 non-null    float64
#  21  Number of neonatal deaths                                                                             759 non-null    float64
#  22  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)          759 non-null    float64
#  23  People using at least basic sanitation services (% of population)                                     759 non-null    float64
#  24  People using safely managed drinking water services (% of population)                                 759 non-null    float64
#  25  Political Stability and Absence of Violence/Terrorism: Estimate                                       759 non-null    float64
#  26  Population ages 80 and above, female                                                                  759 non-null    float64
#  27  Population ages 80 and above, male                                                                    759 non-null    float64
#  28  Population density (people per sq. km of land area)                                                   759 non-null    float64
#  29  Population, female                                                                                    759 non-null    float64
#  30  Population, female (% of total population)                                                            759 non-null    float64
#  31  Population, male                                                                                      759 non-null    float64
#  32  Population, male (% of total population)                                                              759 non-null    float64
#  33  Population, total                                                                                     759 non-null    float64
#  34  Poverty gap at $6.85 a day (2017 PPP) (%)                                                             759 non-null    float64
#  35  Pregnant women receiving prenatal care (%)                                                            759 non-null    float64
#  36  Prevalence of overweight (% of adults)                                                                759 non-null    float64
#  37  Prevalence of overweight, weight for height (% of children under 5)                                   759 non-null    float64
#  38  Prevalence of undernourishment (% of population)                                                      759 non-null    float64
#  39  Rural population (% of total population)                                                              759 non-null    float64
#  40  Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  759 non-null    float64
#  41  Unemployment, total (% of total labor force) (modeled ILO estimate)                                   759 non-null    float64
#  42  Urban population                                                                                      759 non-null    float64
#  43  Urban population (% of total population)                                                              759 non-null    float64
# dtypes: float64(44)
# memory usage: 263.1+ KB

# %%
df_filtrado_nulos_Sin_Caribe.head()
# Out:
# Indicador       Birth rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                21.989
#           1991                                21.844
#           1992                                21.683
#           1993                                21.570
#           1994                                21.419
#
# Indicador       CO2 emissions (kg per PPP $ of GDP)  \
# País      Año
# Argentina 1990                             0.427859
#           1991                             0.400371
#           1992                             0.369563
#           1993                             0.340845
#           1994                             0.320044
#
# Indicador       Capital health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                    0.0
#           1991                                    0.0
#           1992                                    0.0
#           1993                                    0.0
#           1994                                    0.0
#
# Indicador       Compulsory education, duration (years)  \
# País      Año
# Argentina 1990                                     0.0
#           1991                                     0.0
#           1992                                     0.0
#           1993                                     0.0
#           1994                                     0.0
#
# Indicador       Control of Corruption: Estimate  \
# País      Año
# Argentina 1990                              0.0
#           1991                              0.0
#           1992                              0.0
#           1993                              0.0
#           1994                              0.0
#
# Indicador       Current health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Death rate, crude (per 1,000 people)  \
# País      Año
# Argentina 1990                                 7.743
#           1991                                 7.536
#           1992                                 7.595
#           1993                                 7.631
#           1994                                 7.403
#
# Indicador       Diabetes prevalence (% of population ages 20 to 79)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure (% of GDP)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Domestic general government health expenditure per capita, PPP (current international $)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# País      Año   ...
# Argentina 1990  ...                                        0.0
#           1991  ...                                        4.5
#           1992  ...                                        5.0
#           1993  ...                                        5.5
#           1994  ...                                        5.7
#
# Indicador       Pregnant women receiving prenatal care (%)  \
# País      Año
# Argentina 1990                                         0.0
#           1991                                         0.0
#           1992                                         0.0
#           1993                                        95.0
#           1994                                         0.0
#
# Indicador       Prevalence of overweight (% of adults)  \
# País      Año
# Argentina 1990                                    48.7
#           1991                                    49.3
#           1992                                    49.9
#           1993                                    50.5
#           1994                                    51.1
#
# Indicador       Prevalence of overweight, weight for height (% of children under 5)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                               11.1
#
# Indicador       Prevalence of undernourishment (% of population)  \
# País      Año
# Argentina 1990                                               0.0
#           1991                                               0.0
#           1992                                               0.0
#           1993                                               0.0
#           1994                                               0.0
#
# Indicador       Rural population (% of total population)  \
# País      Año
# Argentina 1990                                    13.016
#           1991                                    12.672
#           1992                                    12.458
#           1993                                    12.248
#           1994                                    12.040
#
# Indicador       Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# País      Año
# Argentina 1990                                                0.0
#           1991                                                0.0
#           1992                                                0.0
#           1993                                                0.0
#           1994                                                0.0
#
# Indicador       Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# País      Año
# Argentina 1990                                               0.00
#           1991                                               5.44
#           1992                                               6.36
#           1993                                              10.10
#           1994                                              11.76
#
# Indicador       Urban population  Urban population (% of total population)
# País      Año
# Argentina 1990        28389540.0                                    86.984
#           1991        28910601.0                                    87.328
#           1992        29386348.0                                    87.542
#           1993        29859584.0                                    87.752
#           1994        30336257.0                                    87.960
#
# [5 rows x 44 columns]

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado df_filtrado_nulos_Sin_Caribe
# y que 'País' y 'Año' están en el índice

# 1. Filtrar las columnas numéricas
columnas_numericas = df_filtrado_nulos_Sin_Caribe.select_dtypes(include='number')

# 2. Crear un DataFrame vacío para almacenar las correlaciones por país
correlaciones_por_pais = pd.DataFrame()

# 3. Iterar a través de los países y calcular las correlaciones para cada uno
for pais in df_filtrado_nulos_Sin_Caribe.index.get_level_values('País').unique():
    datos_pais = df_filtrado_nulos_Sin_Caribe.xs(pais, level='País', drop_level=False)
    correlaciones = datos_pais.corrwith(datos_pais['Life expectancy at birth, total (years)'])
    correlaciones_por_pais = pd.concat([correlaciones_por_pais, correlaciones], axis=1, sort=False)

# Transponer el DataFrame de correlaciones para que los países sean las filas y los indicadores las columnas
correlaciones_por_pais = correlaciones_por_pais.T

# Imprimir las correlaciones
print("Correlaciones de indicadores numéricos por país con Esperanza de Vida:")
print(correlaciones_por_pais)
# Out:
# Correlaciones de indicadores numéricos por país con Esperanza de Vida:
#    Birth rate, crude (per 1,000 people)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                              0.769019                             0.400697
# 0                              0.553211                             0.159017
# 0                              0.477770                             0.483241
# 0                              0.767757                             0.348921
# 0                              0.542633                             0.292770
# 0                              0.470423                             0.229455
# 0                              0.558151                             0.378914
# 0                              0.676471                                  NaN
# 0                              0.660309                             0.311954
# 0                              0.593779                             0.484526
# 0                              0.498134                             0.538358
# 0                              0.541473                             0.575301
# 0                              0.499552                             0.503997
# 0                              0.503109                                  NaN
# 0                              0.552385                             0.418508
# 0                              0.627683                             0.454843
# 0                              0.516760                             0.290397
# 0                              0.750761                             0.315505
# 0                              0.636636                             0.540965
# 0                              0.528817                             0.297951
# 0                              0.817973                             0.306141
# 0                              0.713190                             0.392865
# 0                              0.745975                             0.240057
#
#    Capital health expenditure (% of GDP)  \
# 0                               0.219555
# 0                               0.433155
# 0                               0.275348
# 0                               0.334708
# 0                               0.289604
# 0                               0.226812
# 0                               0.256316
# 0                               0.189297
# 0                               0.085722
# 0                               0.324360
# 0                               0.345090
# 0                               0.339533
# 0                               0.201676
# 0                                    NaN
# 0                               0.206841
# 0                               0.239385
# 0                               0.267110
# 0                               0.327275
# 0                               0.285176
# 0                               0.397175
# 0                               0.306199
# 0                               0.254943
# 0                               0.157030
#
#    Compulsory education, duration (years)  Control of Corruption: Estimate  \
# 0                               -0.043365                         0.098457
# 0                                0.101643                        -0.002336
# 0                               -0.009387                         0.213800
# 0                               -0.008530                         0.023635
# 0                                0.021668                         0.097501
# 0                                0.015002                        -0.012546
# 0                               -0.071576                         0.013785
# 0                               -0.016219                         0.286060
# 0                               -0.040619                        -0.174798
# 0                               -0.005803                        -0.043671
# 0                                0.130375                         0.099921
# 0                                0.139860                        -0.075180
# 0                                0.008218                         0.047049
# 0                                0.034464                         0.038268
# 0                               -0.103166                        -0.139739
# 0                               -0.073336                         0.253710
# 0                                0.100461                         0.070447
# 0                                0.036894                         0.130698
# 0                               -0.045245                         0.050809
# 0                                0.097928                         0.185178
# 0                               -0.030809                         0.032817
# 0                               -0.051223                        -0.127024
# 0                                0.284241                         0.219000
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                           0.312727
# 0                                           0.415349
# 0                                           0.408673
# 0                                           0.337380
# 0                                           0.341573
# 0                                           0.380711
# 0                                           0.273027
# 0                                           0.281334
# 0                                           0.332150
# 0                                           0.346861
# 0                                           0.456054
# 0                                           0.417250
# 0                                           0.390747
# 0                                                NaN
# 0                                           0.234545
# 0                                           0.304027
# 0                                           0.422321
# 0                                           0.312294
# 0                                           0.330873
# 0                                           0.422354
# 0                                           0.293550
# 0                                           0.314885
# 0                                           0.237530
#
#    Death rate, crude (per 1,000 people)  \
# 0                              0.967689
# 0                              0.495251
# 0                              0.887702
# 0                              0.985748
# 0                              0.901336
# 0                              0.812565
# 0                              0.762766
# 0                              0.707088
# 0                              0.973464
# 0                              0.772898
# 0                              0.458220
# 0                              0.280488
# 0                              0.515541
# 0                              0.921301
# 0                              0.886043
# 0                              0.648494
# 0                              0.571413
# 0                              0.902634
# 0                              0.887582
# 0                              0.867643
# 0                              0.924958
# 0                              0.950170
# 0                              0.728668
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                           0.062824
# 0                                           0.079589
# 0                                           0.080030
# 0                                           0.079702
# 0                                           0.074265
# 0                                           0.067595
# 0                                           0.047761
# 0                                           0.035484
# 0                                           0.077480
# 0                                           0.064582
# 0                                           0.071866
# 0                                           0.118295
# 0                                           0.070979
# 0                                           0.076343
# 0                                           0.049606
# 0                                           0.041814
# 0                                           0.123874
# 0                                           0.070437
# 0                                           0.049830
# 0                                           0.074705
# 0                                           0.047076
# 0                                           0.047637
# 0                                           0.034409
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.323658
# 0                                           0.452302
# 0                                           0.401578
# 0                                           0.345970
# 0                                           0.370077
# 0                                           0.395621
# 0                                           0.299825
# 0                                           0.311878
# 0                                           0.334782
# 0                                           0.335491
# 0                                           0.452813
# 0                                           0.319906
# 0                                           0.408071
# 0                                                NaN
# 0                                           0.236417
# 0                                           0.319137
# 0                                           0.427502
# 0                                           0.358245
# 0                                           0.334579
# 0                                           0.435403
# 0                                           0.302031
# 0                                           0.325513
# 0                                           0.222923
#
#    Domestic general government health expenditure per capita, PPP (current international $)  \
# 0                                           0.303186
# 0                                           0.387887
# 0                                           0.407687
# 0                                           0.336460
# 0                                           0.317375
# 0                                           0.381242
# 0                                           0.267628
# 0                                           0.277205
# 0                                           0.301088
# 0                                           0.307159
# 0                                           0.451146
# 0                                           0.352708
# 0                                           0.395385
# 0                                                NaN
# 0                                           0.222887
# 0                                           0.291070
# 0                                           0.401957
# 0                                           0.317979
# 0                                           0.308967
# 0                                           0.401184
# 0                                           0.283770
# 0                                           0.294063
# 0                                           0.234633
#
#    ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# 0  ...                                   0.194124
# 0  ...                                   0.242822
# 0  ...                                   0.159368
# 0  ...                                   0.179966
# 0  ...                                   0.032427
# 0  ...                                   0.254229
# 0  ...                                   0.116808
# 0  ...                                        NaN
# 0  ...                                   0.279958
# 0  ...                                   0.069732
# 0  ...                                   0.067863
# 0  ...                                   0.079528
# 0  ...                                   0.284475
# 0  ...                                        NaN
# 0  ...                                   0.070377
# 0  ...                                   0.158055
# 0  ...                                   0.006258
# 0  ...                                   0.192145
# 0  ...                                   0.099204
# 0  ...                                   0.317862
# 0  ...                                   0.661656
# 0  ...                                   0.185170
# 0  ...                                   0.111759
#
#    Pregnant women receiving prenatal care (%)  \
# 0                                    0.075038
# 0                                    0.123391
# 0                                    0.119130
# 0                                    0.036705
# 0                                   -0.011661
# 0                                    0.101640
# 0                                    0.103081
# 0                                    0.167485
# 0                                    0.109584
# 0                                    0.021434
# 0                                    0.081639
# 0                                    0.118108
# 0                                    0.086129
# 0                                         NaN
# 0                                    0.096500
# 0                                    0.116530
# 0                                    0.035905
# 0                                    0.096232
# 0                                    0.065305
# 0                                    0.354986
# 0                                         NaN
# 0                                    0.072486
# 0                                    0.056411
#
#    Prevalence of overweight (% of adults)  \
# 0                                0.335196
# 0                                0.322811
# 0                                0.307279
# 0                                0.330184
# 0                                0.319733
# 0                                0.319394
# 0                                0.352482
# 0                                0.372768
# 0                                0.323019
# 0                                0.348186
# 0                                0.310366
# 0                                0.251114
# 0                                0.325196
# 0                                     NaN
# 0                                0.372399
# 0                                0.403086
# 0                                0.270338
# 0                                0.330770
# 0                                0.327988
# 0                                0.309750
# 0                                0.365604
# 0                                0.339690
# 0                                0.396649
#
#    Prevalence of overweight, weight for height (% of children under 5)  \
# 0                                           0.058614
# 0                                           0.094767
# 0                                           0.085662
# 0                                           0.029653
# 0                                           0.120969
# 0                                           0.082999
# 0                                           0.056814
# 0                                           0.047309
# 0                                           0.096929
# 0                                           0.143206
# 0                                           0.055224
# 0                                           0.093093
# 0                                           0.096276
# 0                                                NaN
# 0                                           0.198943
# 0                                           0.120609
# 0                                           0.038192
# 0                                           0.084968
# 0                                           0.086462
# 0                                           0.310057
# 0                                           0.151683
# 0                                           0.134842
# 0                                           0.216618
#
#    Prevalence of undernourishment (% of population)  \
# 0                                          0.294207
# 0                                          0.368006
# 0                                          0.242975
# 0                                          0.302708
# 0                                          0.335737
# 0                                          0.337671
# 0                                          0.274131
# 0                                          0.311234
# 0                                          0.222665
# 0                                          0.279982
# 0                                          0.419242
# 0                                          0.395274
# 0                                          0.335524
# 0                                          0.334937
# 0                                          0.238238
# 0                                          0.293922
# 0                                          0.355280
# 0                                          0.243878
# 0                                          0.309716
# 0                                          0.279973
# 0                                          0.292696
# 0                                          0.290468
# 0                                          0.134534
#
#    Rural population (% of total population)  \
# 0                                  0.149099
# 0                                 -0.010054
# 0                                  0.022155
# 0                                  0.095959
# 0                                  0.051659
# 0                                  0.086413
# 0                                  0.201812
# 0                                  0.143097
# 0                                  0.132840
# 0                                  0.061489
# 0                                  0.064386
# 0                                  0.001443
# 0                                  0.124888
# 0                                 -0.030424
# 0                                  0.321625
# 0                                  0.230172
# 0                                  0.059514
# 0                                  0.095862
# 0                                  0.117755
# 0                                 -0.009536
# 0                                  0.195642
# 0                                  0.113209
# 0                                  0.135419
#
#    Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                           0.107467
# 0                                           0.153904
# 0                                           0.124308
# 0                                           0.100214
# 0                                           0.113746
# 0                                           0.121109
# 0                                           0.089783
# 0                                           0.102004
# 0                                           0.104055
# 0                                           0.121098
# 0                                           0.125975
# 0                                           0.050089
# 0                                           0.123958
# 0                                                NaN
# 0                                           0.074407
# 0                                           0.108041
# 0                                           0.131249
# 0                                           0.116328
# 0                                           0.105010
# 0                                           0.144115
# 0                                           0.098585
# 0                                           0.097467
# 0                                           0.085135
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                           0.137313
# 0                                          -0.145745
# 0                                           0.104225
# 0                                           0.162844
# 0                                           0.067728
# 0                                           0.007510
# 0                                          -0.205180
# 0                                           0.092510
# 0                                          -0.080883
# 0                                           0.008559
# 0                                           0.144333
# 0                                           0.091942
# 0                                          -0.114647
# 0                                          -0.056332
# 0                                           0.121118
# 0                                           0.109368
# 0                                          -0.018661
# 0                                          -0.219381
# 0                                          -0.139812
# 0                                           0.059684
# 0                                           0.213134
# 0                                           0.077239
# 0                                           0.162441
#
#    Urban population  Urban population (% of total population)
# 0         -0.192160                                 -0.149099
# 0         -0.040174                                  0.010054
# 0         -0.047544                                 -0.022155
# 0         -0.209193                                 -0.095959
# 0         -0.161430                                 -0.051659
# 0         -0.119684                                 -0.086413
# 0         -0.213080                                 -0.201812
# 0         -0.047479                                 -0.143097
# 0         -0.158273                                 -0.132840
# 0         -0.147819                                 -0.061489
# 0         -0.069109                                 -0.064386
# 0         -0.030335                                 -0.001443
# 0         -0.141558                                 -0.124888
# 0         -0.018134                                  0.030424
# 0         -0.266819                                 -0.321625
# 0         -0.220590                                 -0.230172
# 0         -0.059299                                 -0.059514
# 0         -0.155415                                 -0.095862
# 0         -0.167460                                 -0.117755
# 0         -0.070705                                  0.009536
# 0         -0.193300                                 -0.195642
# 0         -0.110409                                 -0.113209
# 0         -0.098932                                 -0.135419
#
# [23 rows x 44 columns]

# %%
correlaciones_por_pais.head(100)
# Out:
#    Birth rate, crude (per 1,000 people)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                              0.769019                             0.400697
# 0                              0.553211                             0.159017
# 0                              0.477770                             0.483241
# 0                              0.767757                             0.348921
# 0                              0.542633                             0.292770
# 0                              0.470423                             0.229455
# 0                              0.558151                             0.378914
# 0                              0.676471                                  NaN
# 0                              0.660309                             0.311954
# 0                              0.593779                             0.484526
# 0                              0.498134                             0.538358
# 0                              0.541473                             0.575301
# 0                              0.499552                             0.503997
# 0                              0.503109                                  NaN
# 0                              0.552385                             0.418508
# 0                              0.627683                             0.454843
# 0                              0.516760                             0.290397
# 0                              0.750761                             0.315505
# 0                              0.636636                             0.540965
# 0                              0.528817                             0.297951
# 0                              0.817973                             0.306141
# 0                              0.713190                             0.392865
# 0                              0.745975                             0.240057
#
#    Capital health expenditure (% of GDP)  \
# 0                               0.219555
# 0                               0.433155
# 0                               0.275348
# 0                               0.334708
# 0                               0.289604
# 0                               0.226812
# 0                               0.256316
# 0                               0.189297
# 0                               0.085722
# 0                               0.324360
# 0                               0.345090
# 0                               0.339533
# 0                               0.201676
# 0                                    NaN
# 0                               0.206841
# 0                               0.239385
# 0                               0.267110
# 0                               0.327275
# 0                               0.285176
# 0                               0.397175
# 0                               0.306199
# 0                               0.254943
# 0                               0.157030
#
#    Compulsory education, duration (years)  Control of Corruption: Estimate  \
# 0                               -0.043365                         0.098457
# 0                                0.101643                        -0.002336
# 0                               -0.009387                         0.213800
# 0                               -0.008530                         0.023635
# 0                                0.021668                         0.097501
# 0                                0.015002                        -0.012546
# 0                               -0.071576                         0.013785
# 0                               -0.016219                         0.286060
# 0                               -0.040619                        -0.174798
# 0                               -0.005803                        -0.043671
# 0                                0.130375                         0.099921
# 0                                0.139860                        -0.075180
# 0                                0.008218                         0.047049
# 0                                0.034464                         0.038268
# 0                               -0.103166                        -0.139739
# 0                               -0.073336                         0.253710
# 0                                0.100461                         0.070447
# 0                                0.036894                         0.130698
# 0                               -0.045245                         0.050809
# 0                                0.097928                         0.185178
# 0                               -0.030809                         0.032817
# 0                               -0.051223                        -0.127024
# 0                                0.284241                         0.219000
#
#    Current health expenditure per capita, PPP (current international $)  \
# 0                                           0.312727
# 0                                           0.415349
# 0                                           0.408673
# 0                                           0.337380
# 0                                           0.341573
# 0                                           0.380711
# 0                                           0.273027
# 0                                           0.281334
# 0                                           0.332150
# 0                                           0.346861
# 0                                           0.456054
# 0                                           0.417250
# 0                                           0.390747
# 0                                                NaN
# 0                                           0.234545
# 0                                           0.304027
# 0                                           0.422321
# 0                                           0.312294
# 0                                           0.330873
# 0                                           0.422354
# 0                                           0.293550
# 0                                           0.314885
# 0                                           0.237530
#
#    Death rate, crude (per 1,000 people)  \
# 0                              0.967689
# 0                              0.495251
# 0                              0.887702
# 0                              0.985748
# 0                              0.901336
# 0                              0.812565
# 0                              0.762766
# 0                              0.707088
# 0                              0.973464
# 0                              0.772898
# 0                              0.458220
# 0                              0.280488
# 0                              0.515541
# 0                              0.921301
# 0                              0.886043
# 0                              0.648494
# 0                              0.571413
# 0                              0.902634
# 0                              0.887582
# 0                              0.867643
# 0                              0.924958
# 0                              0.950170
# 0                              0.728668
#
#    Diabetes prevalence (% of population ages 20 to 79)  \
# 0                                           0.062824
# 0                                           0.079589
# 0                                           0.080030
# 0                                           0.079702
# 0                                           0.074265
# 0                                           0.067595
# 0                                           0.047761
# 0                                           0.035484
# 0                                           0.077480
# 0                                           0.064582
# 0                                           0.071866
# 0                                           0.118295
# 0                                           0.070979
# 0                                           0.076343
# 0                                           0.049606
# 0                                           0.041814
# 0                                           0.123874
# 0                                           0.070437
# 0                                           0.049830
# 0                                           0.074705
# 0                                           0.047076
# 0                                           0.047637
# 0                                           0.034409
#
#    Domestic general government health expenditure (% of GDP)  \
# 0                                           0.323658
# 0                                           0.452302
# 0                                           0.401578
# 0                                           0.345970
# 0                                           0.370077
# 0                                           0.395621
# 0                                           0.299825
# 0                                           0.311878
# 0                                           0.334782
# 0                                           0.335491
# 0                                           0.452813
# 0                                           0.319906
# 0                                           0.408071
# 0                                                NaN
# 0                                           0.236417
# 0                                           0.319137
# 0                                           0.427502
# 0                                           0.358245
# 0                                           0.334579
# 0                                           0.435403
# 0                                           0.302031
# 0                                           0.325513
# 0                                           0.222923
#
#    Domestic general government health expenditure per capita, PPP (current international $)  \
# 0                                           0.303186
# 0                                           0.387887
# 0                                           0.407687
# 0                                           0.336460
# 0                                           0.317375
# 0                                           0.381242
# 0                                           0.267628
# 0                                           0.277205
# 0                                           0.301088
# 0                                           0.307159
# 0                                           0.451146
# 0                                           0.352708
# 0                                           0.395385
# 0                                                NaN
# 0                                           0.222887
# 0                                           0.291070
# 0                                           0.401957
# 0                                           0.317979
# 0                                           0.308967
# 0                                           0.401184
# 0                                           0.283770
# 0                                           0.294063
# 0                                           0.234633
#
#    ...  Poverty gap at $6.85 a day (2017 PPP) (%)  \
# 0  ...                                   0.194124
# 0  ...                                   0.242822
# 0  ...                                   0.159368
# 0  ...                                   0.179966
# 0  ...                                   0.032427
# 0  ...                                   0.254229
# 0  ...                                   0.116808
# 0  ...                                        NaN
# 0  ...                                   0.279958
# 0  ...                                   0.069732
# 0  ...                                   0.067863
# 0  ...                                   0.079528
# 0  ...                                   0.284475
# 0  ...                                        NaN
# 0  ...                                   0.070377
# 0  ...                                   0.158055
# 0  ...                                   0.006258
# 0  ...                                   0.192145
# 0  ...                                   0.099204
# 0  ...                                   0.317862
# 0  ...                                   0.661656
# 0  ...                                   0.185170
# 0  ...                                   0.111759
#
#    Pregnant women receiving prenatal care (%)  \
# 0                                    0.075038
# 0                                    0.123391
# 0                                    0.119130
# 0                                    0.036705
# 0                                   -0.011661
# 0                                    0.101640
# 0                                    0.103081
# 0                                    0.167485
# 0                                    0.109584
# 0                                    0.021434
# 0                                    0.081639
# 0                                    0.118108
# 0                                    0.086129
# 0                                         NaN
# 0                                    0.096500
# 0                                    0.116530
# 0                                    0.035905
# 0                                    0.096232
# 0                                    0.065305
# 0                                    0.354986
# 0                                         NaN
# 0                                    0.072486
# 0                                    0.056411
#
#    Prevalence of overweight (% of adults)  \
# 0                                0.335196
# 0                                0.322811
# 0                                0.307279
# 0                                0.330184
# 0                                0.319733
# 0                                0.319394
# 0                                0.352482
# 0                                0.372768
# 0                                0.323019
# 0                                0.348186
# 0                                0.310366
# 0                                0.251114
# 0                                0.325196
# 0                                     NaN
# 0                                0.372399
# 0                                0.403086
# 0                                0.270338
# 0                                0.330770
# 0                                0.327988
# 0                                0.309750
# 0                                0.365604
# 0                                0.339690
# 0                                0.396649
#
#    Prevalence of overweight, weight for height (% of children under 5)  \
# 0                                           0.058614
# 0                                           0.094767
# 0                                           0.085662
# 0                                           0.029653
# 0                                           0.120969
# 0                                           0.082999
# 0                                           0.056814
# 0                                           0.047309
# 0                                           0.096929
# 0                                           0.143206
# 0                                           0.055224
# 0                                           0.093093
# 0                                           0.096276
# 0                                                NaN
# 0                                           0.198943
# 0                                           0.120609
# 0                                           0.038192
# 0                                           0.084968
# 0                                           0.086462
# 0                                           0.310057
# 0                                           0.151683
# 0                                           0.134842
# 0                                           0.216618
#
#    Prevalence of undernourishment (% of population)  \
# 0                                          0.294207
# 0                                          0.368006
# 0                                          0.242975
# 0                                          0.302708
# 0                                          0.335737
# 0                                          0.337671
# 0                                          0.274131
# 0                                          0.311234
# 0                                          0.222665
# 0                                          0.279982
# 0                                          0.419242
# 0                                          0.395274
# 0                                          0.335524
# 0                                          0.334937
# 0                                          0.238238
# 0                                          0.293922
# 0                                          0.355280
# 0                                          0.243878
# 0                                          0.309716
# 0                                          0.279973
# 0                                          0.292696
# 0                                          0.290468
# 0                                          0.134534
#
#    Rural population (% of total population)  \
# 0                                  0.149099
# 0                                 -0.010054
# 0                                  0.022155
# 0                                  0.095959
# 0                                  0.051659
# 0                                  0.086413
# 0                                  0.201812
# 0                                  0.143097
# 0                                  0.132840
# 0                                  0.061489
# 0                                  0.064386
# 0                                  0.001443
# 0                                  0.124888
# 0                                 -0.030424
# 0                                  0.321625
# 0                                  0.230172
# 0                                  0.059514
# 0                                  0.095862
# 0                                  0.117755
# 0                                 -0.009536
# 0                                  0.195642
# 0                                  0.113209
# 0                                  0.135419
#
#    Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)  \
# 0                                           0.107467
# 0                                           0.153904
# 0                                           0.124308
# 0                                           0.100214
# 0                                           0.113746
# 0                                           0.121109
# 0                                           0.089783
# 0                                           0.102004
# 0                                           0.104055
# 0                                           0.121098
# 0                                           0.125975
# 0                                           0.050089
# 0                                           0.123958
# 0                                                NaN
# 0                                           0.074407
# 0                                           0.108041
# 0                                           0.131249
# 0                                           0.116328
# 0                                           0.105010
# 0                                           0.144115
# 0                                           0.098585
# 0                                           0.097467
# 0                                           0.085135
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                           0.137313
# 0                                          -0.145745
# 0                                           0.104225
# 0                                           0.162844
# 0                                           0.067728
# 0                                           0.007510
# 0                                          -0.205180
# 0                                           0.092510
# 0                                          -0.080883
# 0                                           0.008559
# 0                                           0.144333
# 0                                           0.091942
# 0                                          -0.114647
# 0                                          -0.056332
# 0                                           0.121118
# 0                                           0.109368
# 0                                          -0.018661
# 0                                          -0.219381
# 0                                          -0.139812
# 0                                           0.059684
# 0                                           0.213134
# 0                                           0.077239
# 0                                           0.162441
#
#    Urban population  Urban population (% of total population)
# 0         -0.192160                                 -0.149099
# 0         -0.040174                                  0.010054
# 0         -0.047544                                 -0.022155
# 0         -0.209193                                 -0.095959
# 0         -0.161430                                 -0.051659
# 0         -0.119684                                 -0.086413
# 0         -0.213080                                 -0.201812
# 0         -0.047479                                 -0.143097
# 0         -0.158273                                 -0.132840
# 0         -0.147819                                 -0.061489
# 0         -0.069109                                 -0.064386
# 0         -0.030335                                 -0.001443
# 0         -0.141558                                 -0.124888
# 0         -0.018134                                  0.030424
# 0         -0.266819                                 -0.321625
# 0         -0.220590                                 -0.230172
# 0         -0.059299                                 -0.059514
# 0         -0.155415                                 -0.095862
# 0         -0.167460                                 -0.117755
# 0         -0.070705                                  0.009536
# 0         -0.193300                                 -0.195642
# 0         -0.110409                                 -0.113209
# 0         -0.098932                                 -0.135419
#
# [23 rows x 44 columns]

# %%
# Especifica el nombre del archivo CSV sin la ruta completa
nombre_archivo_csv = 'dataset_completo_sin_caribe.csv'

# Exporta el DataFrame a un archivo CSV en la misma carpeta
df_filtrado_nulos_Sin_Caribe.to_csv(nombre_archivo_csv)
