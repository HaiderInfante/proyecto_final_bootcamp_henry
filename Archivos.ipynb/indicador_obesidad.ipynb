# %% [markdown]
# * Indicador: Proportion of adults who are obese, 20 years old and over
# * ID para extracción: I555b0f6a
# * Fuente :https://gender-data-hub-2-undesa.hub.arcgis.com

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Fuente externa - United Nations Statistics Division (UNSD),
df_obesidad= pd.read_excel("./Obese - United Nations Statistics Division.xlsx")
df_obesidad.head()
# Out:
#   indicator_id
# 0    I555b0f6a  \
# 1    I555b0f6a
# 2    I555b0f6a
# 3    I555b0f6a
# 4    I555b0f6a
#
#    Proportion of adults who are obese, 20 years old and over ,by sex
# 0                                                1.0                  \
# 1                                                1.1
# 2                                                1.2
# 3                                                1.2
# 4                                                1.3
#
#   ref_area_desc iso3                           sex_desc  Unnamed: 5
# 0   Afghanistan  AFG  Both sexes or no breakdown by sex         NaN  \
# 1   Afghanistan  AFG  Both sexes or no breakdown by sex         NaN
# 2   Afghanistan  AFG  Both sexes or no breakdown by sex         NaN
# 3   Afghanistan  AFG  Both sexes or no breakdown by sex         NaN
# 4   Afghanistan  AFG  Both sexes or no breakdown by sex         NaN
#
#    Unnamed: 6  time_period
# 0         NaN         1990
# 1         NaN         1991
# 2         NaN         1992
# 3         NaN         1993
# 4         NaN         1994

# %%
# Elimino las columnas no necesarias
df_obesidad = df_obesidad.drop("indicator_id", axis=1) 
df_obesidad = df_obesidad.drop("Unnamed: 5", axis=1) 
df_obesidad = df_obesidad.drop("Unnamed: 6", axis=1) 
df_obesidad.head()
# Out:
#    Proportion of adults who are obese, 20 years old and over ,by sex
# 0                                                1.0                  \
# 1                                                1.1
# 2                                                1.2
# 3                                                1.2
# 4                                                1.3
#
#   ref_area_desc iso3                           sex_desc  time_period
# 0   Afghanistan  AFG  Both sexes or no breakdown by sex         1990
# 1   Afghanistan  AFG  Both sexes or no breakdown by sex         1991
# 2   Afghanistan  AFG  Both sexes or no breakdown by sex         1992
# 3   Afghanistan  AFG  Both sexes or no breakdown by sex         1993
# 4   Afghanistan  AFG  Both sexes or no breakdown by sex         1994

# %%
# Cambio nombres de algunas columnas en el df, para que coincida con el df de WB.
df_obesidad.rename(columns={"ref_area_desc": "Country"}, inplace=True)
df_obesidad.rename(columns={"time_period": "Year"}, inplace=True)
df_obesidad.rename(columns={"iso3": "Country_Code"}, inplace=True)
df_obesidad.rename(columns={"sex_desc": "Gender"}, inplace=True)
df_obesidad
# Out:
#        Proportion of adults who are obese, 20 years old and over ,by sex
# 0                                                    1.0                  \
# 1                                                    1.1
# 2                                                    1.2
# 3                                                    1.2
# 4                                                    1.3
# ...                                                  ...
# 15385                                                3.1
# 15386                                                3.2
# 15387                                                3.4
# 15388                                                3.5
# 15389                                                3.7
#
#            Country Country_Code                             Gender  Year
# 0      Afghanistan          AFG  Both sexes or no breakdown by sex  1990
# 1      Afghanistan          AFG  Both sexes or no breakdown by sex  1991
# 2      Afghanistan          AFG  Both sexes or no breakdown by sex  1992
# 3      Afghanistan          AFG  Both sexes or no breakdown by sex  1993
# 4      Afghanistan          AFG  Both sexes or no breakdown by sex  1994
# ...            ...          ...                                ...   ...
# 15385     Zimbabwe          ZWE                               Male  2012
# 15386     Zimbabwe          ZWE                               Male  2013
# 15387     Zimbabwe          ZWE                               Male  2014
# 15388     Zimbabwe          ZWE                               Male  2015
# 15389     Zimbabwe          ZWE                               Male  2016
#
# [15390 rows x 5 columns]

# %%
# Reordeno las columnas
orden_columnas = ["Country", "Country_Code" ,"Year","Proportion of adults who are obese, 20 years old and over ,by sex","Gender" ]  # Define el nuevo orden de las columnas
df_obesidad = df_obesidad[orden_columnas]  
df_obesidad
# Out:
#            Country Country_Code  Year
# 0      Afghanistan          AFG  1990  \
# 1      Afghanistan          AFG  1991
# 2      Afghanistan          AFG  1992
# 3      Afghanistan          AFG  1993
# 4      Afghanistan          AFG  1994
# ...            ...          ...   ...
# 15385     Zimbabwe          ZWE  2012
# 15386     Zimbabwe          ZWE  2013
# 15387     Zimbabwe          ZWE  2014
# 15388     Zimbabwe          ZWE  2015
# 15389     Zimbabwe          ZWE  2016
#
#        Proportion of adults who are obese, 20 years old and over ,by sex
# 0                                                    1.0                  \
# 1                                                    1.1
# 2                                                    1.2
# 3                                                    1.2
# 4                                                    1.3
# ...                                                  ...
# 15385                                                3.1
# 15386                                                3.2
# 15387                                                3.4
# 15388                                                3.5
# 15389                                                3.7
#
#                                   Gender
# 0      Both sexes or no breakdown by sex
# 1      Both sexes or no breakdown by sex
# 2      Both sexes or no breakdown by sex
# 3      Both sexes or no breakdown by sex
# 4      Both sexes or no breakdown by sex
# ...                                  ...
# 15385                               Male
# 15386                               Male
# 15387                               Male
# 15388                               Male
# 15389                               Male
#
# [15390 rows x 5 columns]

# %%
# Filtro los paises de la OEA, pero sin Caribe
Countries =["ARG","BRA","CAN","CHL","COL","CRI","CUB","DOM","ECU","SLV","GTM",
        "GUY","HTI","HND","JAM","MEX","NIC","PAN","PRY","PER","TTO","URY"]
df_obesidad_filtrado = df_obesidad[df_obesidad["Country_Code"].isin(Countries)]
df_obesidad_filtrado
# Out:
#          Country Country_Code  Year
# 162    Argentina          ARG  1990  \
# 163    Argentina          ARG  1991
# 164    Argentina          ARG  1992
# 165    Argentina          ARG  1993
# 166    Argentina          ARG  1994
# ...          ...          ...   ...
# 15196    Uruguay          URY  2012
# 15197    Uruguay          URY  2013
# 15198    Uruguay          URY  2014
# 15199    Uruguay          URY  2015
# 15200    Uruguay          URY  2016
#
#        Proportion of adults who are obese, 20 years old and over ,by sex
# 162                                                 16.6                  \
# 163                                                 17.0
# 164                                                 17.4
# 165                                                 17.8
# 166                                                 18.2
# ...                                                  ...
# 15196                                               23.1
# 15197                                               23.6
# 15198                                               24.2
# 15199                                               24.8
# 15200                                               25.3
#
#                                   Gender
# 162    Both sexes or no breakdown by sex
# 163    Both sexes or no breakdown by sex
# 164    Both sexes or no breakdown by sex
# 165    Both sexes or no breakdown by sex
# 166    Both sexes or no breakdown by sex
# ...                                  ...
# 15196                               Male
# 15197                               Male
# 15198                               Male
# 15199                               Male
# 15200                               Male
#
# [1782 rows x 5 columns]

# %%
# Cuentos los nulos
df_obesidad_filtrado.isnull().sum()
# Out:
# Country                                                              0
# Country_Code                                                         0
# Year                                                                 0
# Proportion of adults who are obese, 20 years old and over ,by sex    0
# Gender                                                               0
# dtype: int64

# %%
# Renombro las columnas del df, para que al momento de hacer la unión con el dataset de WB, coinicidan los nombres.
# Cambiar nombres de las columnas
df_obesidad_filtrado = df_obesidad_filtrado.rename(columns={'Country': 'País', 'Proportion of adults who are obese, 20 years old and over ,by sex': 'Proportion of adults who are obese', 'Year': "Año"})

# %%
# Procedo a dejar las columnas necesarias para hacer merge con el dataset de WB.
df_obesidad_filtrado = df_obesidad_filtrado.drop("Country_Code", axis=1) 
df_obesidad_filtrado = df_obesidad_filtrado.drop("Gender", axis=1) 
df_obesidad_filtrado.head()
# Out:
#           País   Año  Proportion of adults who are obese
# 162  Argentina  1990                                16.6
# 163  Argentina  1991                                17.0
# 164  Argentina  1992                                17.4
# 165  Argentina  1993                                17.8
# 166  Argentina  1994                                18.2

# %%
df_obesidad_filtrado.to_csv('obesidad.csv', index=False)
