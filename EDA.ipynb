# %%
import pandas as pd

# %%
archivo_csv = '09e13236-f04b-41c1-a740-65d5ce258b48_Data.csv'

# Leer el archivo CSV y crear un DataFrame
df = pd.read_csv(archivo_csv)

# %%
df.head()
# Out:
#                                          Series Name  Series Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 1  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 2  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 3  Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 4  Adults (ages 15+) and children (0-14 years) li...  SH.HIV.TOTL
#
#   Country Name Country Code 1990 [YR1990] 1998 [YR1998] 1999 [YR1999]  \
# 0    Argentina          ARG        70.928        69.307        68.268
# 1     Colombia          COL        94.916         92.16        94.957
# 2   Costa Rica          CRI        93.687        84.553        84.734
# 3      Bolivia          BOL        96.346        91.297        92.943
# 4    Argentina          ARG         16000         55000         59000
#
#   2000 [YR2000] 2001 [YR2001] 2002 [YR2002]  ... 2005 [YR2005] 2006 [YR2006]  \
# ...

# %%
# Supongamos que tienes un DataFrame llamado 'df' con la estructura proporcionada

# Lista de columnas que no se deben incluir en la fusión
columnas_no_a_melt = ['Country Name', 'Country Code', 'Series Name', 'Series Code']

# Utiliza pd.melt para combinar las columnas de años en una sola columna
df_melted = pd.melt(df, id_vars=columnas_no_a_melt, var_name='Año', value_name='Valor')

# Esto creará un nuevo DataFrame 'df_melted' con las columnas 'Country Name', 'Country Code', 'Series Name', 'Series Code', 'Año' y 'Valor'

# %%
df_melted
# Out:
#       Country Name Country Code  \
# 0        Argentina          ARG
# 1         Colombia          COL
# 2       Costa Rica          CRI
# 3          Bolivia          BOL
# 4        Argentina          ARG
# ...            ...          ...
# 33925          NaN          NaN
# 33926          NaN          NaN
# 33927          NaN          NaN
# 33928          NaN          NaN
# 33929          NaN          NaN
#
#                                              Series Name  Series Code  \
# 0      Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 1      Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 2      Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 3      Adolescent fertility rate (births per 1,000 wo...  SP.ADO.TFRT
# 4      Adults (ages 15+) and children (0-14 years) li...  SH.HIV.TOTL
# ...                                                  ...          ...
# 33925                                                NaN          NaN
# ...

# %%
# Elimina las filas que contienen '..' en la columna 'Valor'
df_final = df_melted[df_melted['Valor'] != '..']

# Agrupa por 'Series Name' y cuenta la cantidad de filas con valores en la columna 'Valor'
conteo_series_name = df_final.groupby('Series Name')['Valor'].count().reset_index()

# Renombra la columna de conteo para mayor claridad
conteo_series_name.rename(columns={'Valor': 'Cantidad'}, inplace=True)

# Ahora 'conteo_series_name' contiene el conteo de "Series Name" con valores asociados
# Puedes imprimirlo o trabajar con él según tus necesidades
conteo_series_name = conteo_series_name.sort_values(by='Cantidad', ascending=False)
conteo_series_name
# Out:
#                                            Series Name  Cantidad
# 0             AIDS estimated deaths (UNAIDS estimates)        72
# 258                        Population ages 10-14, male        72
# 265                      Population ages 15-64, female        72
# 264      Population ages 15-64 (% of total population)        72
# 263  Population ages 15-19, male (% of male populat...        72
# ..                                                 ...       ...
# 450  Use of insecticide-treated bed nets (% of unde...         1
# 76         Community health workers (per 1,000 people)         1
# 147  Infant and young child feeding practices, all ...         1
# 101  Data from database: Health Nutrition and Popul...         0
# 150                           Last Updated: 09/21/2023         0
#
# [457 rows x 2 columns]

# %%
# Filtra las filas donde 'Cantidad' sea igual a 132
result = conteo_series_name[conteo_series_name['Cantidad'] == 72]

# Imprime o trabaja con el DataFrame 'result', que contendrá solo las filas donde 'Cantidad' es igual a 132
result
# Out:
#                                            Series Name  Cantidad
# 0             AIDS estimated deaths (UNAIDS estimates)        72
# 258                        Population ages 10-14, male        72
# 265                      Population ages 15-64, female        72
# 264      Population ages 15-64 (% of total population)        72
# 263  Population ages 15-19, male (% of male populat...        72
# ..                                                 ...       ...
# 74                       Children orphaned by HIV/AIDS        72
# 142  Incidence of HIV, ages 15-49 (per 1,000 uninfe...        72
# 144  Incidence of HIV, all (per 1,000 uninfected po...        72
# 18        Age population, age 03, female, interpolated        72
# 143  Incidence of HIV, ages 50+ (per 1,000 uninfect...        72
#
# [233 rows x 2 columns]

# %%
# Supongamos que tienes un DataFrame llamado 'df' que deseas exportar a un archivo CSV.

# Especifica el nombre del archivo CSV de destino
nombre_archivo_csv = 'Health Nutrition and Population Statistics.csv'

# Utiliza la función to_csv para exportar el DataFrame a CSV
result.to_csv(nombre_archivo_csv, index=False)  # El parámetro index=False evita que se incluyan los índices en el archivo CSV
